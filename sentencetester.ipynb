# %%
DEBUG = False

# Word file assists with the randomness of the prompt
with open("words", 'r') as file:
        lines_array = [line.strip() for line in file.readlines()]
        if(DEBUG):
                print(f"{len(lines_array)} words in list")

# %%
from ollama import Client
from ollama import generate
import random

def generate_theme():
    word1 = lines_array[random.randint(0, len(lines_array))]
    word2 = lines_array[random.randint(0, len(lines_array))]
    prompt = f"The theme is '{word1} {word2}'."
    if(DEBUG):
        print(prompt)
    return prompt

def generate_response(client, model):
    prompt = generate_theme()
    seed = int(random.random()*1000)
    system_prompt = """
        Write a single sentence with between 8 and 10 words to be used as a memorable pass phrase.
        Try to use as much of the alphabet as you can, but don't put yourself out over it.
        Only output the sentence. Don't ramble.
        """
    
    options = {
        "seed": seed, 
        "temperature": seed/100.0,
        "num_predict": 400

    }
    response = client.generate(
        model = model,
        prompt = f"{system_prompt} {prompt}",
        # system = system_prompt,
        options=options,
        stream = False
    )
    reply = response['response']
    if(DEBUG):
        print(f"r:{reply}")
    return reply

# %%
class Sentence:
    boring_words = ["quick", "brown", "fox", "jumps", "dog", "lazy"]
    bonus_dups = ["r", "s", "t", "l", "p", "e"]

    def __init__(self, text, client):
        """
        Args:
            text (str): The text of the sentence.  Must be a string.
        
        Raises:
            TypeError: if input is not a string
        """
        if not isinstance(text, str):
            raise TypeError("Input must be a string.")

        if len(text) > 80:
            if(DEBUG):
                print(f"long text rejected: {text}")
            raise TypeError("No paragraphs.")
        
        self._text = text.encode("ascii", errors="ignore").decode()  # Use a protected attribute for encapsulation
        self._words = len(text.split(" "))
        self._missing = self.find_missing_letters()
        self._duplicates = self.find_duplicate_letters()
        self._duplength = len(self._duplicates)
        self._dupkeys = "".join(self._duplicates.keys())
        self._client = client
        self._score = self.calculate_score()

    def get_text(self):
        """
        Returns the text of the sentence.

        Returns:
            str: The sentence text.
        """
        return self._text

    def get_client(self):
        return self._client
    
    def get_missing(self):
        return self._missing
    
    def get_missing_count(self):
        return len(self.get_missing())
      
    def get_duplicates(self):
        return self._duplicates
    
    def get_duplength(self):
        return self._duplength
    
    def get_dupkeys(self):
        return self._dupkeys
    
    def get_score(self):
        return self._score
    
    def calculate_score(self):
        missing_score = (26 - self.get_missing_count())**2
        duplicate_score = self.get_duplength()
        for boring_word in self.boring_words:
            if(boring_word in self.get_text().lower()):
                if(DEBUG):
                    print(f"Lowering score for {boring_word}")
                missing_score = missing_score - 100

        for bonus in self.bonus_dups:
            if(bonus in self.get_dupkeys()):
                duplicate_score = duplicate_score + 50

        return missing_score * duplicate_score

    
    def find_missing_letters(self):
        """
        Checks a string for the presence of all lowercase letters and identifies missing ones.

        Returns:
            A string containing the missing letters, or an empty string if all letters are present.
            Returns None if the input is not a string.
        """

        alphabet = "abcdefghijklmnopqrstuvwxyz"
        missing_letters = ""
        
        # Convert the input string to lowercase for case-insensitive comparison
        input_string = self._text.lower()

        for letter in alphabet:
            if letter not in input_string:
                missing_letters += letter

        return missing_letters

    def find_duplicate_letters(self):
        """
        Identifies duplicate letters in a string and counts their occurrences.

        Returns:
            A dictionary where keys are the duplicate letters and values are their counts.
            Returns an empty dictionary if there are no duplicates.
            Returns None if the input is not a string.
        """

        letter_counts = {}
        duplicate_counts = {}

        input_string = self._text.lower()  # Case-insensitive counting

        for letter in input_string:
            if 'a' <= letter <= 'z':  # Only consider letters
                if letter in letter_counts:
                    letter_counts[letter] += 1
                else:
                    letter_counts[letter] = 1

        # Identify duplicates and create a new dictionary
        for letter, count in letter_counts.items():
            if count > 1:
                duplicate_counts[letter] = count

        return duplicate_counts

class Winners:
    def __init__(self):
        self._sentences = []

    def add(self, sentence):
        self._sentences.append(sentence)
        if(DEBUG):
            print(f"There are {len(self._sentences)} sentences in the list.")

    def get_missing_winners(self, _count):
        sorted_winners = sorted(self._sentences, key=lambda item: item.get_missing_count())
        return sorted_winners[:_count]
    
    def get_score_winners(self, _count):
        sorted_winners = sorted(self._sentences, key=lambda item: item.get_score(), reverse=True)
        return sorted_winners[:_count]

    def length(self):
        return len(self._sentences)

# Test cases. Add to this list when you find good terms.
the_sentences = [
    "The quick brown fox jumps over the lazy dog.",
    "Golden sunlight danced upon the rippling, turquoise ocean waves.",
    "Old photographs revealed stories of laughter, love, and bygone days.",
    "The majestic mountains stood silently guarding the peaceful valley below.",
    "She expertly crafted intricate jewelry using shimmering silver and gold. The majestic mountains stood silently guarding the peaceful valley below.",
    "Dark storm clouds gathered quickly, threatening a powerful summer rain.",
    "Street food tasted wonderfully fresh.",
    "Remote islands felt truly peaceful.",
    "The axel, quickly! Jumping fences with brave, zealous strides.",
    "The teen quickly jammed, exploring vibrant chords with joyful zest."
]

winners = Winners()
for sentence in the_sentences:
    try:
        winners.add(Sentence(sentence, 0))
        
    except Exception as e:
        print(e)


def print_missing_winners(the_winners):
    for winner in the_winners:
        print(f"Missing:{winner.get_missing_count()}\t'{winner.get_missing()}'\tScore:{winner.get_score()}\tDuplicates:{winner.get_duplength()}\t'{winner.get_dupkeys()}'\t\tClient:{winner.get_client()}\t\"{winner.get_text()}\"")
    print("****************************")

print_missing_winners(winners.get_missing_winners(5))

def print_score_winners(the_winners):
    for winner in the_winners:
        print(f"Score:{winner.get_score()}\tMissing:{winner.get_missing_count()}\t'{winner.get_missing()}'\tDuplicates:{winner.get_duplength()}\t'{winner.get_dupkeys()}'\t\tClient:{winner.get_client()}\t\"{winner.get_text()}\"")
    print("============================")

print_score_winners(winners.get_score_winners(5))
# Out:
# No paragraphs.
# Missing:0	''	Score:11856	Duplicates:6	'theuro'		Client:0	"The quick brown fox jumps over the lazy dog."
# Missing:0	''	Score:150336	Duplicates:11	'thealuicnsr'		Client:0	"The axel, quickly! Jumping fences with brave, zealous strides."
# Missing:0	''	Score:153216	Duplicates:16	'thenuiclyjamdors'		Client:0	"The teen quickly jammed, exploring vibrant chords with joyful zest."
# Missing:4	'kqxz'	Score:104060	Duplicates:15	'themasicoundlyg'		Client:0	"The majestic mountains stood silently guarding the peaceful valley below."
# Missing:5	'bjvxz'	Score:90706	Duplicates:16	'darkstomclughein'		Client:0	"Dark storm clouds gathered quickly, threatening a powerful summer rain."
# ****************************
# Score:153216	Missing:0	''	Duplicates:16	'thenuiclyjamdors'		Client:0	"The teen quickly jammed, exploring vibrant chords with joyful zest."
# Score:150336	Missing:0	''	Duplicates:11	'thealuicnsr'		Client:0	"The axel, quickly! Jumping fences with brave, zealous strides."
# Score:104060	Missing:4	'kqxz'	Duplicates:15	'themasicoundlyg'		Client:0	"The majestic mountains stood silently guarding the peaceful valley below."
# Score:102060	Missing:8	'bfjkmxyz'	Duplicates:15	'goldensuihtacpr'		Client:0	"Golden sunlight danced upon the rippling, turquoise ocean waves."
# Score:101736	Missing:8	'cjkmqwxz'	Duplicates:14	'oldphtgrasevny'		Client:0	"Old photographs revealed stories of laughter, love, and bygone days."
# ============================

# %%
import threading
import time

timeout = 1*60*60 #60*15 #*60 #7*60*60 #30*30 #1*60*60 #2*60*60 #7*60*60
winning_sentences = Winners()
running = True
previous_missing = [] # Keep track of high winners so we can display it when it changes.
previous_high_scores = []
DEBUG = False #True

def worker(client_id, url, model):
    """
     a client processing a task.
    
    Args:
        client_id: Unique identifier for the client.
        url: The URL associated with the client's task.
        model: the model to use for this client.
    """
    client = Client(host=url)
    i = 0
    while True:
        global running
        global winning_sentences
        global previous_missing
        global previous_high_scores
        i = i + 1
        if(running != True):
           # Exiting
           print(f"Quitting client {client_id} url {url} model {model} i {i} running: {running}")
           return
        try:
            if(DEBUG):
                print(f"client {client_id} url {url} model {model} i {i} running: {running}")

            sentence = Sentence(generate_response(client, model).strip().replace("\n", " "), client_id)
            if(DEBUG):
                print(sentence.get_text())

            winning_sentences.add(sentence)

            missing_winners = winning_sentences.get_missing_winners(3)
            if(missing_winners != previous_missing):
                previous_missing = missing_winners
                print_missing_winners(missing_winners)
            
            score_winners = winning_sentences.get_score_winners(3)
            if(score_winners != previous_high_scores):
                previous_high_scores = score_winners
                print_score_winners(score_winners)

            # 2 Seconds of cool down for the LLM. Gives the connection time to die.
            time.sleep(2)

        except Exception as e:
            dummy = 1 # Ignore all exceptions. Set dummy so linter doesn't complain.
            if(DEBUG):
                print(f"client {client_id} url {url} {e}")
        

def main():
    """
    Creates and starts multiple client threads.
    """

    clients = [
        {"id": 1, "url": "http://192.168.137.118:11434", "model": "gemma3:12b"},
        {"id": 2, "url": "http://192.168.137.117:11434", "model": "gemma3:4b"},
        {"id": 3, "url": "http://192.168.137.119:11434", "model": "gemma3:4b"},
    ]

    global running
    running = True
    threads = []
    for client in clients:
        thread = threading.Thread(target=worker, args=(client["id"], client["url"], client["model"]))
        threads.append(thread)
        thread.start()

    try:
        time.sleep(timeout)
        # Time's up. Tell threads to wrap it up. There may be a significant delay because the client might still be processing.
        running = False
        print(f"Calling it quits after {timeout} seconds.")
        
        # Wait for all threads to finish
        for thread in threads:
            thread.join(timeout=30)

        print("\n\nAll threads have stopped.")
        missing_winners = winning_sentences.get_missing_winners(50)
        
        # Word file assists with the randomness of the prompt
        with open("winners", 'a') as file:
            for winner in missing_winners:
                message = f"Missing:{winner.get_missing_count()}\t'{winner.get_missing()}'\tScore:{winner.get_score()}\tDuplicates:{winner.get_duplength()}\t'{winner.get_dupkeys()}'\t\tClient:{winner.get_client()}\t\"{winner.get_text()}\""
                print(message)
                print(message, file=file)

            print("-----------------------------")
            duplicate_winners = winning_sentences.get_score_winners(50)
            for winner in duplicate_winners:
                message = f"Score:{winner.get_score()}\tMissing:{winner.get_missing_count()}\t'{winner.get_missing()}'\tDuplicates:{winner.get_duplength()}\t'{winner.get_dupkeys()}'\t\tClient:{winner.get_client()}\t\"{winner.get_text()}\""
                print(message)
                print(message, file=file)

            file.close()
            print("============================\n\n")

    
       
    except KeyboardInterrupt:
        print("Stopping threads due to KeyboardInterrupt...")
        running = False
        for thread in threads:
            thread.join()
        print("All threads stopped after KeyboardInterrupt")

if __name__ == "__main__":
    main()
# Out:
# Missing:5	'dkqwx'	Score:138915	Duplicates:15	'voilenjyafusprt'		Client:2	"Voil, enjoy a fabulous joy, perhaps letting zest influence every move."
# ****************************
# Score:138915	Missing:5	'dkqwx'	Duplicates:15	'voilenjyafusprt'		Client:2	"Voil, enjoy a fabulous joy, perhaps letting zest influence every move."
# ============================
# Missing:4	'hkmz'	Score:153428	Duplicates:17	'udicosexprtaflyvn'		Client:1	"Judicious experts carefully observe vital taxpayer flows quietly expanding."
# Missing:5	'dkqwx'	Score:138915	Duplicates:15	'voilenjyafusprt'		Client:2	"Voil, enjoy a fabulous joy, perhaps letting zest influence every move."
# ****************************
# Score:153428	Missing:4	'hkmz'	Duplicates:17	'udicosexprtaflyvn'		Client:1	"Judicious experts carefully observe vital taxpayer flows quietly expanding."
# Score:138915	Missing:5	'dkqwx'	Duplicates:15	'voilenjyafusprt'		Client:2	"Voil, enjoy a fabulous joy, perhaps letting zest influence every move."
# ============================
# Missing:3	'jqx'	Score:140714	Duplicates:16	'zealouswirdncktg'		Client:2	"Zealous wizards unlock cryptic chambers, revealing forgotten knowledge."
# Missing:4	'hkmz'	Score:153428	Duplicates:17	'udicosexprtaflyvn'		Client:1	"Judicious experts carefully observe vital taxpayer flows quietly expanding."
# Missing:5	'dkqwx'	Score:138915	Duplicates:15	'voilenjyafusprt'		Client:2	"Voil, enjoy a fabulous joy, perhaps letting zest influence every move."
# ****************************
# Score:153428	Missing:4	'hkmz'	Duplicates:17	'udicosexprtaflyvn'		Client:1	"Judicious experts carefully observe vital taxpayer flows quietly expanding."
# Score:140714	Missing:3	'jqx'	Duplicates:16	'zealouswirdncktg'		Client:2	"Zealous wizards unlock cryptic chambers, revealing forgotten knowledge."
# Score:138915	Missing:5	'dkqwx'	Duplicates:15	'voilenjyafusprt'		Client:2	"Voil, enjoy a fabulous joy, perhaps letting zest influence every move."
# ============================
# Missing:3	'jqx'	Score:140714	Duplicates:16	'zealouswirdncktg'		Client:2	"Zealous wizards unlock cryptic chambers, revealing forgotten knowledge."
# Missing:3	'bmz'	Score:139656	Duplicates:14	'enturoilyjgswa'		Client:2	"Venture forth, quietly explore, judging journeys, knowing secrets, always."
# Missing:4	'hkmz'	Score:153428	Duplicates:17	'udicosexprtaflyvn'		Client:1	"Judicious experts carefully observe vital taxpayer flows quietly expanding."
# ****************************
# Score:153428	Missing:4	'hkmz'	Duplicates:17	'udicosexprtaflyvn'		Client:1	"Judicious experts carefully observe vital taxpayer flows quietly expanding."
# Score:140714	Missing:3	'jqx'	Duplicates:16	'zealouswirdncktg'		Client:2	"Zealous wizards unlock cryptic chambers, revealing forgotten knowledge."
# Score:139656	Missing:3	'bmz'	Duplicates:14	'enturoilyjgswa'		Client:2	"Venture forth, quietly explore, judging journeys, knowing secrets, always."
# ============================
# Missing:2	'bw'	Score:46640	Duplicates:15	'uicoesmpvrladgn'		Client:1	"Quick foxes jump over lazy dogs, valuing historic American pride."
# Missing:3	'jqx'	Score:140714	Duplicates:16	'zealouswirdncktg'		Client:2	"Zealous wizards unlock cryptic chambers, revealing forgotten knowledge."
# Missing:3	'bmz'	Score:139656	Duplicates:14	'enturoilyjgswa'		Client:2	"Venture forth, quietly explore, judging journeys, knowing secrets, always."
# ****************************
# Missing:2	'bw'	Score:46640	Duplicates:15	'uicoesmpvrladgn'		Client:1	"Quick foxes jump over lazy dogs, valuing historic American pride."
# Missing:2	'kz'	Score:180864	Duplicates:14	'uerinatxoslwpd'		Client:1	"Queering vibrant axioms fetch low pipes, justly explode upwards."
# Missing:3	'jqx'	Score:140714	Duplicates:16	'zealouswirdncktg'		Client:2	"Zealous wizards unlock cryptic chambers, revealing forgotten knowledge."
# ****************************
# Score:180864	Missing:2	'kz'	Duplicates:14	'uerinatxoslwpd'		Client:1	"Queering vibrant axioms fetch low pipes, justly explode upwards."
# Score:153428	Missing:4	'hkmz'	Duplicates:17	'udicosexprtaflyvn'		Client:1	"Judicious experts carefully observe vital taxpayer flows quietly expanding."
# Score:140714	Missing:3	'jqx'	Duplicates:16	'zealouswirdncktg'		Client:2	"Zealous wizards unlock cryptic chambers, revealing forgotten knowledge."
# ============================
# Missing:2	'bw'	Score:46640	Duplicates:15	'uicoesmpvrladgn'		Client:1	"Quick foxes jump over lazy dogs, valuing historic American pride."
# Missing:2	'kz'	Score:180864	Duplicates:14	'uerinatxoslwpd'		Client:1	"Queering vibrant axioms fetch low pipes, justly explode upwards."
# Missing:2	'vz'	Score:149940	Duplicates:15	'ritjunpesclyoda'		Client:1	"Bright junipers quickly produced fantastic Japanese melon sweetness expertly."
# ****************************
# Score:180864	Missing:2	'kz'	Duplicates:14	'uerinatxoslwpd'		Client:1	"Queering vibrant axioms fetch low pipes, justly explode upwards."
# Score:153428	Missing:4	'hkmz'	Duplicates:17	'udicosexprtaflyvn'		Client:1	"Judicious experts carefully observe vital taxpayer flows quietly expanding."
# Score:149940	Missing:2	'vz'	Duplicates:15	'ritjunpesclyoda'		Client:1	"Bright junipers quickly produced fantastic Japanese melon sweetness expertly."
# ============================
# Score:180864	Missing:2	'kz'	Duplicates:14	'uerinatxoslwpd'		Client:1	"Queering vibrant axioms fetch low pipes, justly explode upwards."
# Score:153428	Missing:4	'hkmz'	Duplicates:17	'udicosexprtaflyvn'		Client:1	"Judicious experts carefully observe vital taxpayer flows quietly expanding."
# Score:151488	Missing:2	'hj'	Duplicates:13	'leyrasuitwckn'		Client:3	"Lovely zebras quietly wreck flawed items using excellent raw keeps!."
# ============================
# Score:180864	Missing:2	'kz'	Duplicates:14	'uerinatxoslwpd'		Client:1	"Queering vibrant axioms fetch low pipes, justly explode upwards."
# Score:153428	Missing:4	'hkmz'	Duplicates:17	'udicosexprtaflyvn'		Client:1	"Judicious experts carefully observe vital taxpayer flows quietly expanding."
# Score:152944	Missing:4	'cgkq'	Duplicates:16	'brasfluteopnmvyi'		Client:1	"Brass, flutes, saxophones, trumpets weave joyful, vibrant, breezy melodies."
# ============================
# Score:180864	Missing:2	'kz'	Duplicates:14	'uerinatxoslwpd'		Client:1	"Queering vibrant axioms fetch low pipes, justly explode upwards."
# Score:153912	Missing:4	'bjkx'	Duplicates:18	'vastehiclpdornqufy'		Client:2	"Vast vehicles zipped corners vanquush effortlessly whenever qualitys managed!"
# Score:153428	Missing:4	'hkmz'	Duplicates:17	'udicosexprtaflyvn'		Client:1	"Judicious experts carefully observe vital taxpayer flows quietly expanding."
# ============================
# Score:180864	Missing:2	'kz'	Duplicates:14	'uerinatxoslwpd'		Client:1	"Queering vibrant axioms fetch low pipes, justly explode upwards."
# Score:166106	Missing:3	'bjm'	Duplicates:14	'ovenlascphgitr'		Client:1	"Woven landscapes challenge; quiet knights forge, valiantly explore Zenith."
# Score:153912	Missing:4	'bjkx'	Duplicates:18	'vastehiclpdornqufy'		Client:2	"Vast vehicles zipped corners vanquush effortlessly whenever qualitys managed!"
# ============================
# Score:180864	Missing:2	'kz'	Duplicates:14	'uerinatxoslwpd'		Client:1	"Queering vibrant axioms fetch low pipes, justly explode upwards."
# Score:166106	Missing:3	'bjm'	Duplicates:14	'ovenlascphgitr'		Client:1	"Woven landscapes challenge; quiet knights forge, valiantly explore Zenith."
# Score:166106	Missing:3	'bqx'	Duplicates:14	'ealthjprosingz'		Client:2	"Wealthy jade protects jovial knights from puzzling serpents glee."
# ============================
# Missing:1	'f'	Score:140700	Duplicates:18	'uiclytaposevdnzmhw'		Client:1	"Quickly juxtapose vivid enzymes, labeling shrewd plots with calm zest."
# Missing:2	'bw'	Score:46640	Duplicates:15	'uicoesmpvrladgn'		Client:1	"Quick foxes jump over lazy dogs, valuing historic American pride."
# Missing:2	'kz'	Score:180864	Duplicates:14	'uerinatxoslwpd'		Client:1	"Queering vibrant axioms fetch low pipes, justly explode upwards."
# ****************************
# Score:183168	Missing:2	'qx'	Duplicates:18	'ackgeorylwipsfthum'		Client:1	"Jack gazed over yellow brick papers, feeling thoughtfully optimistic tomorrow"
# Score:180864	Missing:2	'kz'	Duplicates:14	'uerinatxoslwpd'		Client:1	"Queering vibrant axioms fetch low pipes, justly explode upwards."
# Score:166106	Missing:3	'bjm'	Duplicates:14	'ovenlascphgitr'		Client:1	"Woven landscapes challenge; quiet knights forge, valiantly explore Zenith."
# ============================
# Score:183168	Missing:2	'qx'	Duplicates:18	'ackgeorylwipsfthum'		Client:1	"Jack gazed over yellow brick papers, feeling thoughtfully optimistic tomorrow"
# Score:180864	Missing:2	'kz'	Duplicates:14	'uerinatxoslwpd'		Client:1	"Queering vibrant axioms fetch low pipes, justly explode upwards."
# Score:180864	Missing:2	'kz'	Duplicates:14	'estournyaplivc'		Client:1	"Qwest journey amplies vast evolution xenographic protocols broadly refine."
# ============================
# Missing:1	'f'	Score:140700	Duplicates:18	'uiclytaposevdnzmhw'		Client:1	"Quickly juxtapose vivid enzymes, labeling shrewd plots with calm zest."
# Missing:1	'j'	Score:165900	Duplicates:16	'uiesploryantdwgh'		Client:1	"Quick Zeus explores buoyant meadows gathering playful wave shadows."
# Missing:2	'bw'	Score:46640	Duplicates:15	'uicoesmpvrladgn'		Client:1	"Quick foxes jump over lazy dogs, valuing historic American pride."
# ****************************
# Missing:1	'f'	Score:140700	Duplicates:18	'uiclytaposevdnzmhw'		Client:1	"Quickly juxtapose vivid enzymes, labeling shrewd plots with calm zest."
# Missing:1	'j'	Score:165900	Duplicates:16	'uiesploryantdwgh'		Client:1	"Quick Zeus explores buoyant meadows gathering playful wave shadows."
# Missing:1	'w'	Score:111775	Duplicates:13	'uifoespravlyn'		Client:1	"Quick foxes jump bravely over zealous plants, defying all hope."
# ****************************
# Missing:0	''	Score:177788	Duplicates:13	'enitqualmdrsg'		Client:1	"Zenith quail jumped, browsing xenial fields, actively seeking quiet dreams."
# Missing:1	'f'	Score:140700	Duplicates:18	'uiclytaposevdnzmhw'		Client:1	"Quickly juxtapose vivid enzymes, labeling shrewd plots with calm zest."
# Missing:1	'j'	Score:165900	Duplicates:16	'uiesploryantdwgh'		Client:1	"Quick Zeus explores buoyant meadows gathering playful wave shadows."
# ****************************
# Score:196875	Missing:1	'z'	Duplicates:15	'asuiphomerflnvt'		Client:1	"Jax's quipy homework baffled enemies, launching pivotal innovative results."
# Score:183168	Missing:2	'qx'	Duplicates:18	'ackgeorylwipsfthum'		Client:1	"Jack gazed over yellow brick papers, feeling thoughtfully optimistic tomorrow"
# Score:180864	Missing:2	'kz'	Duplicates:14	'uerinatxoslwpd'		Client:1	"Queering vibrant axioms fetch low pipes, justly explode upwards."
# ============================
# Missing:0	''	Score:177788	Duplicates:13	'enitqualmdrsg'		Client:1	"Zenith quail jumped, browsing xenial fields, actively seeking quiet dreams."
# Missing:0	''	Score:181440	Duplicates:15	'uilyepandbrtosf'		Client:1	"Quickly expand vibrant zones, transforming futures with joyful, bold steps."
# Missing:1	'f'	Score:140700	Duplicates:18	'uiclytaposevdnzmhw'		Client:1	"Quickly juxtapose vivid enzymes, labeling shrewd plots with calm zest."
# ****************************
# Score:196875	Missing:1	'z'	Duplicates:15	'asuiphomerflnvt'		Client:1	"Jax's quipy homework baffled enemies, launching pivotal innovative results."
# Score:183168	Missing:2	'qx'	Duplicates:18	'ackgeorylwipsfthum'		Client:1	"Jack gazed over yellow brick papers, feeling thoughtfully optimistic tomorrow"
# Score:181440	Missing:0	''	Duplicates:15	'uilyepandbrtosf'		Client:1	"Quickly expand vibrant zones, transforming futures with joyful, bold steps."
# ============================
# Missing:0	''	Score:177788	Duplicates:13	'enitqualmdrsg'		Client:1	"Zenith quail jumped, browsing xenial fields, actively seeking quiet dreams."
# Missing:0	''	Score:181440	Duplicates:15	'uilyepandbrtosf'		Client:1	"Quickly expand vibrant zones, transforming futures with joyful, bold steps."
# Missing:0	''	Score:152640	Duplicates:15	'quickealyprosdn'		Client:1	"Quick zeal quickly proves fair judgment beyond anxious whispers."
# ****************************
# Score:198750	Missing:1	'g'	Duplicates:18	'uizalebrsoyxpdwnth'		Client:1	"Quizzical zebras joyfully expressed awkwardness with perplexed, vibrant humor."
# Score:196875	Missing:1	'z'	Duplicates:15	'asuiphomerflnvt'		Client:1	"Jax's quipy homework baffled enemies, launching pivotal innovative results."
# Score:183168	Missing:2	'qx'	Duplicates:18	'ackgeorylwipsfthum'		Client:1	"Jack gazed over yellow brick papers, feeling thoughtfully optimistic tomorrow"
# ============================
# Score:213616	Missing:0	''	Duplicates:16	'acquietlypdsonrh'		Client:1	"Jack quietly mapped bison exploring zones frequently where teachers prevailed."
# Score:198750	Missing:1	'g'	Duplicates:18	'uizalebrsoyxpdwnth'		Client:1	"Quizzical zebras joyfully expressed awkwardness with perplexed, vibrant humor."
# Score:196875	Missing:1	'z'	Duplicates:15	'asuiphomerflnvt'		Client:1	"Jax's quipy homework baffled enemies, launching pivotal innovative results."
# ============================
# Score:213616	Missing:0	''	Duplicates:16	'acquietlypdsonrh'		Client:1	"Jack quietly mapped bison exploring zones frequently where teachers prevailed."
# Score:198750	Missing:1	'g'	Duplicates:18	'uizalebrsoyxpdwnth'		Client:1	"Quizzical zebras joyfully expressed awkwardness with perplexed, vibrant humor."
# Score:197500	Missing:1	'z'	Duplicates:16	'udgebyaintplorsh'		Client:1	"Judged by quaint explorers, brokers deftly plan vital growth schemes."
# ============================
# Score:214968	Missing:0	''	Duplicates:18	'uiotcplmsegrywhnba'		Client:1	"Quixotic plums jumped vigorously when breezy cats awoke brightly soon after"
# Score:213616	Missing:0	''	Duplicates:16	'acquietlypdsonrh'		Client:1	"Jack quietly mapped bison exploring zones frequently where teachers prevailed."
# Score:198750	Missing:1	'g'	Duplicates:18	'uizalebrsoyxpdwnth'		Client:1	"Quizzical zebras joyfully expressed awkwardness with perplexed, vibrant humor."
# ============================
# Calling it quits after 3600 seconds.
# Quitting client 1 url http://192.168.137.118:11434 model gemma3:12b i 1454 running: False
# Quitting client 3 url http://192.168.137.119:11434 model gemma3:4b i 995 running: False
# Quitting client 2 url http://192.168.137.117:11434 model gemma3:4b i 2170 running: False
#
#
# All threads have stopped.
# Missing:0	''	Score:177788	Duplicates:13	'enitqualmdrsg'		Client:1	"Zenith quail jumped, browsing xenial fields, actively seeking quiet dreams."
# Missing:0	''	Score:181440	Duplicates:15	'uilyepandbrtosf'		Client:1	"Quickly expand vibrant zones, transforming futures with joyful, bold steps."
# Missing:0	''	Score:152640	Duplicates:15	'quickealyprosdn'		Client:1	"Quick zeal quickly proves fair judgment beyond anxious whispers."
# Missing:0	''	Score:127092	Duplicates:17	'uickxesmpravlynwd'		Client:1	"Quick foxes jump bravely, vexing clumsy wizards with dark plans."
# Missing:0	''	Score:80088	Duplicates:13	'uicfoesvrathg'		Client:1	"Quick foxes jump over lazy software, having bright code."
# Missing:0	''	Score:19608	Duplicates:8	'uronpsel'		Client:3	"Quick brown fox jumps over the lazy nor plus dog."
# Missing:0	''	Score:150912	Duplicates:12	'uilyerotafsn'		Client:1	"Quickly Xerophyte, jam flavorful artisans zest by fluent design swiftly."
# Missing:0	''	Score:213616	Duplicates:16	'acquietlypdsonrh'		Client:1	"Jack quietly mapped bison exploring zones frequently where teachers prevailed."
# Missing:0	''	Score:181440	Duplicates:15	'uilyeanospthfgr'		Client:1	"Quickly examine zealous paths, safeguarding future hopes with vibrant joy."
# Missing:0	''	Score:182592	Duplicates:17	'uicaxflewthnoprms'		Client:1	"Quick Jax flew the zenith helicopter, promptly examining wondrous vibes often."
# Missing:0	''	Score:151488	Duplicates:13	'ealousvicrntg'		Client:2	"Zealous wolves quickly explore vibrant echoes, judging numerous gifts."
# Missing:0	''	Score:93888	Duplicates:13	'quilyeamnogth'		Client:1	"Quickly examine poems, judging quality with thoughtful, vibrant zeal."
# Missing:0	''	Score:72312	Duplicates:12	'uioesvrlwngt'		Client:1	"Quick foxes jump over lazy brown vines during twilight."
# Missing:0	''	Score:152640	Duplicates:15	'uiclexamngospwt'		Client:1	"Quickly examine jagged boxes, proving flaws with zealous complaints."
# Missing:0	''	Score:182592	Duplicates:17	'uartmpsbconefigly'		Client:1	"Quartz jumps back onward before fixing the strange problem, very clearly"
# Missing:0	''	Score:46288	Duplicates:13	'uicbroesmpvla'		Client:3	"Quick brown foxes jump over lazy dogs, but schemes prevail."
# Missing:0	''	Score:182016	Duplicates:16	'braveiuclydthosp'		Client:1	"Brave Xavier quickly judged birthday chief with zealous, plump honors."
# Missing:0	''	Score:145340	Duplicates:15	'aswitlyuknvoceh'		Client:1	"Jax swiftly quaking voids cleverly bounce with phantom tunes zealots know."
# Missing:0	''	Score:126140	Duplicates:15	'ealousicmpyrngh'		Client:1	"Zealous quick foxes jump wildly, proving charmingly humble notions."
# Missing:0	''	Score:46464	Duplicates:14	'uifoespvrlndgh'		Client:1	"Quick foxes jump over lazy brown dogs, providing fourth help."
# Missing:0	''	Score:124236	Duplicates:11	'estyviranul'		Client:3	""Zesty, vibrant foxes jump quickly, never hiding, always true.""
# Missing:0	''	Score:123264	Duplicates:14	'ewiclymandzosp'		Client:1	"Few quickly imagined jazz blossoms proved wholly exceptional anew."
# Missing:0	''	Score:214968	Duplicates:18	'uiotcplmsegrywhnba'		Client:1	"Quixotic plums jumped vigorously when breezy cats awoke brightly soon after"
# Missing:0	''	Score:179140	Duplicates:15	'uartlosedginhwy'		Client:1	"Quartz blooms reflect judging hawks, weaving xylography endlessly."
# Missing:0	''	Score:181440	Duplicates:15	'uiclyedwsapfrnt'		Client:1	"Quickly vexed jewels amplify bronze wrap perfectly during shifts."
# Missing:0	''	Score:180864	Duplicates:14	'icoalerfsmptng'		Client:1	"Quick jovial zebra faxes home promptly, alerting staff concerning wrongdoings."
# Missing:1	'f'	Score:140700	Duplicates:18	'uiclytaposevdnzmhw'		Client:1	"Quickly juxtapose vivid enzymes, labeling shrewd plots with calm zest."
# Missing:1	'j'	Score:165900	Duplicates:16	'uiesploryantdwgh'		Client:1	"Quick Zeus explores buoyant meadows gathering playful wave shadows."
# Missing:1	'w'	Score:111775	Duplicates:13	'uifoespravlyn'		Client:1	"Quick foxes jump bravely over zealous plants, defying all hope."
# Missing:1	'q'	Score:165625	Duplicates:15	'kevinsxbratowhl'		Client:1	"Kevin's exuberant jam provoked wrath, hitting boxers fiercely now, zeal.\\"
# Missing:1	'h'	Score:165375	Duplicates:15	'venturiclypgosz'		Client:3	"Venture quickly, Xavier, jumping over bridges, following cryptic puzzles."
# Missing:1	'z'	Score:164375	Duplicates:13	'eyingoplxstaw'		Client:1	"Querying complex boxes: envision deft hawks jolting patiently west."
# Missing:1	'f'	Score:137550	Duplicates:12	'quinteaslwro'		Client:1	"Quintex jabs quickly thwart gold zones; renew ample vision."
# Missing:1	'f'	Score:111775	Duplicates:13	'andusibrtecyp'		Client:3	""Xanadus vibrant zebra quickly jumps, etching cryptic words.""
# Missing:1	'v'	Score:139650	Duplicates:16	'iklyogeaprdhmftn'		Client:1	"Quickly joggle a zippered khaki emblem softly, now expand there freely."
# Missing:1	'k'	Score:165000	Duplicates:14	'uartzgsofenmil'		Client:1	"Quartz jugs often move, exhibiting inward zealous promise carefully."
# Missing:1	'b'	Score:166425	Duplicates:17	'uicadevorpzlshngt'		Client:1	"Quick, Jax devoured puzzles showcasing every thrilling future triumph."
# Missing:1	'z'	Score:196875	Duplicates:15	'asuiphomerflnvt'		Client:1	"Jax's quipy homework baffled enemies, launching pivotal innovative results."
# Missing:1	'x'	Score:112350	Duplicates:14	'ephanquilyovgt'		Client:1	"Zephan quickly moved away jogging playfully beneath quaint hilltop groves."
# Missing:1	'g'	Score:198750	Duplicates:18	'uizalebrsoyxpdwnth'		Client:1	"Quizzical zebras joyfully expressed awkwardness with perplexed, vibrant humor."
# Missing:1	'w'	Score:164850	Duplicates:14	'uigaelonsptbmr'		Client:1	"Quick gazelle joins photo albums, expertly framing vibrant design."
# Missing:1	'w'	Score:165900	Duplicates:16	'uiepyrsabovxtlnd'		Client:1	"Quick zephyrs jump above prior boxes expertly, finding valuable data."
# Missing:1	'q'	Score:132500	Duplicates:12	'wenouryalsdv'		Client:2	"When journey zealously expands wisdom, uncover every fabulous greatness' key."
# Missing:1	'k'	Score:167500	Duplicates:18	'uartewlsmiybnchodg'		Client:1	"Quartz jewels exemplify vibrant character, boldly showcasing tremendous design."
# Missing:1	'g'	Score:133875	Duplicates:15	'ipyenohuklstwar'		Client:2	"Zippy xenophon quickly jumps toward silent hopes every week alone first boy?."
# Missing:1	'v'	Score:111775	Duplicates:13	'uiespgarnwhlz'		Client:1	"Quick foxes jump, guaranteeing snaps, while blazing zephyrs wander."
# Missing:1	'j'	Score:138600	Duplicates:14	'uikealosdgrntb'		Client:1	"Quick zealous hawks avoid daily germs, fixing stubborn plots."
# Missing:1	'w'	Score:113050	Duplicates:16	'quicmsetlovrafnz'		Client:1	"Quick jumps excite lovely dreams; faith reveals fortunate, baffling quizzes."
# Missing:1	'z'	Score:137550	Duplicates:12	'rapidntsuewv'		Client:1	"Rapid fonts jump between quickly, weaving varied, expressive shapes."
# Missing:1	'h'	Score:86450	Duplicates:16	'uickronmpsfteazg'		Client:1	"Quick brown jumps often fix dazzling systems, improving core tasks."
# -----------------------------
# Score:214968	Missing:0	''	Duplicates:18	'uiotcplmsegrywhnba'		Client:1	"Quixotic plums jumped vigorously when breezy cats awoke brightly soon after"
# Score:213616	Missing:0	''	Duplicates:16	'acquietlypdsonrh'		Client:1	"Jack quietly mapped bison exploring zones frequently where teachers prevailed."
# Score:198750	Missing:1	'g'	Duplicates:18	'uizalebrsoyxpdwnth'		Client:1	"Quizzical zebras joyfully expressed awkwardness with perplexed, vibrant humor."
# Score:198750	Missing:1	'j'	Duplicates:18	'uietzbraslympngokh'		Client:1	"Quiet zebras bravely exemplify amazing leaps, unlocking wondrous mirky heights."
# Score:197500	Missing:1	'z'	Duplicates:16	'udgebyaintplorsh'		Client:1	"Judged by quaint explorers, brokers deftly plan vital growth schemes."
# Score:197500	Missing:1	'x'	Duplicates:16	'acgehpyuitonswlr'		Client:1	"Jack gave happy, quiet zones showing whimsical beauty afterward always?"
# Score:197500	Missing:1	'k'	Duplicates:16	'uiotebraflpmngsh'		Client:1	"Quixotic zebra flipped, jamming yellow fingers through vibrant hues."
# Score:197500	Missing:1	'q'	Duplicates:16	'zomiesrckxngatpl'		Client:2	"Zombies wrecked xenon zigzag jackets often shatter complex privacy rules."
# Score:196875	Missing:1	'z'	Duplicates:15	'asuiphomerflnvt'		Client:1	"Jax's quipy homework baffled enemies, launching pivotal innovative results."
# Score:196875	Missing:1	'k'	Duplicates:15	'uniperbalycsdtg'		Client:1	"Juniper bravely cleansed xeris at quartz while imagining peaceful bliss today!"
# Score:196875	Missing:1	'j'	Duplicates:15	'ebrasutionplkvy'		Client:1	"Zebras questioned purple hawks observing slimy knit factories bravely exist."
# Score:196875	Missing:1	'b'	Duplicates:15	'otmyhialsepngrd'		Client:1	"Jot mythical hawks; zepple vanquishes grim dragons, eternally fixed."
# Score:196875	Missing:1	'k'	Duplicates:15	'uiteaflngvrspod'		Client:1	"Quite baffling, Xavier's jumpy waltz echoes, proving average indeed."
# Score:196250	Missing:1	'k'	Duplicates:14	'quartvilyepnso'		Client:1	"Quartz vividly explains primary colors, subtly weaving unique, joyful hues."
# Score:195625	Missing:1	'j'	Duplicates:13	'astleingmproh'		Client:1	"Vastly exciting gems prompted a queer blitz from shining hawks."
# Score:195625	Missing:1	'k'	Duplicates:13	'uartelspiyvno'		Client:1	"Quartz jewels exemplify vibrant distinction, proving versions truly shine."
# Score:195625	Missing:1	'h'	Duplicates:13	'reablyoipntsd'		Client:1	"Remarkably jovial pixie quaint, captains wizard plans boldly ignite fear .</"
# Score:183168	Missing:2	'qx'	Duplicates:18	'ackgeorylwipsfthum'		Client:1	"Jack gazed over yellow brick papers, feeling thoughtfully optimistic tomorrow"
# Score:183168	Missing:2	'jk'	Duplicates:18	'vanuishgrmeltcpydf'		Client:1	"Vanquish grammar zeal with vibrant clauses perplexing scholarly drafts deftly. ."
# Score:183168	Missing:2	'fk'	Duplicates:18	'xenopsuitlyahzbrgd'		Client:2	"Xenops quietly watch zebras jumping next behind university grounds zealously."
# Score:183168	Missing:2	'xz'	Duplicates:18	'jacklopesfrumwidnt'		Client:2	"Jackalopes fro brook frogs jump wildly via quantum ethics nine too swift indeed!"
# Score:182592	Missing:2	'km'	Duplicates:17	'uezjaoldywisprfnt'		Client:1	"Queez Jax boldly whispers fantastic prize won during joyful ventures, oddly so"
# Score:182592	Missing:0	''	Duplicates:17	'uicaxflewthnoprms'		Client:1	"Quick Jax flew the zenith helicopter, promptly examining wondrous vibes often."
# Score:182592	Missing:2	'cv'	Duplicates:17	'aziltsbrodyempfng'		Client:1	"Jazz quilts broadly exemplify profitably shrewd marketing gains."
# Score:182592	Missing:0	''	Duplicates:17	'uartmpsbconefigly'		Client:1	"Quartz jumps back onward before fixing the strange problem, very clearly"
# Score:182592	Missing:2	'kx'	Duplicates:17	'uartbloswevphdign'		Client:1	"Quartz blooms weave joyful paths, designing landscapes with vibrant hues."
# Score:182592	Missing:2	'kz'	Duplicates:17	'eactlosrvingupdmf'		Client:1	"Exactly observing quiet justice proves wisdom, favoring hopeful minds."
# Score:182592	Missing:2	'gv'	Duplicates:17	'frequntlypasoikwc'		Client:1	"Frequently players joy and quirk xenial breezes awaken powerful charms typically"
# Score:182592	Missing:2	'ck'	Duplicates:17	'oyfulvienbraqtsmp'		Client:1	"Joyfully viewing zebra Xavi frequently orbits quantum realms daily perhaps."
# Score:182592	Missing:2	'qz'	Duplicates:17	'avierpodugmntsfly'		Client:1	"Xavier proved judgments frankly embody courage whispering softly inside soon."
# Score:182592	Missing:2	'cz'	Duplicates:17	'uirkydavesplongth'		Client:1	"Quirky dwarves explore fading mythologies beneath juniper groves keenly."
# Score:182016	Missing:2	'vx'	Duplicates:16	'uaersctilyhogbfp'		Client:1	"Quakers educate wisely through belief impacting joyful public zeal hopefully ."
# Score:182016	Missing:2	'fk'	Duplicates:16	'quartelspndichog'		Client:1	"Quartz jewels expand, vibrantly echoing through dim, quiet spaces."
# Score:182016	Missing:2	'fj'	Duplicates:16	'inlyehtprmauogsw'		Client:1	"Kindly exhibit permit zeal autographs, viewing promptly with quiet consent."
# Score:182016	Missing:2	'bv'	Duplicates:16	'udgeinflowsrypta'		Client:1	"Judgemind flows quirkly; expect wilder laughs for playful zones lately.!"
# Score:182016	Missing:0	''	Duplicates:16	'braveiuclydthosp'		Client:1	"Brave Xavier quickly judged birthday chief with zealous, plump honors."
# Score:182016	Missing:2	'cz'	Duplicates:16	'uirylophneamtsfg'		Client:1	"Quirky xylophone jam tastes superb while flavorful dumplings please gently."
# Score:182016	Missing:2	'bc'	Duplicates:16	'uartzlyedspnfoiv'		Client:1	"Quartzly weekdays expand zestfully, joining helpful informative novels."
# Score:181440	Missing:0	''	Duplicates:15	'uilyepandbrtosf'		Client:1	"Quickly expand vibrant zones, transforming futures with joyful, bold steps."
# Score:181440	Missing:2	'jk'	Duplicates:15	'uiteaflngosprch'		Client:1	"Quite baffling zooms perplexed prospects envision future highway access."
# Score:181440	Missing:2	'qv'	Duplicates:15	'azeroyflinsptwh'		Client:1	"A zebra joyfully examines pancake zest with whipped fragrant oats."
# Score:181440	Missing:2	'fk'	Duplicates:15	'uartnglesypobid'		Client:1	"Quartz jungles weave strangely past; xenophobic trials bloom suddenly."
# Score:181440	Missing:0	''	Duplicates:15	'uilyeanospthfgr'		Client:1	"Quickly examine zealous paths, safeguarding future hopes with vibrant joy."
# Score:181440	Missing:2	'jk'	Duplicates:15	'artfinclsyexpom'		Client:1	"Quartz financials visibly exceed practical axioms of company growth."
# Score:181440	Missing:2	'kz'	Duplicates:15	'oyulaintwsepmbr'		Client:1	"Joyful quaint vows excite planned ambitions, warmly bring hope."
# Score:181440	Missing:2	'cm'	Duplicates:15	'inlyaowequtsprv'		Client:1	"Kindly allow equitable zones, perhaps viewing Xavier's joyful quests."
# Score:181440	Missing:2	'gw'	Duplicates:15	'uartzeboylpsdic'		Client:1	"Quartz zebra joyfully exposed remarkable villains practically shattered doubts."
# Score:181440	Missing:2	'cv'	Duplicates:15	'uartpesniolfwdh'		Client:1	"Quartz jumpers anxiously broke, erasing flawed plans with newfound hope."
# Score:181440	Missing:2	'cj'	Duplicates:15	'briefwaplugsthy'		Client:1	"Brief wax plumage zest defines twelve hawks globally quite sharply"
# Score:181440	Missing:2	'km'	Duplicates:15	'xavierustlypdzn'		Client:1	"Xavier justly flipped, perplexed while quizzing observant talents cleverly."
# ============================
