# %%
DEBUG = False

# Word file assists with the randomness of the prompt
with open("words", 'r') as file:
        lines_array = [line.strip() for line in file.readlines()]
        if(DEBUG):
                print(f"{len(lines_array)} words in list")

# %%
from ollama import Client
from ollama import generate
import random

def generate_prompt():
    word1 = lines_array[random.randint(0, len(lines_array))]
    word2 = lines_array[random.randint(0, len(lines_array))]
    prompt = f"The theme is '{word1} {word2}'."
    if(DEBUG):
        print(f"{prompt}")
    # print(f"{word1}:{word2}")
    return prompt

def generate_response(client, model):
    prompt = generate_prompt()
    seed = int(random.random()*1000)
    system_prompt = "Write a single sentence with between 8 and 10 words. Only output the sentence generated without preamble. The goal is to use all the letters of the alphabet."
    options = {
        "seed": seed, 
        "temperature": seed/100.0,
        "num_predict": 400

    }
    response = client.generate(
        model = model,
        prompt = f"{system_prompt} {prompt}",
        # system = system_prompt,
        options=options,
        stream = False
    )
    reply = response['response']
    if(DEBUG):
        print(f"r:{reply}")
    return reply

# %%
class Sentence:
    boring_words = ["quick", "brown", "fox", "jumps", "dog", "lazy"]
    def __init__(self, text, client):
        """
        Args:
            text (str): The text of the sentence.  Must be a string.
        
        Raises:
            TypeError: if input is not a string
        """
        if not isinstance(text, str):
            raise TypeError("Input must be a string.")

        if len(text) > 80:
            if(DEBUG):
                print(f"long text rejected: {text}")
            raise TypeError("No paragraphs.")
        
        self._text = text.encode("ascii", errors="ignore").decode()  # Use a protected attribute for encapsulation
        self._words = len(text.split(" "))
        self._missing = self.find_missing_letters()
        self._duplicates = self.find_duplicate_letters()
        self._duplength = len(self._duplicates)
        self._dupkeys = "".join(self._duplicates.keys())
        self._client = client

    def get_text(self):
        """
        Returns the text of the sentence.

        Returns:
            str: The sentence text.
        """
        return self._text

    def get_client(self):
        return self._client
    
    def get_missing(self):
        return self._missing
    
    def get_missing_count(self):
        return len(self.get_missing())
      
    def get_duplicates(self):
        return self._duplicates
    
    def get_duplength(self):
        return self._duplength
    
    def get_dupkeys(self):
        return self._dupkeys
    
    def get_score(self):
        missing_score = (26 - self.get_missing_count())**2 if self.get_missing_count() < 3 else 1
        duplicate_score = self.get_duplength()
        for boring_word in self.boring_words:
            if(boring_word in self.get_text().lower()):
                if(DEBUG):
                    print(f"Lowering score for {boring_word}")
                missing_score = missing_score - 100
        return missing_score * duplicate_score

    
    def find_missing_letters(self):
        """
        Checks a string for the presence of all lowercase letters and identifies missing ones.

        Returns:
            A string containing the missing letters, or an empty string if all letters are present.
            Returns None if the input is not a string.
        """

        alphabet = "abcdefghijklmnopqrstuvwxyz"
        missing_letters = ""
        
        # Convert the input string to lowercase for case-insensitive comparison
        input_string = self._text.lower()

        for letter in alphabet:
            if letter not in input_string:
                missing_letters += letter

        return missing_letters

    def find_duplicate_letters(self):
        """
        Identifies duplicate letters in a string and counts their occurrences.

        Returns:
            A dictionary where keys are the duplicate letters and values are their counts.
            Returns an empty dictionary if there are no duplicates.
            Returns None if the input is not a string.
        """

        letter_counts = {}
        duplicate_counts = {}

        input_string = self._text.lower()  # Case-insensitive counting

        for letter in input_string:
            if 'a' <= letter <= 'z':  # Only consider letters
                if letter in letter_counts:
                    letter_counts[letter] += 1
                else:
                    letter_counts[letter] = 1

        # Identify duplicates and create a new dictionary
        for letter, count in letter_counts.items():
            if count > 1:
                duplicate_counts[letter] = count

        return duplicate_counts

class Winners:
    def __init__(self):
        self._sentences = []

    def add(self, sentence):
        self._sentences.append(sentence)
        if(DEBUG):
            print(f"There are {len(self._sentences)} sentences in the list.")

    def get_missing_winners(self, _count):
        sorted_winners = sorted(self._sentences, key=lambda item: item.get_missing_count())
        return sorted_winners[:_count]
    
    def get_duplicate_winners(self, _count):
        sorted_winners = sorted(self._sentences, key=lambda item: item.get_score())
        return sorted_winners[len(sorted_winners)-_count:]

    def length(self):
        return len(self._sentences)

# Test cases. Add to this list when you find good terms.
the_sentences = [
    "The quick brown fox jumps over the lazy dog.",
    "Golden sunlight danced upon the rippling, turquoise ocean waves.",
    "Old photographs revealed stories of laughter, love, and bygone days.",
    "The majestic mountains stood silently guarding the peaceful valley below.",
    "She expertly crafted intricate jewelry using shimmering silver and gold. The majestic mountains stood silently guarding the peaceful valley below.",
    "Dark storm clouds gathered quickly, threatening a powerful summer rain.",
    "Street food tasted wonderfully fresh.",
    "Remote islands felt truly peaceful.",
    "The axel, quickly! Jumping fences with brave, zealous strides.",
    "The teen quickly jammed, exploring vibrant chords with joyful zest."
]

winners = Winners()
for sentence in the_sentences:
    try:
        winners.add(Sentence(sentence, 0))
        
    except Exception as e:
        print(e)


missing_winners = winners.get_missing_winners(5)
for winner in missing_winners:
    print(f"missing {winner.get_missing_count()} {winner.get_text()} '{winner.get_missing()}' duplicates: {winner.get_duplength()} '{winner.get_dupkeys()}' client: {winner.get_client()}")

print("****************************")
duplicate_winners = winners.get_duplicate_winners(5)
for winner in duplicate_winners:
    print(f"duplicates: {winner.get_duplength()} {winner.get_text()} '{winner.get_dupkeys()}' missing {winner.get_missing_count()} '{winner.get_missing()}' client: {winner.get_client()}")
# Out:
# No paragraphs.
# missing 0 The quick brown fox jumps over the lazy dog. '' duplicates: 6 'theuro' client: 0
# missing 0 The axel, quickly! Jumping fences with brave, zealous strides. '' duplicates: 11 'thealuicnsr' client: 0
# missing 0 The teen quickly jammed, exploring vibrant chords with joyful zest. '' duplicates: 16 'thenuiclyjamdors' client: 0
# missing 4 The majestic mountains stood silently guarding the peaceful valley below. 'kqxz' duplicates: 15 'themasicoundlyg' client: 0
# missing 5 Dark storm clouds gathered quickly, threatening a powerful summer rain. 'bjvxz' duplicates: 16 'darkstomclughein' client: 0
# ****************************
# duplicates: 15 Golden sunlight danced upon the rippling, turquoise ocean waves. 'goldensuihtacpr' missing 8 'bfjkmxyz' client: 0
# duplicates: 15 The majestic mountains stood silently guarding the peaceful valley below. 'themasicoundlyg' missing 4 'kqxz' client: 0
# duplicates: 6 The quick brown fox jumps over the lazy dog. 'theuro' missing 0 '' client: 0
# duplicates: 11 The axel, quickly! Jumping fences with brave, zealous strides. 'thealuicnsr' missing 0 '' client: 0
# duplicates: 16 The teen quickly jammed, exploring vibrant chords with joyful zest. 'thenuiclyjamdors' missing 0 '' client: 0

# %%
import threading
import time

timeout = 60*30 #7*60*60 #30*30 #1*60*60 #2*60*60 #7*60*60
winning_sentences = Winners()
running = True
previous_missing = [] # Keep track of high winners so we can display it when it changes.
DEBUG = False

def worker(client_id, url, model):
    """
     a client processing a task.
    
    Args:
        client_id: Unique identifier for the client.
        url: The URL associated with the client's task.
        model: the model to use for this client.
    """
    client = Client(host=url)
    i = 0
    while True:
        global running
        global winning_sentences
        global previous_missing
        i = i + 1
        if(running != True):
           # Exiting
           print(f"Quitting client {client_id} url {url} model {model} i {i} running: {running}")
           return
        try:
            if(DEBUG):
                print(f"client {client_id} url {url} model {model} i {i} running: {running}")

            sentence = Sentence(generate_response(client, model).strip().replace("\n", " "), client_id)
            if(DEBUG):
                print(sentence.get_text())

            winning_sentences.add(sentence)

            missing_winners = winning_sentences.get_duplicate_winners(5)
            if(missing_winners != previous_missing):
                previous_missing = missing_winners
                for winner in missing_winners:
                    print(f"missing {winner.get_missing_count()} {winner.get_text()} '{winner.get_missing()}' duplicates: {winner.get_duplength()} '{winner.get_dupkeys()}' client {winner.get_client()} score: {winner.get_score()}")
                print("****************************\n")
            # 3 Seconds of cool down for the LLM. This actually saves time in the forever loop.
            time.sleep(3)

        except Exception as e:
            dummy = 1 # Ignore all exceptions. Set dummy so linter doesn't complain.
            if(DEBUG):
                print(f"client {client_id} url {url} {e}")
        

def main():
    """
    Creates and starts multiple client threads.
    """

    clients = [
        {"id": 1, "url": "http://192.168.137.118:11434", "model": "gemma3:12b"},
        {"id": 2, "url": "http://192.168.137.117:11434", "model": "gemma3:4b"},
        {"id": 3, "url": "http://192.168.137.119:11434", "model": "gemma3:4b"},
    ]

    global running
    running = True
    threads = []
    for client in clients:
        thread = threading.Thread(target=worker, args=(client["id"], client["url"], client["model"]))
        threads.append(thread)
        thread.start()

    try:
        time.sleep(timeout)
        # Time's up. Tell threads to wrap it up. There may be a significant delay because the client might still be processing.
        running = False
        print(f"Calling it quits after {timeout} seconds.")
        
        # Wait for all threads to finish
        for thread in threads:
            thread.join(timeout=30)

        print("\n\nAll threads have stopped.")
        missing_winners = winning_sentences.get_missing_winners(50)
        
        # Word file assists with the randomness of the prompt
        with open("winners", 'a') as file:
            for winner in missing_winners:
                message = f"missing {winner.get_missing_count()} {winner.get_text()} '{winner.get_missing()}' duplicates: {winner.get_duplength()} '{winner.get_dupkeys()}' client {winner.get_client()} score: {winner.get_score()}"
                print(message)
                print(message, file=file)

            print("-----------------------------")
            duplicate_winners = winning_sentences.get_duplicate_winners(50)
            for winner in duplicate_winners:
                message = f"duplicates: {winner.get_duplength()} {winner.get_text()} '{winner.get_dupkeys()}' missing {winner.get_missing_count()} '{winner.get_missing()}' client {winner.get_client()} score: {winner.get_score()}"
                print(message)
                print(message, file=file)

            file.close()
            print("============================\n\n")

    
       
    except KeyboardInterrupt:
        print("Stopping threads due to KeyboardInterrupt...")
        running = False
        for thread in threads:
            thread.join()
        print("All threads stopped after KeyboardInterrupt")

if __name__ == "__main__":
    main()
# Out:
# missing 8 Whereas glad xylophones zigzayed wildly each zooying zebra. 'fjkmqtuv' duplicates: 14 'wherasgldyonzi' client 3 score: 14
# ****************************
#
# missing 8 Whereas glad xylophones zigzayed wildly each zooying zebra. 'fjkmqtuv' duplicates: 14 'wherasgldyonzi' client 3 score: 14
# missing 2 Quiz brought every joyful keyword, framing historic values. 'px' duplicates: 14 'uiroghtevyflas' client 1 score: 8064
# ****************************
#
# missing 3 Observe exotic xylographs, just beyond my fragile yet potent, unique orbit! 'kwz' duplicates: 15 'obserxtiylgapun' client 2 score: 15
# missing 2 Quiz brought every joyful keyword, framing historic values. 'px' duplicates: 14 'uiroghtevyflas' client 1 score: 8064
# ****************************
#
# missing 2 Quiz brought every joyful keyword, framing historic values. 'px' duplicates: 14 'uiroghtevyflas' client 1 score: 8064
# ****************************
#
# missing 8 Whereas glad xylophones zigzayed wildly each zooying zebra. 'fjkmqtuv' duplicates: 14 'wherasgldyonzi' client 3 score: 14
# missing 8 I justly need my unique, zealous, phantom, xylophone, zest. 'bcfgkrvw' duplicates: 14 'iustlynemzaoph' client 3 score: 14
# missing 3 Observe exotic xylographs, just beyond my fragile yet potent, unique orbit! 'kwz' duplicates: 15 'obserxtiylgapun' client 2 score: 15
# missing 0 Jazzy sphinx quickly vowed, "Bring ample fun, participate!" '' duplicates: 12 'azypinuclert' client 1 score: 6912
# missing 2 Quiz brought every joyful keyword, framing historic values. 'px' duplicates: 14 'uiroghtevyflas' client 1 score: 8064
# ****************************
#
# missing 8 I justly need my unique, zealous, phantom, xylophone, zest. 'bcfgkrvw' duplicates: 14 'iustlynemzaoph' client 3 score: 14
# missing 3 Observe exotic xylographs, just beyond my fragile yet potent, unique orbit! 'kwz' duplicates: 15 'obserxtiylgapun' client 2 score: 15
# missing 6 Zinc axes blaze fiercely, xylophone sharp knives lacerating his aching chest. 'djmquw' duplicates: 16 'zincaxeslryophtg' client 2 score: 16
# missing 0 Jazzy sphinx quickly vowed, "Bring ample fun, participate!" '' duplicates: 12 'azypinuclert' client 1 score: 6912
# missing 2 Quiz brought every joyful keyword, framing historic values. 'px' duplicates: 14 'uiroghtevyflas' client 1 score: 8064
# ****************************
#
# missing 3 Observe exotic xylographs, just beyond my fragile yet potent, unique orbit! 'kwz' duplicates: 15 'obserxtiylgapun' client 2 score: 15
# missing 6 Azure, bronze, crimson, emerald, fuchsia, gold, indigo, jade, kelp, orchid. 'qtvwxy' duplicates: 15 'azureoncimsldhg' client 2 score: 15
# missing 6 Zinc axes blaze fiercely, xylophone sharp knives lacerating his aching chest. 'djmquw' duplicates: 16 'zincaxeslryophtg' client 2 score: 16
# missing 0 Jazzy sphinx quickly vowed, "Bring ample fun, participate!" '' duplicates: 12 'azypinuclert' client 1 score: 6912
# missing 2 Quiz brought every joyful keyword, framing historic values. 'px' duplicates: 14 'uiroghtevyflas' client 1 score: 8064
# ****************************
#
# missing 6 Azure, bronze, crimson, emerald, fuchsia, gold, indigo, jade, kelp, orchid. 'qtvwxy' duplicates: 15 'azureoncimsldhg' client 2 score: 15
# missing 6 Zinc axes blaze fiercely, xylophone sharp knives lacerating his aching chest. 'djmquw' duplicates: 16 'zincaxeslryophtg' client 2 score: 16
# missing 0 Jazzy sphinx quickly vowed, "Bring ample fun, participate!" '' duplicates: 12 'azypinuclert' client 1 score: 6912
# missing 2 Quiz brought every joyful keyword, framing historic values. 'px' duplicates: 14 'uiroghtevyflas' client 1 score: 8064
# missing 1 Bright hawk jams quiet fences byzed profound trulyx zooed 'v' duplicates: 15 'brihtasuefnyzdo' client 1 score: 9375
# ****************************
#
# missing 6 Zinc axes blaze fiercely, xylophone sharp knives lacerating his aching chest. 'djmquw' duplicates: 16 'zincaxeslryophtg' client 2 score: 16
# missing 3 Few joy wept xylobolt quirks gazed patiently throughout zealous dawn. 'cmv' duplicates: 17 'ewoyptluirsgazdnh' client 1 score: 17
# missing 0 Jazzy sphinx quickly vowed, "Bring ample fun, participate!" '' duplicates: 12 'azypinuclert' client 1 score: 6912
# missing 2 Quiz brought every joyful keyword, framing historic values. 'px' duplicates: 14 'uiroghtevyflas' client 1 score: 8064
# missing 1 Bright hawk jams quiet fences byzed profound trulyx zooed 'v' duplicates: 15 'brihtasuefnyzdo' client 1 score: 9375
# ****************************
#
# missing 3 Few joy wept xylobolt quirks gazed patiently throughout zealous dawn. 'cmv' duplicates: 17 'ewoyptluirsgazdnh' client 1 score: 17
# missing 0 Jazzy sphinx quickly vowed, "Bring ample fun, participate!" '' duplicates: 12 'azypinuclert' client 1 score: 6912
# missing 2 Quiz brought every joyful keyword, framing historic values. 'px' duplicates: 14 'uiroghtevyflas' client 1 score: 8064
# missing 1 Bright hawk jams quiet fences byzed profound trulyx zooed 'v' duplicates: 15 'brihtasuefnyzdo' client 1 score: 9375
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# ****************************
#
# missing 0 Jazzy sphinx quickly vowed, "Bring ample fun, participate!" '' duplicates: 12 'azypinuclert' client 1 score: 6912
# missing 2 Quiz brought every joyful keyword, framing historic values. 'px' duplicates: 14 'uiroghtevyflas' client 1 score: 8064
# missing 2 Quartz box jumps fixed elegantly worthy dense photographs crumbled slowly. 'kv' duplicates: 18 'uartboxmpsedlgnywh' client 1 score: 8568
# missing 1 Bright hawk jams quiet fences byzed profound trulyx zooed 'v' duplicates: 15 'brihtasuefnyzdo' client 1 score: 9375
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# ****************************
#
# missing 1 Jax quickly brought every film, urged zealous poets adapting residents. 'w' duplicates: 14 'auilyrogtedspn' client 1 score: 7350
# missing 2 Quiz brought every joyful keyword, framing historic values. 'px' duplicates: 14 'uiroghtevyflas' client 1 score: 8064
# missing 2 Quartz box jumps fixed elegantly worthy dense photographs crumbled slowly. 'kv' duplicates: 18 'uartboxmpsedlgnywh' client 1 score: 8568
# missing 1 Bright hawk jams quiet fences byzed profound trulyx zooed 'v' duplicates: 15 'brihtasuefnyzdo' client 1 score: 9375
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# ****************************
#
# missing 2 Quiz brought every joyful keyword, framing historic values. 'px' duplicates: 14 'uiroghtevyflas' client 1 score: 8064
# missing 2 Quartz box jumps fixed elegantly worthy dense photographs crumbled slowly. 'kv' duplicates: 18 'uartboxmpsedlgnywh' client 1 score: 8568
# missing 1 Bright hawk jams quiet fences byzed profound trulyx zooed 'v' duplicates: 15 'brihtasuefnyzdo' client 1 score: 9375
# missing 2 Zipped bolts box jig waltz xylophone quirky zithers boom floats now zig. 'cv' duplicates: 17 'zipeboltsxgwayhnr' client 2 score: 9792
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# ****************************
#
# missing 2 Quartz box jumps fixed elegantly worthy dense photographs crumbled slowly. 'kv' duplicates: 18 'uartboxmpsedlgnywh' client 1 score: 8568
# missing 1 Bright hawk jams quiet fences byzed profound trulyx zooed 'v' duplicates: 15 'brihtasuefnyzdo' client 1 score: 9375
# missing 2 Zipped bolts box jig waltz xylophone quirky zithers boom floats now zig. 'cv' duplicates: 17 'zipeboltsxgwayhnr' client 2 score: 9792
# missing 2 Zoos exemplified what boxed nymphs frantically journey quickly, always breezy.** 'gv' duplicates: 21 'zosexmplifdwhatbnyrcu' client 1 score: 9996
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# ****************************
#
# missing 1 Quick fuzzy dwarves exchanged jets blaming vibrant communication variables. 'p' duplicates: 17 'uiczdarvesngtblmo' client 1 score: 8925
# missing 1 Bright hawk jams quiet fences byzed profound trulyx zooed 'v' duplicates: 15 'brihtasuefnyzdo' client 1 score: 9375
# missing 2 Zipped bolts box jig waltz xylophone quirky zithers boom floats now zig. 'cv' duplicates: 17 'zipeboltsxgwayhnr' client 2 score: 9792
# missing 2 Zoos exemplified what boxed nymphs frantically journey quickly, always breezy.** 'gv' duplicates: 21 'zosexmplifdwhatbnyrcu' client 1 score: 9996
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# ****************************
#
# missing 1 Bright hawk jams quiet fences byzed profound trulyx zooed 'v' duplicates: 15 'brihtasuefnyzdo' client 1 score: 9375
# missing 2 Zipped bolts box jig waltz xylophone quirky zithers boom floats now zig. 'cv' duplicates: 17 'zipeboltsxgwayhnr' client 2 score: 9792
# missing 2 Zoos exemplified what boxed nymphs frantically journey quickly, always breezy.** 'gv' duplicates: 21 'zosexmplifdwhatbnyrcu' client 1 score: 9996
# missing 1 Quartz jugs boxed very swiftly, whaling people crossed into dark fjords. 'm' duplicates: 17 'uartjgsoedywiflnp' client 1 score: 10625
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# ****************************
#
# missing 0 Pack wizards job  fine, humble executives gave no query plainly '' duplicates: 14 'pacirsobneulvy' client 1 score: 9464
# missing 2 Zipped bolts box jig waltz xylophone quirky zithers boom floats now zig. 'cv' duplicates: 17 'zipeboltsxgwayhnr' client 2 score: 9792
# missing 2 Zoos exemplified what boxed nymphs frantically journey quickly, always breezy.** 'gv' duplicates: 21 'zosexmplifdwhatbnyrcu' client 1 score: 9996
# missing 1 Quartz jugs boxed very swiftly, whaling people crossed into dark fjords. 'm' duplicates: 17 'uartjgsoedywiflnp' client 1 score: 10625
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# ****************************
#
# missing 2 Zipped bolts box jig waltz xylophone quirky zithers boom floats now zig. 'cv' duplicates: 17 'zipeboltsxgwayhnr' client 2 score: 9792
# missing 2 Zoos exemplified what boxed nymphs frantically journey quickly, always breezy.** 'gv' duplicates: 21 'zosexmplifdwhatbnyrcu' client 1 score: 9996
# missing 1 Despite jaw dropping xyz upgrades, few genuinely vanquished algorithmic debate. 'k' duplicates: 16 'despitawrongyulh' client 1 score: 10000
# missing 1 Quartz jugs boxed very swiftly, whaling people crossed into dark fjords. 'm' duplicates: 17 'uartjgsoedywiflnp' client 1 score: 10625
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# ****************************
#
# missing 2 Zoos exemplified what boxed nymphs frantically journey quickly, always breezy.** 'gv' duplicates: 21 'zosexmplifdwhatbnyrcu' client 1 score: 9996
# missing 1 Despite jaw dropping xyz upgrades, few genuinely vanquished algorithmic debate. 'k' duplicates: 16 'despitawrongyulh' client 1 score: 10000
# missing 1 Quartz jugs boxed very swiftly, whaling people crossed into dark fjords. 'm' duplicates: 17 'uartjgsoedywiflnp' client 1 score: 10625
# missing 0 Quartz judged vexing phantoms while brisk temper affected any woe. '' duplicates: 16 'uartdgeinphomswf' client 1 score: 10816
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# ****************************
#
# missing 1 Despite jaw dropping xyz upgrades, few genuinely vanquished algorithmic debate. 'k' duplicates: 16 'despitawrongyulh' client 1 score: 10000
# missing 1 Buzzing widgets zipped, fixing broken gadgets, crafting joyful achievements. 'q' duplicates: 16 'buzingdetspfroac' client 2 score: 10000
# missing 1 Quartz jugs boxed very swiftly, whaling people crossed into dark fjords. 'm' duplicates: 17 'uartjgsoedywiflnp' client 1 score: 10625
# missing 0 Quartz judged vexing phantoms while brisk temper affected any woe. '' duplicates: 16 'uartdgeinphomswf' client 1 score: 10816
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# ****************************
#
# missing 1 Buzzing widgets zipped, fixing broken gadgets, crafting joyful achievements. 'q' duplicates: 16 'buzingdetspfroac' client 2 score: 10000
# missing 1 Quartz jugs boxed very swiftly, whaling people crossed into dark fjords. 'm' duplicates: 17 'uartjgsoedywiflnp' client 1 score: 10625
# missing 1 Quartz glyphs exhibit hazy jumping kinetics; very powerful observation! 'd' duplicates: 17 'uartzglyphseibnvo' client 1 score: 10625
# missing 0 Quartz judged vexing phantoms while brisk temper affected any woe. '' duplicates: 16 'uartdgeinphomswf' client 1 score: 10816
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# ****************************
#
# missing 0 Brief quick jazz woven exams promptly harbor delightful scenes forever. '' duplicates: 18 'briefucazovnmsptlh' client 1 score: 10368
# missing 1 Quartz jugs boxed very swiftly, whaling people crossed into dark fjords. 'm' duplicates: 17 'uartjgsoedywiflnp' client 1 score: 10625
# missing 1 Quartz glyphs exhibit hazy jumping kinetics; very powerful observation! 'd' duplicates: 17 'uartzglyphseibnvo' client 1 score: 10625
# missing 0 Quartz judged vexing phantoms while brisk temper affected any woe. '' duplicates: 16 'uartdgeinphomswf' client 1 score: 10816
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# ****************************
#
# missing 1 Quartz jugs boxed very swiftly, whaling people crossed into dark fjords. 'm' duplicates: 17 'uartjgsoedywiflnp' client 1 score: 10625
# missing 1 Quartz glyphs exhibit hazy jumping kinetics; very powerful observation! 'd' duplicates: 17 'uartzglyphseibnvo' client 1 score: 10625
# missing 0 Quartz judged vexing phantoms while brisk temper affected any woe. '' duplicates: 16 'uartdgeinphomswf' client 1 score: 10816
# missing 2 Boxing frantically mixed the wizards box, juggling quartz zippers warmly. 'kv' duplicates: 19 'boxingratlymedwzsup' client 3 score: 10944
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# ****************************
#
# missing 1 Quartz glyphs exhibit hazy jumping kinetics; very powerful observation! 'd' duplicates: 17 'uartzglyphseibnvo' client 1 score: 10625
# missing 0 Quartz judged vexing phantoms while brisk temper affected any woe. '' duplicates: 16 'uartdgeinphomswf' client 1 score: 10816
# missing 2 Boxing frantically mixed the wizards box, juggling quartz zippers warmly. 'kv' duplicates: 19 'boxingratlymedwzsup' client 3 score: 10944
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# missing 1 Alex found joyful quizzes brightening everyday perspective within calmer phases. 'k' duplicates: 19 'alefoundyizsrghtvpc' client 1 score: 11875
# ****************************
#
# missing 0 Quartz judged vexing phantoms while brisk temper affected any woe. '' duplicates: 16 'uartdgeinphomswf' client 1 score: 10816
# missing 2 Boxing frantically mixed the wizards box, juggling quartz zippers warmly. 'kv' duplicates: 19 'boxingratlymedwzsup' client 3 score: 10944
# missing 1 Judging quirks vex many powerful diplomats as bright, zestful horizons expand 'c' duplicates: 18 'udginrsexmapoflthz' client 1 score: 11250
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# missing 1 Alex found joyful quizzes brightening everyday perspective within calmer phases. 'k' duplicates: 19 'alefoundyizsrghtvpc' client 1 score: 11875
# ****************************
#
# missing 0 Jazzy nymphs quietly blocked a fervent hope, tracing complex views. '' duplicates: 16 'azynmphsietlocrv' client 1 score: 10816
# missing 2 Boxing frantically mixed the wizards box, juggling quartz zippers warmly. 'kv' duplicates: 19 'boxingratlymedwzsup' client 3 score: 10944
# missing 1 Judging quirks vex many powerful diplomats as bright, zestful horizons expand 'c' duplicates: 18 'udginrsexmapoflthz' client 1 score: 11250
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# missing 1 Alex found joyful quizzes brightening everyday perspective within calmer phases. 'k' duplicates: 19 'alefoundyizsrghtvpc' client 1 score: 11875
# ****************************
#
# missing 2 Boxing frantically mixed the wizards box, juggling quartz zippers warmly. 'kv' duplicates: 19 'boxingratlymedwzsup' client 3 score: 10944
# missing 1 Judging quirks vex many powerful diplomats as bright, zestful horizons expand 'c' duplicates: 18 'udginrsexmapoflthz' client 1 score: 11250
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# missing 2 Voguely charming flax zipped beyond fresh onyx zinc quilts within gloom..   'jk' duplicates: 20 'oguelycharminfxzpdst' client 2 score: 11520
# missing 1 Alex found joyful quizzes brightening everyday perspective within calmer phases. 'k' duplicates: 19 'alefoundyizsrghtvpc' client 1 score: 11875
# ****************************
#
# missing 0 Quartzibly vexing dream flows beneath hazy jump quickly vast world. '' duplicates: 19 'quartziblyvendmowsh' client 1 score: 10944
# missing 1 Judging quirks vex many powerful diplomats as bright, zestful horizons expand 'c' duplicates: 18 'udginrsexmapoflthz' client 1 score: 11250
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# missing 2 Voguely charming flax zipped beyond fresh onyx zinc quilts within gloom..   'jk' duplicates: 20 'oguelycharminfxzpdst' client 2 score: 11520
# missing 1 Alex found joyful quizzes brightening everyday perspective within calmer phases. 'k' duplicates: 19 'alefoundyizsrghtvpc' client 1 score: 11875
# ****************************
#
# missing 1 Judging quirks vex many powerful diplomats as bright, zestful horizons expand 'c' duplicates: 18 'udginrsexmapoflthz' client 1 score: 11250
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# missing 2 Voguely charming flax zipped beyond fresh onyx zinc quilts within gloom..   'jk' duplicates: 20 'oguelycharminfxzpdst' client 2 score: 11520
# missing 1 Alex found joyful quizzes brightening everyday perspective within calmer phases. 'k' duplicates: 19 'alefoundyizsrghtvpc' client 1 score: 11875
# missing 0 Jockey baffled quartz exemplifies wrath knowing livid prism, quite breezy '' duplicates: 20 'okeybafldqurtzmpiswn' client 1 score: 13520
# ****************************
#
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# missing 2 Voguely charming flax zipped beyond fresh onyx zinc quilts within gloom..   'jk' duplicates: 20 'oguelycharminfxzpdst' client 2 score: 11520
# missing 1 Alex found joyful quizzes brightening everyday perspective within calmer phases. 'k' duplicates: 19 'alefoundyizsrghtvpc' client 1 score: 11875
# missing 0 Quartz jowls exemplified fervent wisdom, bravely checking literary paradox. '' duplicates: 18 'artowlsexmpifdvnyc' client 1 score: 12168
# missing 0 Jockey baffled quartz exemplifies wrath knowing livid prism, quite breezy '' duplicates: 20 'okeybafldqurtzmpiswn' client 1 score: 13520
# ****************************
#
# missing 2 Voguely charming flax zipped beyond fresh onyx zinc quilts within gloom..   'jk' duplicates: 20 'oguelycharminfxzpdst' client 2 score: 11520
# missing 1 Alex found joyful quizzes brightening everyday perspective within calmer phases. 'k' duplicates: 19 'alefoundyizsrghtvpc' client 1 score: 11875
# missing 0 Quartz jowls exemplified fervent wisdom, bravely checking literary paradox. '' duplicates: 18 'artowlsexmpifdvnyc' client 1 score: 12168
# missing 0 Jax watched foolish vex zippers quitting zombies forever yielding awkward. '' duplicates: 18 'axwthedfolisvzprng' client 3 score: 12168
# missing 0 Jockey baffled quartz exemplifies wrath knowing livid prism, quite breezy '' duplicates: 20 'okeybafldqurtzmpiswn' client 1 score: 13520
# ****************************
#
# missing 2 Quartz blew grimly when xenophobic experts judged vast energys claim. 'fk' duplicates: 20 'uartblewgimyhnxopcsd' client 1 score: 11520
# missing 1 Alex found joyful quizzes brightening everyday perspective within calmer phases. 'k' duplicates: 19 'alefoundyizsrghtvpc' client 1 score: 11875
# missing 0 Quartz jowls exemplified fervent wisdom, bravely checking literary paradox. '' duplicates: 18 'artowlsexmpifdvnyc' client 1 score: 12168
# missing 0 Jax watched foolish vex zippers quitting zombies forever yielding awkward. '' duplicates: 18 'axwthedfolisvzprng' client 3 score: 12168
# missing 0 Jockey baffled quartz exemplifies wrath knowing livid prism, quite breezy '' duplicates: 20 'okeybafldqurtzmpiswn' client 1 score: 13520
# ****************************
#
# missing 1 Alex found joyful quizzes brightening everyday perspective within calmer phases. 'k' duplicates: 19 'alefoundyizsrghtvpc' client 1 score: 11875
# missing 0 Quartz jowls exemplified fervent wisdom, bravely checking literary paradox. '' duplicates: 18 'artowlsexmpifdvnyc' client 1 score: 12168
# missing 0 Jax watched foolish vex zippers quitting zombies forever yielding awkward. '' duplicates: 18 'axwthedfolisvzprng' client 3 score: 12168
# missing 0 Pack blazing fumes quartz judged awful nymph swiftly vex each one.& '' duplicates: 18 'paclzingfumestdwyh' client 1 score: 12168
# missing 0 Jockey baffled quartz exemplifies wrath knowing livid prism, quite breezy '' duplicates: 20 'okeybafldqurtzmpiswn' client 1 score: 13520
# ****************************
#
# missing 0 Quartz jowls exemplified fervent wisdom, bravely checking literary paradox. '' duplicates: 18 'artowlsexmpifdvnyc' client 1 score: 12168
# missing 0 Jax watched foolish vex zippers quitting zombies forever yielding awkward. '' duplicates: 18 'axwthedfolisvzprng' client 3 score: 12168
# missing 0 Pack blazing fumes quartz judged awful nymph swiftly vex each one.& '' duplicates: 18 'paclzingfumestdwyh' client 1 score: 12168
# missing 0 Quartz justly weaves flax benign, charmed every knowledge profound, zip. '' duplicates: 18 'uartzslywevfnigdop' client 1 score: 12168
# missing 0 Jockey baffled quartz exemplifies wrath knowing livid prism, quite breezy '' duplicates: 20 'okeybafldqurtzmpiswn' client 1 score: 13520
# ****************************
#
# Calling it quits after 1800 seconds.
# Quitting client 2 url http://192.168.137.117:11434 model gemma3:4b i 1167 running: False
# Quitting client 3 url http://192.168.137.119:11434 model gemma3:4b i 524 running: False
# Quitting client 1 url http://192.168.137.118:11434 model gemma3:12b i 525 running: False
#
#
# All threads have stopped.
# missing 0 Jazzy sphinx quickly vowed, "Bring ample fun, participate!" '' duplicates: 12 'azypinuclert' client 1 score: 6912
# missing 0 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. '' duplicates: 17 'uniestbakdclrhogm' client 1 score: 11492
# missing 0 Jazzy box quivered: damp fragile hens exploited quick wolf! '' duplicates: 13 'azoxquierdpfl' client 1 score: 7488
# missing 0 Pack wizards job  fine, humble executives gave no query plainly '' duplicates: 14 'pacirsobneulvy' client 1 score: 9464
# missing 0 Amazingly, quick brown foxes jump over lazy dogs, beginning ample wealth. '' duplicates: 16 'amzinglyubrowesp' client 1 score: 2816
# missing 0 Quartz judged vexing phantoms while brisk temper affected any woe. '' duplicates: 16 'uartdgeinphomswf' client 1 score: 10816
# missing 0 Jubilant quiz fox wept, gladly baking cream, then vanished. '' duplicates: 11 'ubilantegdh' client 1 score: 6336
# missing 0 Jazzy fox quickened, browsing the enormous plum where vibrant xylophone hummed. '' duplicates: 19 'azyoxuiendbrwsthmpl' client 1 score: 9044
# missing 0 Quartz jumped quickly by freezing xylan aphids vehemently testing growth. '' duplicates: 17 'quartzmpedilynghs' client 1 score: 9792
# missing 0 Grant Whites zealous fox jumped quickly, vexing a zebra. '' duplicates: 13 'grantieszloux' client 2 score: 6188
# missing 0 The zealous quick fox jumps great lifts wonderfully zigzags, giving zero bliss. '' duplicates: 13 'tezalousifgrn' client 3 score: 4888
# missing 0 Juggling bright ventures, a quizzical businessman found expert growth quickly. '' duplicates: 16 'uglinbrhtesaqzco' client 1 score: 9216
# missing 0 Brave fox jumps quickly, forging a new foundation beneath zany boots. '' duplicates: 13 'braefousiygnt' client 2 score: 4888
# missing 0 Brief quick jazz woven exams promptly harbor delightful scenes forever. '' duplicates: 18 'briefucazovnmsptlh' client 1 score: 10368
# missing 0 Quickly, jaded fox begs with zest, triumphing over legal bounds. '' duplicates: 14 'uiladeobgsthrn' client 1 score: 6664
# missing 0 Jazzed quarterbacks fix grumpy allies, bewailing thorny vexations. '' duplicates: 15 'azeurtbsixgylno' client 1 score: 10140
# missing 0 Jazzy nymphs quietly blocked a fervent hope, tracing complex views. '' duplicates: 16 'azynmphsietlocrv' client 1 score: 10816
# missing 0 Buzz awkwardly queried xylem photons glazed, observing crystalline jets swiftly. '' duplicates: 16 'buzawrdlyeiotnsg' client 1 score: 10816
# missing 0 Quartzibly vexing dream flows beneath hazy jump quickly vast world. '' duplicates: 19 'quartziblyvendmowsh' client 1 score: 10944
# missing 0 Zealous foxes jumped quickly, exhibiting vibrant moments, quite wonderfully. '' duplicates: 17 'ealousfxmdqiybtnr' client 3 score: 8092
# missing 0 Quick zebra jumped x-raying frantic vehicles across sprawling zones. '' duplicates: 13 'uiczerapnglso' client 2 score: 7488
# missing 0 Jaq unfizling brown quietly vexed plump kid, charmed a happy zest. '' duplicates: 15 'aqunizlretydpmh' client 1 score: 8640
# missing 0 Quartz vex, Jim shrewdly blamed fancy dog perplexing work. '' duplicates: 14 'areximwdlynogp' client 1 score: 8064
# missing 0 Jazzy friends quickly vowed, bringing excellent snow, proving warmth. '' duplicates: 16 'azyriendsclvowgt' client 1 score: 9216
# missing 0 Quartz jammed every bright chick, promptly fixing walls anew. '' duplicates: 14 'artmeyighcplnw' client 1 score: 9464
# missing 0 Quick brown foxes jump over lazy dogs, attaching bridges with zeal. '' duplicates: 17 'uicbrowneslazdgth' client 3 score: 2992
# missing 0 Swift job quartz exemplifies bright designs affecting viable keys nonetheless '' duplicates: 13 'siftobarelghn' client 1 score: 8788
# missing 0 Zealous fox jumps quickly over wary dragons, finding jewels beneath stones. '' duplicates: 16 'ealousfjiyrwdgnt' client 2 score: 6016
# missing 0 Zealous fox jumped quickly, baffling the wicked plot, vexing every zealot. '' duplicates: 18 'zealoufxpdickyngtv' client 2 score: 8568
# missing 0 Analyze quick graphs: bizarre vexations bloom when drafting adjustments! '' duplicates: 16 'anlzeuigrhsbtomd' client 1 score: 9216
# missing 0 Juggling brightly, quartz vexed Phillip awoke gently crafting fixes calmly. '' duplicates: 15 'uglinrhtyaexpcf' client 1 score: 10140
# missing 0 Jockey baffled quartz exemplifies wrath knowing livid prism, quite breezy '' duplicates: 20 'okeybafldqurtzmpiswn' client 1 score: 13520
# missing 0 Quick boxers jumped after lovely views deeply picturing fervent haze. '' duplicates: 16 'uicoerspdaftlvyn' client 1 score: 9216
# missing 0 Quartz jumps quickly, fixing vibrant wisdom, exceeding gentle hope. '' duplicates: 17 'quartmpsiclxngdoe' client 1 score: 8092
# missing 0 Quartz jowls exemplified fervent wisdom, bravely checking literary paradox. '' duplicates: 18 'artowlsexmpifdvnyc' client 1 score: 12168
# missing 0 A black quilt framed jokes vex, nymph glow with graceful zeality. '' duplicates: 16 'alckuitfrmeoyhgw' client 1 score: 10816
# missing 0 Jumping quickly, buzzards vex new-hire optics formed subtly. '' duplicates: 16 'umpinclybzrdseot' client 1 score: 9216
# missing 0 Zebedee, vexed for jumps, packed xylophone confetti with quick vigor. '' duplicates: 15 'edvxforupckhnti' client 3 score: 7140
# missing 0 Meanwhile quietly, fox jumps wildly, vexing zebra, quick brown jelly. '' duplicates: 15 'meanwilquyoxjbr' client 2 score: 4140
# missing 0 Jax watched foolish vex zippers quitting zombies forever yielding awkward. '' duplicates: 18 'axwthedfolisvzprng' client 3 score: 12168
# missing 0 Quartz jewels beckon, vexing a grumpy fox through dense reason forest. '' duplicates: 12 'uartesonxgfh' client 1 score: 6912
# missing 0 Jazzy quick brown fox jumps over lazy, gifted whales. '' duplicates: 13 'jazyuirowfsel' client 1 score: 2288
# missing 0 Quick purple zen ox, while big Xavier jumped often, zealously xanny'. '' duplicates: 12 'uiprleznoxay' client 3 score: 6912
# missing 0 Jack vehemently quizzed Mr. Edward, analyzing profound axioms, truly beyond. '' duplicates: 13 'aemntlyuizdro' client 1 score: 8788
# missing 0 Quartz, jived, fox, bumpy, editor stock cleverly gains warmth. '' duplicates: 14 'uartivedomyscl' client 1 score: 8064
# missing 0 Drowning quick joy boxes flap every zenith clearly maps thenward. '' duplicates: 15 'drownicyeslapth' client 1 score: 8640
# missing 0 Quartz jabbed xylophone, framing black chocolate for viewing pleasure. '' duplicates: 15 'uartbelophnfigc' client 1 score: 10140
# missing 0 Quick brown fox jumps over lazy dogs, bewitching court both. '' duplicates: 13 'uicbrownsegth' client 1 score: 988
# missing 0 Jax quickly framed bronze with lively pixie cuts, observing great homes. '' duplicates: 18 'axuiclyrmebonthvsg' client 1 score: 10368
# missing 0 Pack blazing fumes quartz judged awful nymph swiftly vex each one.& '' duplicates: 18 'paclzingfumestdwyh' client 1 score: 12168
# -----------------------------
# duplicates: 16 Jow faced, quirky fingertips boxed velvet, then amplified great charm! 'ofacedirngtpvlhm' missing 1 'z' client 1 score: 10000
# duplicates: 16 Queer jobs funded vex amusing diplomats criticize helpful laws promptly zone. 'uerosfndamipltcz' missing 1 'k' client 1 score: 10000
# duplicates: 16 Judge waxed gloom beyond cryptic marvelfaint zeph admired historic quarry. 'udgealomyncrptih' missing 1 'k' client 1 score: 10000
# duplicates: 16 Jumping quizfowl brought exciting plans, devoid of every lawful thought. 'upingfowlrhteadv' missing 1 'k' client 1 score: 10000
# duplicates: 16 Quartz jumbles vexed physicians, buying homes for vital, keen remedies. 'uartmblesvdhyino' missing 1 'w' client 1 score: 10000
# duplicates: 16 Jazz, quiet vendors boxed my lovely playful tricks forthwith clearly. 'azuietvdorsylfch' missing 1 'g' client 1 score: 10000
# duplicates: 15 Jazzed quarterbacks fix grumpy allies, bewailing thorny vexations. 'azeurtbsixgylno' missing 0 '' client 1 score: 10140
# duplicates: 15 Juggling brightly, quartz vexed Phillip awoke gently crafting fixes calmly. 'uglinrhtyaexpcf' missing 0 '' client 1 score: 10140
# duplicates: 15 Quartz jabbed xylophone, framing black chocolate for viewing pleasure. 'uartbelophnfigc' missing 0 '' client 1 score: 10140
# duplicates: 15 Jackdaws quiz nymph expertly flowing bravely charged within silent places 'acdwsinyphertlg' missing 0 '' client 1 score: 10140
# duplicates: 15 My quandful boxer jumped zeal awkwardly, carving new cabins elsewhere today 'myuandlboerwcis' missing 0 '' client 1 score: 10140
# duplicates: 18 Brief quick jazz woven exams promptly harbor delightful scenes forever. 'briefucazovnmsptlh' missing 0 '' client 1 score: 10368
# duplicates: 18 Acquiring xenophobic data yielded expensive wisdom, justifying complex effort. 'acuirngxeopdtylsmf' missing 2 'kz' client 2 score: 10368
# duplicates: 18 Xavier's whole vibrant room exemplified complete zeal, showing grace frequently. 'xavierswholntmpfcg' missing 2 'jk' client 2 score: 10368
# duplicates: 18 Jax quickly framed bronze with lively pixie cuts, observing great homes. 'axuiclyrmebonthvsg' missing 0 '' client 1 score: 10368
# duplicates: 18 Zephyrs blew, quickly jamming blessed craft, involving pious, xenial wonders. 'epyrsblwuicamngdvo' missing 0 '' client 1 score: 10368
# duplicates: 17 Quartz jugs boxed very swiftly, whaling people crossed into dark fjords. 'uartjgsoedywiflnp' missing 1 'm' client 1 score: 10625
# duplicates: 17 Quartz glyphs exhibit hazy jumping kinetics; very powerful observation! 'uartzglyphseibnvo' missing 1 'd' client 1 score: 10625
# duplicates: 17 Joyful wizards quizzed baffled critics after a humbling expert gave hope. 'ofulizardsebcthgp' missing 1 'k' client 1 score: 10625
# duplicates: 17 Quartzibly, flamboyant judges vexed woven plains under cryptic helix. 'uartiblyondesvxpc' missing 1 'k' client 1 score: 10625
# duplicates: 17 Quartz glyphs exhibit bizarre, complex, fluid, joyous, keen, warm xenoliths. 'uartzlyphsexibomn' missing 1 'v' client 1 score: 10625
# duplicates: 17 Fixquizzbing yielded answers jovially exempluating what the judge discerned. 'ixuzngyeldaswrjth' missing 1 'k' client 1 score: 10625
# duplicates: 17 Azure cream water fell widely: qxyzbvkscpmgnfhjllwkbt.hprsd  'azrecmwtfldybksph' missing 1 'o' client 3 score: 10625
# duplicates: 17 Wicked zealous box, every xylophone's quaint humor exemplifies zero fright. 'iezalousxryphntmf' missing 1 'j' client 2 score: 10625
# duplicates: 17 Quixotic blaze jumped few grown herbs vinyl dawdling swiftly over. 'uiotblaedfwgrnsvy' missing 1 'k' client 1 score: 10625
# duplicates: 17 Quartz jibes vexedly brought him playful songs defying unknown depths. 'uartibesdlyoghpfn' missing 1 'c' client 1 score: 10625
# duplicates: 17 Exacting jumbles woven perplex glyph quiet zestedly affirm belongings. 'exatingumblsopryf' missing 1 'k' client 1 score: 10625
# duplicates: 17 Jaded quiz brought vexing charm, swiftly impacting profound labor. 'adeuibroghtncmflp' missing 1 'k' client 1 score: 10625
# duplicates: 16 Quartz judged vexing phantoms while brisk temper affected any woe. 'uartdgeinphomswf' missing 0 '' client 1 score: 10816
# duplicates: 16 Jazzy nymphs quietly blocked a fervent hope, tracing complex views. 'azynmphsietlocrv' missing 0 '' client 1 score: 10816
# duplicates: 16 Buzz awkwardly queried xylem photons glazed, observing crystalline jets swiftly. 'buzawrdlyeiotnsg' missing 0 '' client 1 score: 10816
# duplicates: 16 A black quilt framed jokes vex, nymph glow with graceful zeality. 'alckuitfrmeoyhgw' missing 0 '' client 1 score: 10816
# duplicates: 16 Pack fuzzy goblins joyfully watched examining every strange quiet task 'ackfuzygolinster' missing 0 '' client 1 score: 10816
# duplicates: 16 Quartz swiftly judged xenophobes, burying clever hymns under stark despair. 'uartsilydgenophb' missing 0 '' client 1 score: 10816
# duplicates: 19 Boxing frantically mixed the wizards box, juggling quartz zippers warmly. 'boxingratlymedwzsup' missing 2 'kv' client 3 score: 10944
# duplicates: 19 Quartzibly vexing dream flows beneath hazy jump quickly vast world. 'quartziblyvendmowsh' missing 0 '' client 1 score: 10944
# duplicates: 19 Amazing perplexing jumbo swift xylons quench fiery dots erode clearly, now. 'amingperlxuoswftycd' missing 2 'kv' client 1 score: 10944
# duplicates: 18 Judging quirks vex many powerful diplomats as bright, zestful horizons expand 'udginrsexmapoflthz' missing 1 'c' client 1 score: 11250
# duplicates: 18 Jaded quiz vexed him, abruptly crafting complex, wry, profound thoughts. 'adeuixhmrptlycfngo' missing 1 'k' client 1 score: 11250
# duplicates: 18 The quirky flux capacitor zipped beyond jumbling quirky zeros every xyzn bet. 'tequirkylxcapozdbn' missing 1 'w' client 2 score: 11250
# duplicates: 17 Unique zest baked cleverly whilst exploring famed harbor adjacent kingdom. 'uniestbakdclrhogm' missing 0 '' client 1 score: 11492
# duplicates: 17 Jack favored quilt buzz nymph Xeroxed amazing crystal, playing well calmly 'acoreduiltznympxg' missing 0 '' client 1 score: 11492
# duplicates: 20 Voguely charming flax zipped beyond fresh onyx zinc quilts within gloom..   'oguelycharminfxzpdst' missing 2 'jk' client 2 score: 11520
# duplicates: 20 Quartz blew grimly when xenophobic experts judged vast energys claim. 'uartblewgimyhnxopcsd' missing 2 'fk' client 1 score: 11520
# duplicates: 19 Alex found joyful quizzes brightening everyday perspective within calmer phases. 'alefoundyizsrghtvpc' missing 1 'k' client 1 score: 11875
# duplicates: 18 Quartz jowls exemplified fervent wisdom, bravely checking literary paradox. 'artowlsexmpifdvnyc' missing 0 '' client 1 score: 12168
# duplicates: 18 Jax watched foolish vex zippers quitting zombies forever yielding awkward. 'axwthedfolisvzprng' missing 0 '' client 3 score: 12168
# duplicates: 18 Pack blazing fumes quartz judged awful nymph swiftly vex each one.& 'paclzingfumestdwyh' missing 0 '' client 1 score: 12168
# duplicates: 18 Quartz justly weaves flax benign, charmed every knowledge profound, zip. 'uartzslywevfnigdop' missing 0 '' client 1 score: 12168
# duplicates: 20 Jockey baffled quartz exemplifies wrath knowing livid prism, quite breezy 'okeybafldqurtzmpiswn' missing 0 '' client 1 score: 13520
# ============================
