# %%
DEBUG = False

# Word file assists with the randomness of the prompt
with open("words", 'r') as file:
        lines_array = [line.strip() for line in file.readlines()]
        if(DEBUG):
                print(f"{len(lines_array)} words in list")

# %%
from ollama import Client
from ollama import generate
import random

def generate_theme():
    word1 = lines_array[random.randint(0, len(lines_array))]
    word2 = lines_array[random.randint(0, len(lines_array))]
    prompt = f"The theme is '{word1} {word2}'."
    if(DEBUG):
        print(prompt)
    return prompt

def generate_response(client, model):
    prompt = generate_theme()
    seed = int(random.random()*1000)
    system_prompt = """
        Write a single sentence with between 8 and 10 words to be used as a memorable pass phrase.
        Try to use as much of the alphabet as you can, but don't put yourself out over it.
        Only output the sentence. Don't ramble.
        """
    
    options = {
        "seed": seed, 
        "temperature": seed/100.0,
        "num_predict": 400

    }
    response = client.generate(
        model = model,
        prompt = f"{system_prompt} {prompt}",
        # system = system_prompt,
        options=options,
        stream = False
    )
    reply = response['response']
    if(DEBUG):
        print(f"r:{reply}")
    return reply

# %%
class Sentence:
    boring_words = ["quick", "brown", "fox", "jumps", "dog", "lazy"]
    bonus_dups = ["r", "s", "t", "l", "p", "e"]

    def __init__(self, text, client):
        """
        Args:
            text (str): The text of the sentence.  Must be a string.
        
        Raises:
            TypeError: if input is not a string
        """
        if not isinstance(text, str):
            raise TypeError("Input must be a string.")

        if len(text) > 80:
            if(DEBUG):
                print(f"long text rejected: {text}")
            raise TypeError("No paragraphs.")
        
        self._text = text.encode("ascii", errors="ignore").decode()  # Use a protected attribute for encapsulation
        self._words = len(text.split(" "))
        self._missing = self.find_missing_letters()
        self._duplicates = self.find_duplicate_letters()
        self._duplength = len(self._duplicates)
        self._dupkeys = "".join(self._duplicates.keys())
        self._client = client
        self._score = self.calculate_score()

    def get_text(self):
        """
        Returns the text of the sentence.

        Returns:
            str: The sentence text.
        """
        return self._text

    def get_client(self):
        return self._client
    
    def get_missing(self):
        return self._missing
    
    def get_missing_count(self):
        return len(self.get_missing())
      
    def get_duplicates(self):
        return self._duplicates
    
    def get_duplength(self):
        return self._duplength
    
    def get_dupkeys(self):
        return self._dupkeys
    
    def get_score(self):
        return self._score
    
    def calculate_score(self):
        missing_score = (26 - self.get_missing_count())**2
        duplicate_score = self.get_duplength()
        for boring_word in self.boring_words:
            if(boring_word in self.get_text().lower()):
                if(DEBUG):
                    print(f"Lowering score for {boring_word}")
                missing_score = missing_score - 100

        for bonus in self.bonus_dups:
            if(bonus in self.get_dupkeys()):
                duplicate_score = duplicate_score + 50

        return missing_score * duplicate_score

    
    def find_missing_letters(self):
        """
        Checks a string for the presence of all lowercase letters and identifies missing ones.

        Returns:
            A string containing the missing letters, or an empty string if all letters are present.
            Returns None if the input is not a string.
        """

        alphabet = "abcdefghijklmnopqrstuvwxyz"
        missing_letters = ""
        
        # Convert the input string to lowercase for case-insensitive comparison
        input_string = self._text.lower()

        for letter in alphabet:
            if letter not in input_string:
                missing_letters += letter

        return missing_letters

    def find_duplicate_letters(self):
        """
        Identifies duplicate letters in a string and counts their occurrences.

        Returns:
            A dictionary where keys are the duplicate letters and values are their counts.
            Returns an empty dictionary if there are no duplicates.
            Returns None if the input is not a string.
        """

        letter_counts = {}
        duplicate_counts = {}

        input_string = self._text.lower()  # Case-insensitive counting

        for letter in input_string:
            if 'a' <= letter <= 'z':  # Only consider letters
                if letter in letter_counts:
                    letter_counts[letter] += 1
                else:
                    letter_counts[letter] = 1

        # Identify duplicates and create a new dictionary
        for letter, count in letter_counts.items():
            if count > 1:
                duplicate_counts[letter] = count

        return duplicate_counts

class Winners:
    def __init__(self):
        self._sentences = []

    def add(self, sentence):
        self._sentences.append(sentence)
        if(DEBUG):
            print(f"There are {len(self._sentences)} sentences in the list.")

    def get_missing_winners(self, _count):
        sorted_winners = sorted(self._sentences, key=lambda item: item.get_missing_count())
        return sorted_winners[:_count]
    
    def get_score_winners(self, _count):
        sorted_winners = sorted(self._sentences, key=lambda item: item.get_score(), reverse=True)
        return sorted_winners[:_count]

    def length(self):
        return len(self._sentences)

# Test cases. Add to this list when you find good terms.
the_sentences = [
    "The quick brown fox jumps over the lazy dog.",
    "Golden sunlight danced upon the rippling, turquoise ocean waves.",
    "Old photographs revealed stories of laughter, love, and bygone days.",
    "The majestic mountains stood silently guarding the peaceful valley below.",
    "She expertly crafted intricate jewelry using shimmering silver and gold. The majestic mountains stood silently guarding the peaceful valley below.",
    "Dark storm clouds gathered quickly, threatening a powerful summer rain.",
    "Street food tasted wonderfully fresh.",
    "Remote islands felt truly peaceful.",
    "The axel, quickly! Jumping fences with brave, zealous strides.",
    "The teen quickly jammed, exploring vibrant chords with joyful zest."
]

winners = Winners()
for sentence in the_sentences:
    try:
        winners.add(Sentence(sentence, 0))
        
    except Exception as e:
        print(e)


def print_missing_winners(the_winners):
    for winner in the_winners:
        print(f"Missing:{winner.get_missing_count()}\t'{winner.get_missing()}'\tScore:{winner.get_score()}\tDuplicates:{winner.get_duplength()}\t'{winner.get_dupkeys()}'\t\tClient:{winner.get_client()}\t\"{winner.get_text()}\"")
    print("****************************")

print_missing_winners(winners.get_missing_winners(5))

def print_score_winners(the_winners):
    for winner in the_winners:
        print(f"Score:{winner.get_score()}\tMissing:{winner.get_missing_count()}\t'{winner.get_missing()}'\tDuplicates:{winner.get_duplength()}\t'{winner.get_dupkeys()}'\t\tClient:{winner.get_client()}\t\"{winner.get_text()}\"")
    print("============================")

print_score_winners(winners.get_score_winners(5))
# Out:
# No paragraphs.
# Missing:0	''	Score:11856	Duplicates:6	'theuro'		Client:0	"The quick brown fox jumps over the lazy dog."
# Missing:0	''	Score:150336	Duplicates:11	'thealuicnsr'		Client:0	"The axel, quickly! Jumping fences with brave, zealous strides."
# Missing:0	''	Score:153216	Duplicates:16	'thenuiclyjamdors'		Client:0	"The teen quickly jammed, exploring vibrant chords with joyful zest."
# Missing:4	'kqxz'	Score:104060	Duplicates:15	'themasicoundlyg'		Client:0	"The majestic mountains stood silently guarding the peaceful valley below."
# Missing:5	'bjvxz'	Score:90706	Duplicates:16	'darkstomclughein'		Client:0	"Dark storm clouds gathered quickly, threatening a powerful summer rain."
# ****************************
# Score:153216	Missing:0	''	Duplicates:16	'thenuiclyjamdors'		Client:0	"The teen quickly jammed, exploring vibrant chords with joyful zest."
# Score:150336	Missing:0	''	Duplicates:11	'thealuicnsr'		Client:0	"The axel, quickly! Jumping fences with brave, zealous strides."
# Score:104060	Missing:4	'kqxz'	Duplicates:15	'themasicoundlyg'		Client:0	"The majestic mountains stood silently guarding the peaceful valley below."
# Score:102060	Missing:8	'bfjkmxyz'	Duplicates:15	'goldensuihtacpr'		Client:0	"Golden sunlight danced upon the rippling, turquoise ocean waves."
# Score:101736	Missing:8	'cjkmqwxz'	Duplicates:14	'oldphtgrasevny'		Client:0	"Old photographs revealed stories of laughter, love, and bygone days."
# ============================

# %%
import threading
import time

timeout = 7*60*60 #60*15 #60*15 #*60 #7*60*60 #30*30 #1*60*60 #2*60*60 #7*60*60
winning_sentences = Winners()
running = True
previous_missing = [] # Keep track of high winners so we can display it when it changes.
previous_high_scores = []
DEBUG = False #True

def worker(client_id, url, model):
    """
     a client processing a task.
    
    Args:
        client_id: Unique identifier for the client.
        url: The URL associated with the client's task.
        model: the model to use for this client.
    """
    client = Client(host=url)
    i = 0
    while True:
        global running
        global winning_sentences
        global previous_missing
        global previous_high_scores
        i = i + 1
        if(running != True):
           # Exiting
           print(f"Quitting client {client_id} url {url} model {model} i {i} running: {running}")
           return
        try:
            if(DEBUG):
                print(f"client {client_id} url {url} model {model} i {i} running: {running}")

            sentence = Sentence(generate_response(client, model).strip().replace("\n", " "), client_id)
            if(DEBUG):
                print(sentence.get_text())

            winning_sentences.add(sentence)

            missing_winners = winning_sentences.get_missing_winners(3)
            if(missing_winners != previous_missing):
                previous_missing = missing_winners
                print_missing_winners(missing_winners)
            
            score_winners = winning_sentences.get_score_winners(3)
            if(score_winners != previous_high_scores):
                previous_high_scores = score_winners
                print_score_winners(score_winners)

            # 2 Seconds of cool down for the LLM. Gives the connection time to die.
            time.sleep(2)

        except Exception as e:
            dummy = 1 # Ignore all exceptions. Set dummy so linter doesn't complain.
            if(DEBUG):
                print(f"client {client_id} url {url} {e}")
        

def main():
    """
    Creates and starts multiple client threads.
    """

    clients = [
        {"id": 1, "url": "http://192.168.137.118:11434", "model": "gemma3:12b"},
        {"id": 2, "url": "http://192.168.137.117:11434", "model": "gemma3:4b"},
        {"id": 3, "url": "http://192.168.137.119:11434", "model": "gemma3:4b"},
    ]

    global running
    running = True
    threads = []
    for client in clients:
        thread = threading.Thread(target=worker, args=(client["id"], client["url"], client["model"]))
        threads.append(thread)
        thread.start()

    try:
        time.sleep(timeout)
        # Time's up. Tell threads to wrap it up. There may be a significant delay because the client might still be processing.
        running = False
        print(f"Calling it quits after {timeout} seconds.")
        
        # Wait for all threads to finish
        for thread in threads:
            thread.join(timeout=30)

        print("\n\nAll threads have stopped.")
        missing_winners = winning_sentences.get_missing_winners(50)
        
        # Word file assists with the randomness of the prompt
        with open("winners", 'a') as file:
            for winner in missing_winners:
                message = f"Missing:{winner.get_missing_count()}\t'{winner.get_missing()}'\tScore:{winner.get_score()}\tDuplicates:{winner.get_duplength()}\t'{winner.get_dupkeys()}'\t\tClient:{winner.get_client()}\t\"{winner.get_text()}\""
                print(message)
                print(message, file=file)

            print("-----------------------------")
            duplicate_winners = winning_sentences.get_score_winners(50)
            for winner in duplicate_winners:
                message = f"Score:{winner.get_score()}\tMissing:{winner.get_missing_count()}\t'{winner.get_missing()}'\tDuplicates:{winner.get_duplength()}\t'{winner.get_dupkeys()}'\t\tClient:{winner.get_client()}\t\"{winner.get_text()}\""
                print(message)
                print(message, file=file)

            file.close()
            print("============================\n\n")

    
       
    except KeyboardInterrupt:
        print("Stopping threads due to KeyboardInterrupt...")
        running = False
        for thread in threads:
            thread.join()
        print("All threads stopped after KeyboardInterrupt")

if __name__ == "__main__":
    main()
# Out:
# Missing:3	'bjx'	Score:140185	Duplicates:15	'trulyiganemscow'		Client:2	"Truly, vigilant teams conquer challenges, optimizing workflows daily."
# ****************************
# Score:140185	Missing:3	'bjx'	Duplicates:15	'trulyiganemscow'		Client:2	"Truly, vigilant teams conquer challenges, optimizing workflows daily."
# ============================
# Missing:3	'bjx'	Score:140185	Duplicates:15	'trulyiganemscow'		Client:2	"Truly, vigilant teams conquer challenges, optimizing workflows daily."
# Missing:7	'ghjkmpz'	Score:76532	Duplicates:12	'evrxiousncat'		Client:3	"Everyxious oxen crave vibrant eloquence over Oxford Crest now."
# ****************************
# Score:140185	Missing:3	'bjx'	Duplicates:15	'trulyiganemscow'		Client:2	"Truly, vigilant teams conquer challenges, optimizing workflows daily."
# Score:76532	Missing:7	'ghjkmpz'	Duplicates:12	'evrxiousncat'		Client:3	"Everyxious oxen crave vibrant eloquence over Oxford Crest now."
# ============================
# Missing:2	'hj'	Score:151488	Duplicates:13	'artyieldswbkn'		Client:1	"Quartz yields swiftly, blocking expensive New deals remarkably."
# Missing:3	'bjx'	Score:140185	Duplicates:15	'trulyiganemscow'		Client:2	"Truly, vigilant teams conquer challenges, optimizing workflows daily."
# Missing:7	'ghjkmpz'	Score:76532	Duplicates:12	'evrxiousncat'		Client:3	"Everyxious oxen crave vibrant eloquence over Oxford Crest now."
# ****************************
# Score:151488	Missing:2	'hj'	Duplicates:13	'artyieldswbkn'		Client:1	"Quartz yields swiftly, blocking expensive New deals remarkably."
# Score:140185	Missing:3	'bjx'	Duplicates:15	'trulyiganemscow'		Client:2	"Truly, vigilant teams conquer challenges, optimizing workflows daily."
# Score:76532	Missing:7	'ghjkmpz'	Duplicates:12	'evrxiousncat'		Client:3	"Everyxious oxen crave vibrant eloquence over Oxford Crest now."
# ============================
# Missing:2	'hj'	Score:151488	Duplicates:13	'artyieldswbkn'		Client:1	"Quartz yields swiftly, blocking expensive New deals remarkably."
# Missing:3	'bjx'	Score:140185	Duplicates:15	'trulyiganemscow'		Client:2	"Truly, vigilant teams conquer challenges, optimizing workflows daily."
# Missing:3	'bqv'	Score:113256	Duplicates:14	'wisefoualrnctm'		Client:3	"Wise foxes judge zealous warriors; unlock precision with firm mastery."
# ****************************
# Score:151488	Missing:2	'hj'	Duplicates:13	'artyieldswbkn'		Client:1	"Quartz yields swiftly, blocking expensive New deals remarkably."
# Score:140185	Missing:3	'bjx'	Duplicates:15	'trulyiganemscow'		Client:2	"Truly, vigilant teams conquer challenges, optimizing workflows daily."
# Score:113256	Missing:3	'bqv'	Duplicates:14	'wisefoualrnctm'		Client:3	"Wise foxes judge zealous warriors; unlock precision with firm mastery."
# ============================
# Score:152944	Missing:4	'bfqz'	Duplicates:16	'indlyaceptowrusg'		Client:1	"Kindly accept lower pay, justly valuing experience, growth, wisdom."
# Score:151488	Missing:2	'hj'	Duplicates:13	'artyieldswbkn'		Client:1	"Quartz yields swiftly, blocking expensive New deals remarkably."
# Score:140185	Missing:3	'bjx'	Duplicates:15	'trulyiganemscow'		Client:2	"Truly, vigilant teams conquer challenges, optimizing workflows daily."
# ============================
# Missing:2	'hj'	Score:151488	Duplicates:13	'artyieldswbkn'		Client:1	"Quartz yields swiftly, blocking expensive New deals remarkably."
# Missing:2	'jk'	Score:180864	Duplicates:14	'artzengislyopm'		Client:1	"Quartz engines whir, deftly optimizing vibrant, complex operational systems."
# Missing:3	'bjx'	Score:140185	Duplicates:15	'trulyiganemscow'		Client:2	"Truly, vigilant teams conquer challenges, optimizing workflows daily."
# ****************************
# Score:180864	Missing:2	'jk'	Duplicates:14	'artzengislyopm'		Client:1	"Quartz engines whir, deftly optimizing vibrant, complex operational systems."
# Score:152944	Missing:4	'bfqz'	Duplicates:16	'indlyaceptowrusg'		Client:1	"Kindly accept lower pay, justly valuing experience, growth, wisdom."
# Score:151488	Missing:2	'hj'	Duplicates:13	'artyieldswbkn'		Client:1	"Quartz yields swiftly, blocking expensive New deals remarkably."
# ============================
# Missing:2	'hj'	Score:151488	Duplicates:13	'artyieldswbkn'		Client:1	"Quartz yields swiftly, blocking expensive New deals remarkably."
# Missing:2	'jk'	Score:180864	Duplicates:14	'artzengislyopm'		Client:1	"Quartz engines whir, deftly optimizing vibrant, complex operational systems."
# Missing:2	'vx'	Score:125188	Duplicates:13	'omlueikrstwah'		Client:2	"Zoom! Blue quick frost lets weak shadows jump early growth lines wise."
# ****************************
# Missing:1	'z'	Score:90950	Duplicates:14	'quicoesmntaglv'		Client:1	"Quick foxes jump beyond, tracing twelve quaint village homes."
# Missing:2	'hj'	Score:151488	Duplicates:13	'artyieldswbkn'		Client:1	"Quartz yields swiftly, blocking expensive New deals remarkably."
# Missing:2	'jk'	Score:180864	Duplicates:14	'artzengislyopm'		Client:1	"Quartz engines whir, deftly optimizing vibrant, complex operational systems."
# ****************************
# Score:180864	Missing:2	'jk'	Duplicates:14	'artzengislyopm'		Client:1	"Quartz engines whir, deftly optimizing vibrant, complex operational systems."
# Score:153428	Missing:4	'bmqz'	Duplicates:17	'vidxanthusfgeorlp'		Client:2	"Vivid Xanthuss shifting jade fortunes unlock perplexing winds entirely."
# Score:152944	Missing:4	'bfqz'	Duplicates:16	'indlyaceptowrusg'		Client:1	"Kindly accept lower pay, justly valuing experience, growth, wisdom."
# ============================
# Score:180864	Missing:2	'jk'	Duplicates:14	'artzengislyopm'		Client:1	"Quartz engines whir, deftly optimizing vibrant, complex operational systems."
# Score:167164	Missing:3	'bmx'	Duplicates:16	'ipnodersulcfyvat'		Client:2	"Zipping wonders unlock fresh, unique journeys, vividly crafted and styled."
# Score:153428	Missing:4	'bmqz'	Duplicates:17	'vidxanthusfgeorlp'		Client:2	"Vivid Xanthuss shifting jade fortunes unlock perplexing winds entirely."
# ============================
# Score:180864	Missing:2	'jk'	Duplicates:14	'artzengislyopm'		Client:1	"Quartz engines whir, deftly optimizing vibrant, complex operational systems."
# Score:167164	Missing:3	'bmx'	Duplicates:16	'ipnodersulcfyvat'		Client:2	"Zipping wonders unlock fresh, unique journeys, vividly crafted and styled."
# Score:166106	Missing:3	'ckz'	Duplicates:14	'yulnrseitgmpah'		Client:1	"Joyful nurses quietly bring empathy, warmth expertly, aiding lives."
# ============================
# Missing:1	'z'	Score:90950	Duplicates:14	'quicoesmntaglv'		Client:1	"Quick foxes jump beyond, tracing twelve quaint village homes."
# Missing:1	'k'	Score:135000	Duplicates:16	'revinghaycolsfum'		Client:1	"Reviewing hazy chronicles, Xavier found joyful promises quietly blossoming."
# Missing:2	'hj'	Score:151488	Duplicates:13	'artyieldswbkn'		Client:1	"Quartz yields swiftly, blocking expensive New deals remarkably."
# ****************************
# Missing:1	'z'	Score:90950	Duplicates:14	'quicoesmntaglv'		Client:1	"Quick foxes jump beyond, tracing twelve quaint village homes."
# Missing:1	'k'	Score:135000	Duplicates:16	'revinghaycolsfum'		Client:1	"Reviewing hazy chronicles, Xavier found joyful promises quietly blossoming."
# Missing:1	'z'	Score:166425	Duplicates:17	'uickproxesglmahtf'		Client:1	"Quick proxies juggle massive checksums through flexible network paths deftly."
# ****************************
# Score:180864	Missing:2	'jk'	Duplicates:14	'artzengislyopm'		Client:1	"Quartz engines whir, deftly optimizing vibrant, complex operational systems."
# Score:167164	Missing:3	'bmx'	Duplicates:16	'ipnodersulcfyvat'		Client:2	"Zipping wonders unlock fresh, unique journeys, vividly crafted and styled."
# Score:166425	Missing:1	'z'	Duplicates:17	'uickproxesglmahtf'		Client:1	"Quick proxies juggle massive checksums through flexible network paths deftly."
# ============================
# Score:182592	Missing:2	'gx'	Duplicates:17	'ebraucswiftlymdpo'		Client:1	"Zeebra quack swiftly charmed plump jets of violet noise boldly flew?"
# Score:180864	Missing:2	'jk'	Duplicates:14	'artzengislyopm'		Client:1	"Quartz engines whir, deftly optimizing vibrant, complex operational systems."
# Score:167164	Missing:3	'bmx'	Duplicates:16	'ipnodersulcfyvat'		Client:2	"Zipping wonders unlock fresh, unique journeys, vividly crafted and styled."
# ============================
# Score:182592	Missing:2	'gx'	Duplicates:17	'ebraucswiftlymdpo'		Client:1	"Zeebra quack swiftly charmed plump jets of violet noise boldly flew?"
# Score:182016	Missing:2	'jv'	Duplicates:16	'uartplesbomgcyin'		Client:1	"Quartz apples bloom gracefully during twilight auctions remarkably xylogenic.&"
# Score:180864	Missing:2	'jk'	Duplicates:14	'artzengislyopm'		Client:1	"Quartz engines whir, deftly optimizing vibrant, complex operational systems."
# ============================
# Score:182592	Missing:2	'gx'	Duplicates:17	'ebraucswiftlymdpo'		Client:1	"Zeebra quack swiftly charmed plump jets of violet noise boldly flew?"
# Score:182016	Missing:2	'jv'	Duplicates:16	'uartplesbomgcyin'		Client:1	"Quartz apples bloom gracefully during twilight auctions remarkably xylogenic.&"
# Score:182016	Missing:2	'fq'	Duplicates:16	'wearocsptlidbnug'		Client:3	"Weak xeroces promptly avoid brazen cubs grabbing eager judges' wealth!"
# ============================
# Score:197500	Missing:1	'x'	Duplicates:16	'uartigswdlyonepf'		Client:1	"Quartz jigs awkwardly bounce upon five gentle rooftops today somehow..."
# Score:182592	Missing:2	'gx'	Duplicates:17	'ebraucswiftlymdpo'		Client:1	"Zeebra quack swiftly charmed plump jets of violet noise boldly flew?"
# Score:182016	Missing:2	'jv'	Duplicates:16	'uartplesbomgcyin'		Client:1	"Quartz apples bloom gracefully during twilight auctions remarkably xylogenic.&"
# ============================
# Score:197500	Missing:1	'x'	Duplicates:16	'uartigswdlyonepf'		Client:1	"Quartz jigs awkwardly bounce upon five gentle rooftops today somehow..."
# Score:197500	Missing:1	'q'	Duplicates:16	'enolarsbyupigcht'		Client:2	"Xenon flares boldly, jumping cables via shocking energy zestwise groupsight."
# Score:182592	Missing:2	'gx'	Duplicates:17	'ebraucswiftlymdpo'		Client:1	"Zeebra quack swiftly charmed plump jets of violet noise boldly flew?"
# ============================
# Score:197500	Missing:1	'x'	Duplicates:16	'uartigswdlyonepf'		Client:1	"Quartz jigs awkwardly bounce upon five gentle rooftops today somehow..."
# Score:197500	Missing:1	'q'	Duplicates:16	'enolarsbyupigcht'		Client:2	"Xenon flares boldly, jumping cables via shocking energy zestwise groupsight."
# Score:195625	Missing:1	'f'	Duplicates:13	'arteldpoinswg'		Client:1	"Quartz emerald projections showing vibrant skies expertly ignite new worlds"
# ============================
# Missing:0	''	Score:153792	Duplicates:17	'uibronzesxtwhflad'		Client:1	"Quick bronze joys exist with flavorful depths, amaze and grow.</x>\ndb> </ul>"
# Missing:1	'z'	Score:90950	Duplicates:14	'quicoesmntaglv'		Client:1	"Quick foxes jump beyond, tracing twelve quaint village homes."
# Missing:1	'k'	Score:135000	Duplicates:16	'revinghaycolsfum'		Client:1	"Reviewing hazy chronicles, Xavier found joyful promises quietly blossoming."
# ****************************
# Missing:0	''	Score:153792	Duplicates:17	'uibronzesxtwhflad'		Client:1	"Quick bronze joys exist with flavorful depths, amaze and grow.</x>\ndb> </ul>"
# Missing:0	''	Score:182016	Duplicates:16	'uicglteornaspyhm'		Client:1	"Quick zigilite journals explain every chapter broadly amongst whimsical fans ."
# Missing:1	'z'	Score:90950	Duplicates:14	'quicoesmntaglv'		Client:1	"Quick foxes jump beyond, tracing twelve quaint village homes."
# ****************************
# Missing:0	''	Score:153792	Duplicates:17	'uibronzesxtwhflad'		Client:1	"Quick bronze joys exist with flavorful depths, amaze and grow.</x>\ndb> </ul>"
# Missing:0	''	Score:182016	Duplicates:16	'uicglteornaspyhm'		Client:1	"Quick zigilite journals explain every chapter broadly amongst whimsical fans ."
# Missing:0	''	Score:123840	Duplicates:15	'oyinguzlbersacf'		Client:1	"Joying puzzling boxers vow nuanced zeal quickly affirms breathless."
# ****************************
# Score:197500	Missing:1	'x'	Duplicates:16	'uartigswdlyonepf'		Client:1	"Quartz jigs awkwardly bounce upon five gentle rooftops today somehow..."
# Score:197500	Missing:1	'q'	Duplicates:16	'enolarsbyupigcht'		Client:2	"Xenon flares boldly, jumping cables via shocking energy zestwise groupsight."
# Score:197500	Missing:1	'v'	Duplicates:16	'epingwtarukslyfo'		Client:1	"Zepping with Xander Quinn makes playful jokes across baffling rows yet."
# ============================
# Score:198125	Missing:1	'b'	Duplicates:17	'zigapthselodnrumy'		Client:1	"Zigzag paths explode onward, jumping over quirky fatal rhythms calmly.</zags />"
# Score:197500	Missing:1	'x'	Duplicates:16	'uartigswdlyonepf'		Client:1	"Quartz jigs awkwardly bounce upon five gentle rooftops today somehow..."
# Score:197500	Missing:1	'q'	Duplicates:16	'enolarsbyupigcht'		Client:2	"Xenon flares boldly, jumping cables via shocking energy zestwise groupsight."
# ============================
# Score:198750	Missing:1	'z'	Duplicates:18	'uirkygenatlcmdfosp'		Client:1	"Quirky Gwen exuberantly charmed folks, joyfully displaying captivating romance."
# Score:198125	Missing:1	'b'	Duplicates:17	'zigapthselodnrumy'		Client:1	"Zigzag paths explode onward, jumping over quirky fatal rhythms calmly.</zags />"
# Score:197500	Missing:1	'x'	Duplicates:16	'uartigswdlyonepf'		Client:1	"Quartz jigs awkwardly bounce upon five gentle rooftops today somehow..."
# ============================
# Score:212940	Missing:0	''	Duplicates:15	'umpinzealosrtyv'		Client:1	"Jumping zealous quips maximize robust unknowns promptly find lovely archives."
# Score:198750	Missing:1	'z'	Duplicates:18	'uirkygenatlcmdfosp'		Client:1	"Quirky Gwen exuberantly charmed folks, joyfully displaying captivating romance."
# Score:198125	Missing:1	'b'	Duplicates:17	'zigapthselodnrumy'		Client:1	"Zigzag paths explode onward, jumping over quirky fatal rhythms calmly.</zags />"
# ============================
# Score:215644	Missing:0	''	Duplicates:19	'uerbasiwdlyfngpchot'		Client:1	"Queer zebras jive awkwardly, fumbling playful chaos unexpectedly tonight."
# Score:212940	Missing:0	''	Duplicates:15	'umpinzealosrtyv'		Client:1	"Jumping zealous quips maximize robust unknowns promptly find lovely archives."
# Score:198750	Missing:1	'z'	Duplicates:18	'uirkygenatlcmdfosp'		Client:1	"Quirky Gwen exuberantly charmed folks, joyfully displaying captivating romance."
# ============================
# Score:215644	Missing:0	''	Duplicates:19	'uerbasiwdlyfngpchot'		Client:1	"Queer zebras jive awkwardly, fumbling playful chaos unexpectedly tonight."
# Score:213616	Missing:0	''	Duplicates:16	'lucysimaboetprnz'		Client:1	"Lucy's whimsical books quietly explore vibrant, joyful, puzzling dreams."
# Score:212940	Missing:0	''	Duplicates:15	'umpinzealosrtyv'		Client:1	"Jumping zealous quips maximize robust unknowns promptly find lovely archives."
# ============================
# Score:215644	Missing:0	''	Duplicates:19	'uerbasiwdlyfngpchot'		Client:1	"Queer zebras jive awkwardly, fumbling playful chaos unexpectedly tonight."
# Score:214292	Missing:0	''	Duplicates:17	'oyfulesrtipdhganw'		Client:1	"Joyfully escort zipped through Xavier' keen questing whims abroad always safely."
# Score:213616	Missing:0	''	Duplicates:16	'lucysimaboetprnz'		Client:1	"Lucy's whimsical books quietly explore vibrant, joyful, puzzling dreams."
# ============================
# Score:215644	Missing:0	''	Duplicates:19	'uerbasiwdlyfngpchot'		Client:1	"Queer zebras jive awkwardly, fumbling playful chaos unexpectedly tonight."
# Score:214292	Missing:0	''	Duplicates:17	'oyfulesrtipdhganw'		Client:1	"Joyfully escort zipped through Xavier' keen questing whims abroad always safely."
# Score:214292	Missing:0	''	Duplicates:17	'victualseoprznxyb'		Client:3	"Victuals jeopardaze when Xavier prints goofy albums brazen xylopockets quietly.."
# ============================
# Calling it quits after 25200 seconds.
# Quitting client 2 url http://192.168.137.117:11434 model gemma3:4b i 15035 running: False
# Quitting client 3 url http://192.168.137.119:11434 model gemma3:4b i 7250 running: False
# Quitting client 1 url http://192.168.137.118:11434 model gemma3:12b i 9939 running: False
#
#
# All threads have stopped.
# Missing:0	''	Score:153792	Duplicates:17	'uibronzesxtwhflad'		Client:1	"Quick bronze joys exist with flavorful depths, amaze and grow.</x>\ndb> </ul>"
# Missing:0	''	Score:182016	Duplicates:16	'uicglteornaspyhm'		Client:1	"Quick zigilite journals explain every chapter broadly amongst whimsical fans ."
# Missing:0	''	Score:123840	Duplicates:15	'oyinguzlbersacf'		Client:1	"Joying puzzling boxers vow nuanced zeal quickly affirms breathless."
# Missing:0	''	Score:149464	Duplicates:14	'uifoesmpraltng'		Client:1	"Quick foxes jump, bravely eating zestful mangoes with pride."
# Missing:0	''	Score:152064	Duplicates:14	'ouilteahgsbcnr'		Client:1	"Fox quilted jovial highways beckon, embracing zealous orange paths."
# Missing:0	''	Score:153792	Duplicates:17	'uingqartzecdlysow'		Client:1	"Jumping quartz excitedly fuels bold starts, quickly weaving yellowZenith"
# Missing:0	''	Score:73140	Duplicates:15	'uickfoesmprangt'		Client:1	"Quick foxes jumped over lazy brown packages, figuring them out."
# Missing:0	''	Score:179140	Duplicates:15	'ueryntioshfwadp'		Client:1	"Query junctions exhibit few zones amidst surprising pathways often overlooked."
# Missing:0	''	Score:152064	Duplicates:14	'iclyaewdsrohnt'		Client:1	"Quickly glaze waxed screws; John prefers better chrome, evidently."
# Missing:0	''	Score:180864	Duplicates:14	'uilaermpdsngwt'		Client:1	"Quickly, Xavier jumped, seizing blue flowers amidst startling whispers."
# Missing:0	''	Score:126140	Duplicates:15	'uifoespwldyrang'		Client:1	"Quick foxes jump wildly over blazing paths, easily finding answers."
# Missing:0	''	Score:150892	Duplicates:17	'uicebrafshplytogn'		Client:1	"Quick zebrafish jump wildly though canals observing purple foxes gently."
# Missing:0	''	Score:19008	Duplicates:8	'uifosryb'		Client:2	"Quick fox jumps over lazy brown hybrid fort guys."
# Missing:0	''	Score:46464	Duplicates:14	'uioesvrlazbwnt'		Client:1	"Quick foxes jump over lazy brown dogs with vibrant zeal."
# Missing:0	''	Score:119944	Duplicates:19	'judenticbrowfxslyap'		Client:1	"Judgent quick brown fox justly warms flavors beyond expected zenith plans"
# Missing:0	''	Score:150892	Duplicates:17	'uicfoesmpablyrntg'		Client:1	"Quick foxes jumpably seize vibrant homes, adapting gracefully now."
# Missing:0	''	Score:152640	Duplicates:15	'avierjupdclygsf'		Client:1	"Xavier jumped quickly while judges bravely assessed playful zing effectors ."
# Missing:0	''	Score:100912	Duplicates:12	'uilymoverazs'		Client:1	"Quickly jump over hazy foxes, bravely seizing time's reward."
# Missing:0	''	Score:36960	Duplicates:10	'uioesdrzwt'		Client:1	"Quick foxes jumped over lazy brown dogs with zest."
# Missing:0	''	Score:212940	Duplicates:15	'umpinzealosrtyv'		Client:1	"Jumping zealous quips maximize robust unknowns promptly find lovely archives."
# Missing:0	''	Score:181440	Duplicates:15	'uiklyadstrnpome'		Client:1	"Quickly adjust vibrant photos, making textures playfully zoom outwards."
# Missing:0	''	Score:179816	Duplicates:16	'venrablutycshowi'		Client:1	"Venerable quartz bravely expects humble, joyful crows within stark ridges"
# Missing:0	''	Score:99640	Duplicates:15	'uifoesprhazywnl'		Client:1	"Quick foxes jump over hazy brown walls, deftly seizing hope."
# Missing:0	''	Score:215644	Duplicates:19	'uerbasiwdlyfngpchot'		Client:1	"Queer zebras jive awkwardly, fumbling playful chaos unexpectedly tonight."
# Missing:0	''	Score:126140	Duplicates:15	'uicfoesbravlnth'		Client:1	"Quick foxes jump bravely, finding cabs with zealous, vibrant hues."
# Missing:0	''	Score:46112	Duplicates:12	'uioesprlazwd'		Client:1	"Quick foxes jump over lazy brown dogs with zealous pride."
# Missing:0	''	Score:153792	Duplicates:17	'uicklyeatrogdwnfs'		Client:1	"Quickly zeal Jupiter brought dawn exclaiming wonderfully fervent stars alike."
# Missing:0	''	Score:125188	Duplicates:13	'uifoesmpralyh'		Client:1	"Quick foxes jump bravely, defying loss with zealous, firm hope."
# Missing:0	''	Score:150892	Duplicates:17	'ealousirybnmpgthd'		Client:1	"Zealous quirky brown foxes jump vigorously past humbled green clouds tonight.</t"
# Missing:0	''	Score:180864	Duplicates:14	'uicepyrsmnaltv'		Client:1	"Quick zephyrs jump beyond awful, exciting narratives cleverly tempt."
# Missing:0	''	Score:213616	Duplicates:16	'lucysimaboetprnz'		Client:1	"Lucy's whimsical books quietly explore vibrant, joyful, puzzling dreams."
# Missing:0	''	Score:142636	Duplicates:11	'wenistyoarg'		Client:2	"When zinc swiftly tops weary axes joining vibrant markets quite grand."
# Missing:0	''	Score:153792	Duplicates:17	'oypenibracdzlusqv'		Client:1	"Joy phoenix embraced zealous quartz flips inward quickly proving valuable."
# Missing:0	''	Score:125664	Duplicates:14	'uicoesnyrdwlth'		Client:1	"Quick foxes enjoy breezy dawns; diligently deliver honest, wholesome products?"
# Missing:0	''	Score:183168	Duplicates:18	'uiclyxaerpdonwhstg'		Client:1	"Quickly, Xavier jumped beyond whales, extending gracefully toward azure depths."
# Missing:0	''	Score:152640	Duplicates:15	'aierumpdlybntho'		Client:1	"Xavier jumped quickly beneath many dozen bright plum flowers."
# Missing:0	''	Score:125664	Duplicates:14	'ealousjmicrtnd'		Client:3	"Zealous foxes jump quickly, rejecting shadows, under vibrant, silent moons."
# Missing:0	''	Score:180864	Duplicates:14	'oyularipenwths'		Client:1	"Joyful Mary quickly zipped, exploring new paths with vibrant hues."
# Missing:0	''	Score:80088	Duplicates:13	'uiroweshlaygv'		Client:1	"Quick brown foxes zoom uphill where hardy guests view Hugh jovially."
# Missing:0	''	Score:101388	Duplicates:13	'wrongulebamsy'		Client:2	"Wrongful, exuberant zebra jumps quickly over wary hounds' gloom."
# Missing:0	''	Score:150912	Duplicates:12	'uicasrlyewto'		Client:1	"Quick jabs, firmly viewed, expertly testing crucial loyalty's zero worth."
# Missing:0	''	Score:179712	Duplicates:12	'oyileatsrpfn'		Client:1	"Joy quickly elevates bizarre whims expertly past fading notes often"
# Missing:0	''	Score:125664	Duplicates:14	'ealousikgthrbn'		Client:1	"Zealous foxes quickly jog through vibrant parks among bewildering trails."
# Missing:0	''	Score:126616	Duplicates:16	'estyoxumpiclnwad'		Client:2	"Zesty foxes jump quickly, observing new landscapes within complex minds."
# Missing:0	''	Score:43884	Duplicates:9	'uicoesath'		Client:1	"Quick foxes jump over lazy dogs, both within each."
# Missing:0	''	Score:126140	Duplicates:15	'uilyeavngfospbr'		Client:1	"Quickly weaving foxes adopt playful zebras home, joyful blessings arrive."
# Missing:0	''	Score:125664	Duplicates:14	'uicephyrsmflov'		Client:1	"Quick zephyrs jumped, baffling sly foxes with clever moves."
# Missing:0	''	Score:152064	Duplicates:14	'icklyardosengt'		Client:1	"Quickly pack Bradford's jewelry, examining vast horizons gently."
# Missing:0	''	Score:214292	Duplicates:17	'oyfulesrtipdhganw'		Client:1	"Joyfully escort zipped through Xavier' keen questing whims abroad always safely."
# Missing:0	''	Score:86664	Duplicates:14	'uicoesprlayntg'		Client:1	"Quick foxes jump over lazy brown architects, diligently planning."
# -----------------------------
# Score:215644	Missing:0	''	Duplicates:19	'uerbasiwdlyfngpchot'		Client:1	"Queer zebras jive awkwardly, fumbling playful chaos unexpectedly tonight."
# Score:214292	Missing:0	''	Duplicates:17	'oyfulesrtipdhganw'		Client:1	"Joyfully escort zipped through Xavier' keen questing whims abroad always safely."
# Score:214292	Missing:0	''	Duplicates:17	'victualseoprznxyb'		Client:3	"Victuals jeopardaze when Xavier prints goofy albums brazen xylopockets quietly.."
# Score:214292	Missing:0	''	Duplicates:17	'uartexhibswnocpjl'		Client:1	"Quartz exhibits shrewd xenotech projects; valuable rankings jump swiftly now."
# Score:213616	Missing:0	''	Duplicates:16	'lucysimaboetprnz'		Client:1	"Lucy's whimsical books quietly explore vibrant, joyful, puzzling dreams."
# Score:212940	Missing:0	''	Duplicates:15	'umpinzealosrtyv'		Client:1	"Jumping zealous quips maximize robust unknowns promptly find lovely archives."
# Score:200000	Missing:1	'v'	Duplicates:20	'quitefranlywzdsgompb'		Client:1	"Quite frankly, wizards judge complex, baffling problems with zealous inquiry."
# Score:198750	Missing:1	'z'	Duplicates:18	'uirkygenatlcmdfosp'		Client:1	"Quirky Gwen exuberantly charmed folks, joyfully displaying captivating romance."
# Score:198750	Missing:1	'k'	Duplicates:18	'udgeaiomsprftlywnh'		Client:1	"Judge axioms perfectly; swiftly measure quintile depths when observing zestily ."
# Score:198750	Missing:1	'v'	Duplicates:18	'arshlwityudgenopbc'		Client:1	"Marshall swiftly judged xenophobic quartz, planning elaborate weekly schedules."
# Score:198750	Missing:1	'v'	Duplicates:18	'ualityfxespromgnhw'		Client:1	"Quality fixes prompt zealous judges exploiting humble network chaos swiftly."
# Score:198750	Missing:1	'v'	Duplicates:18	'grandeloushmpwyitc'		Client:1	"Grand zealous hounds jump awkwardly, bewitchingly flex triumphant charm quietly."
# Score:198750	Missing:1	'q'	Duplicates:18	'wisperngactlymovdu'		Client:1	"Whispering jack swiftly moved; vexatious pigeons abruptly zoomed clear!"
# Score:198750	Missing:1	'x'	Duplicates:18	'uiryebasnjoplvcdth'		Client:1	"Quirky zebras enjoy plump avocados, dancing with joyful, vibrant hues."
# Score:198750	Missing:1	'z'	Duplicates:18	'jawioversphbftlngu'		Client:1	"Jaxwick oversaw phoebejive swiftly, piloting robust quantum freighters onward."
# Score:198125	Missing:1	'b'	Duplicates:17	'zigapthselodnrumy'		Client:1	"Zigzag paths explode onward, jumping over quirky fatal rhythms calmly.</zags />"
# Score:198125	Missing:1	'w'	Duplicates:17	'uiteazlngxprsyohv'		Client:1	"Quite dazzling experts, maybe joyfully unpack serene thoughts eventually Xavier."
# Score:198125	Missing:1	'k'	Duplicates:17	'uitepymscaldnbofr'		Client:1	"Quite ztpy whimsical judges unexpectedly bloom fervourfully around noble cells.*"
# Score:198125	Missing:1	'k'	Duplicates:17	'quartohensilymgpx'		Client:1	"Quartz Cohen swiftly jammed Samsung's vibrant, perplexing xylophone quietly."
# Score:198125	Missing:1	'x'	Duplicates:17	'uerybandwitsmplzc'		Client:1	"Query bandwidths jumped subtly optimizing access; truly very swift, Zack!"
# Score:198125	Missing:1	'd'	Duplicates:17	'uarteoksxnigylcpm'		Client:1	"Quartz evokes Xenus bringing joyfully excellent works upon calm hopes.<img>"
# Score:198125	Missing:1	'w'	Duplicates:17	'uaingzelshdpromty'		Client:1	"Quacking zeal vanished prompt images softly box rare glyph zoo jumped really."
# Score:198125	Missing:1	'j'	Duplicates:17	'uietlbzngarwpsdof'		Client:1	"Quietly buzzing, Xavier wept; shadows faded among bleak, forlorn landscapes."
# Score:197500	Missing:1	'x'	Duplicates:16	'uartigswdlyonepf'		Client:1	"Quartz jigs awkwardly bounce upon five gentle rooftops today somehow..."
# Score:197500	Missing:1	'q'	Duplicates:16	'enolarsbyupigcht'		Client:2	"Xenon flares boldly, jumping cables via shocking energy zestwise groupsight."
# Score:197500	Missing:1	'v'	Duplicates:16	'epingwtarukslyfo'		Client:1	"Zepping with Xander Quinn makes playful jokes across baffling rows yet."
# Score:197500	Missing:1	'k'	Duplicates:16	'oyfulartednpswim'		Client:1	"Joyful quartz vexed Donna tops, swiftly embracing purple whims."
# Score:197500	Missing:1	'k'	Duplicates:16	'uartislecompngwd'		Client:1	"Quartz visibly echoes, jumping westward, framing new, complex designs."
# Score:197500	Missing:1	'j'	Duplicates:16	'uartilybngmsewcp'		Client:1	"Quartzily boxing drums flew while cracking lively emblems appear subtly."
# Score:197500	Missing:1	'k'	Duplicates:16	'uartinseplfyogvd'		Client:1	"Quartz bins exemplify playful actions giving rewarded, joyful harvests."
# Score:197500	Missing:1	'j'	Duplicates:16	'ueryinglsovtamdp'		Client:1	"Queryingly solve zestful exams; bright knowledge openly advances promptly."
# Score:197500	Missing:1	'k'	Duplicates:16	'uartzdiplomsgebn'		Client:1	"Quartz diplomats judged ballroom waltzes, exhibiting playful, vibrant grace."
# Score:197500	Missing:1	'v'	Duplicates:16	'udgineftlyosacrp'		Client:1	"Judging deftly quitted books anxiously charmed few zealous prospects near"
# Score:197500	Missing:1	'f'	Duplicates:16	'uartblosnepcdyiw'		Client:1	"Quartz blooms unexpectedly, happily accepting vibrant, jeweled rocks below."
# Score:197500	Missing:1	'z'	Duplicates:16	'uryingdsmaloethp'		Client:1	"Jurrying dismal books unequivocally framed, nothing exists properly anywhere."
# Score:197500	Missing:1	'k'	Duplicates:16	'estyuailomrwdnvp'		Client:1	"Zesty quails bloom, rewarding Xavier's joyfully purple whimsical adventure."
# Score:197500	Missing:1	'j'	Duplicates:16	'izwardsceyptmlng'		Client:1	"Quiz wizards face cryptic exams yielding thrilling pivotal answers remarkably."
# Score:197500	Missing:1	'j'	Duplicates:16	'uaintxerspdmlyvw'		Client:1	"Quaint xeriscaped zones exemplify thriving westward, truly remarkable views."
# Score:197500	Missing:1	'c'	Duplicates:16	'uiteranlymghsdpo'		Client:1	"Quite frankly, Birmingham sir, Xavier judged promptly with zealous hope."
# Score:197500	Missing:1	'k'	Duplicates:16	'uartbndsxpoeilmg'		Client:1	"Quartz bands juxtaposed finely examine crimson hull plotting valuable wings!"
# Score:197500	Missing:1	'x'	Duplicates:16	'auretidsglnpohkw'		Client:1	"Azure tides glisten, quivering pool depths beckon, joyful warmth awakens."
# Score:197500	Missing:1	'f'	Duplicates:16	'unieoxrlcsvatypw'		Client:2	"Unique zombie Xerox unlocks vast journeys, protecting valued pathways always."
# Score:196875	Missing:1	'k'	Duplicates:15	'agertblxposnwhi'		Client:1	"Jagged quartz bravely explores new spheres with infinite complex orbits."
# Score:196875	Missing:1	'z'	Duplicates:15	'atinqurslympdeo'		Client:1	"Bathing quirts justly ampl Updike'swift vision exceeds many prior quests"
# Score:196875	Missing:1	'w'	Duplicates:15	'aksutlyeminrpho'		Client:1	"Jack subtly examined quartz philatelny amongst various helpful realms alike"
# Score:196875	Missing:1	'k'	Duplicates:15	'uietlyangdrozsp'		Client:1	"Quietly examine jagged bronze relics, then swiftly devour purple zest."
# Score:196875	Missing:1	'k'	Duplicates:15	'uitemascrogndlp'		Client:1	"Quite majestic, farm tractors give boundless excellence zooming onward happily."
# Score:196875	Missing:1	'w'	Duplicates:15	'uirkaspetclodzn'		Client:1	"Quirk Jasper meticulously probed each puzzling X, vital kin of dots."
# Score:196875	Missing:1	'w'	Duplicates:15	'uiryavelmsncpot'		Client:1	"Quirky java fueled exams bring zen; clearly achieve prompt victories.!"
# Score:196875	Missing:1	'z'	Duplicates:15	'evryuilotshpgda'		Client:3	"Every quirky jewel box lets forth typing dreams cleverly displayed through."
# ============================
