# %%
DEBUG = False

# Word file assists with the randomness of the prompt
with open("words", 'r') as file:
        lines_array = [line.strip() for line in file.readlines()]
        if(DEBUG):
                print(f"{len(lines_array)} words in list")

# %%
from ollama import Client
from ollama import generate
import random

def generate_prompt():
    word1 = lines_array[random.randint(0, len(lines_array))]
    word2 = lines_array[random.randint(0, len(lines_array))]
    prompt = f"The theme is '{word1} {word2}'."
    if(DEBUG):
        print(f"{prompt}")
    # print(f"{word1}:{word2}")
    return prompt

def generate_response(client, model):
    prompt = generate_prompt()
    seed = int(random.random()*1000)
    system_prompt = "Write a single sentence with between 8 and 10 words. Only output the sentence generated without preamble. The goal is to use all the letters of the alphabet."
    options = {
        "seed": seed, 
        "temperature": seed/100.0,
        "num_predict": 400

    }
    response = client.generate(
        model = model,
        prompt = f"{system_prompt} {prompt}",
        # system = system_prompt,
        options=options,
        stream = False
    )
    reply = response['response']
    if(DEBUG):
        print(f"r:{reply}")
    return reply

# %%
class Sentence:
    def __init__(self, text, client):
        """
        Args:
            text (str): The text of the sentence.  Must be a string.
        
        Raises:
            TypeError: if input is not a string
        """
        if not isinstance(text, str):
            raise TypeError("Input must be a string.")

        if len(text) > 80:
            if(DEBUG):
                print(f"long text rejected: {text}")
            raise TypeError("No paragraphs.")
        
        self._text = text.encode("ascii", errors="ignore").decode()  # Use a protected attribute for encapsulation
        self._words = len(text.split(" "))
        self._missing = self.find_missing_letters()
        self._duplicates = self.find_duplicate_letters()
        self._duplength = len(self._duplicates)
        self._dupkeys = "".join(self._duplicates.keys())
        self._client = client

    def get_text(self):
        """
        Returns the text of the sentence.

        Returns:
            str: The sentence text.
        """
        return self._text

    def get_client(self):
        return self._client
    
    def get_missing(self):
        return self._missing
    
    def get_missing_count(self):
        return len(self.get_missing())
      
    def get_duplicates(self):
        return self._duplicates
    
    def get_duplength(self):
        return self._duplength
    
    def get_dupkeys(self):
        return self._dupkeys
    
    def get_score(self):
        missing_score = (26 - self.get_missing_count())**2 if self.get_missing_count() < 3 else 1
        duplicate_score = self.get_duplength()
        return missing_score * duplicate_score

    
    def find_missing_letters(self):
        """
        Checks a string for the presence of all lowercase letters and identifies missing ones.

        Returns:
            A string containing the missing letters, or an empty string if all letters are present.
            Returns None if the input is not a string.
        """

        alphabet = "abcdefghijklmnopqrstuvwxyz"
        missing_letters = ""
        
        # Convert the input string to lowercase for case-insensitive comparison
        input_string = self._text.lower()

        for letter in alphabet:
            if letter not in input_string:
                missing_letters += letter

        return missing_letters

    def find_duplicate_letters(self):
        """
        Identifies duplicate letters in a string and counts their occurrences.

        Returns:
            A dictionary where keys are the duplicate letters and values are their counts.
            Returns an empty dictionary if there are no duplicates.
            Returns None if the input is not a string.
        """

        letter_counts = {}
        duplicate_counts = {}

        input_string = self._text.lower()  # Case-insensitive counting

        for letter in input_string:
            if 'a' <= letter <= 'z':  # Only consider letters
                if letter in letter_counts:
                    letter_counts[letter] += 1
                else:
                    letter_counts[letter] = 1

        # Identify duplicates and create a new dictionary
        for letter, count in letter_counts.items():
            if count > 1:
                duplicate_counts[letter] = count

        return duplicate_counts

class Winners:
    def __init__(self):
        self._sentences = []

    def add(self, sentence):
        self._sentences.append(sentence)
        if(DEBUG):
            print(f"There are {len(self._sentences)} sentences in the list.")

    def get_missing_winners(self, _count):
        sorted_winners = sorted(self._sentences, key=lambda item: item.get_missing_count())
        return sorted_winners[:_count]
    
    def get_duplicate_winners(self, _count):
        sorted_winners = sorted(self._sentences, key=lambda item: item.get_score())
        return sorted_winners[len(sorted_winners)-_count:]

    def length(self):
        return len(self._sentences)

# Test cases. Add to this list when you find good terms.
the_sentences = [
    "The quick brown fox jumps over the lazy dog.",
    "Golden sunlight danced upon the rippling, turquoise ocean waves.",
    "Old photographs revealed stories of laughter, love, and bygone days.",
    "The majestic mountains stood silently guarding the peaceful valley below.",
    "She expertly crafted intricate jewelry using shimmering silver and gold. The majestic mountains stood silently guarding the peaceful valley below.",
    "Dark storm clouds gathered quickly, threatening a powerful summer rain.",
    "Street food tasted wonderfully fresh.",
    "Remote islands felt truly peaceful.",
    "The axel, quickly! Jumping fences with brave, zealous strides.",
    "The teen quickly jammed, exploring vibrant chords with joyful zest."
]

winners = Winners()
for sentence in the_sentences:
    try:
        winners.add(Sentence(sentence, 0))
        
    except Exception as e:
        print(e)


missing_winners = winners.get_missing_winners(5)
for winner in missing_winners:
    print(f"missing {winner.get_missing_count()} {winner.get_text()} '{winner.get_missing()}' duplicates: {winner.get_duplength()} '{winner.get_dupkeys()}' client: {winner.get_client()}")

print("****************************")
duplicate_winners = winners.get_duplicate_winners(5)
for winner in duplicate_winners:
    print(f"duplicates: {winner.get_duplength()} {winner.get_text()} '{winner.get_dupkeys()}' missing {winner.get_missing_count()} '{winner.get_missing()}' client: {winner.get_client()}")
# Out:
# No paragraphs.
# missing 0 The quick brown fox jumps over the lazy dog. '' duplicates: 6 'theuro' client: 0
# missing 0 The axel, quickly! Jumping fences with brave, zealous strides. '' duplicates: 11 'thealuicnsr' client: 0
# missing 0 The teen quickly jammed, exploring vibrant chords with joyful zest. '' duplicates: 16 'thenuiclyjamdors' client: 0
# missing 4 The majestic mountains stood silently guarding the peaceful valley below. 'kqxz' duplicates: 15 'themasicoundlyg' client: 0
# missing 5 Dark storm clouds gathered quickly, threatening a powerful summer rain. 'bjvxz' duplicates: 16 'darkstomclughein' client: 0
# ****************************
# duplicates: 15 The majestic mountains stood silently guarding the peaceful valley below. 'themasicoundlyg' missing 4 'kqxz' client: 0
# duplicates: 16 Dark storm clouds gathered quickly, threatening a powerful summer rain. 'darkstomclughein' missing 5 'bjvxz' client: 0
# duplicates: 6 The quick brown fox jumps over the lazy dog. 'theuro' missing 0 '' client: 0
# duplicates: 11 The axel, quickly! Jumping fences with brave, zealous strides. 'thealuicnsr' missing 0 '' client: 0
# duplicates: 16 The teen quickly jammed, exploring vibrant chords with joyful zest. 'thenuiclyjamdors' missing 0 '' client: 0

# %%
import threading
import time

timeout = 60*60 #7*60*60 #30*30 #1*60*60 #2*60*60 #7*60*60
winning_sentences = Winners()
running = True
previous_missing = [] # Keep track of high winners so we can display it when it changes.
DEBUG = False

def worker(client_id, url, model):
    """
     a client processing a task.
    
    Args:
        client_id: Unique identifier for the client.
        url: The URL associated with the client's task.
        model: the model to use for this client.
    """
    client = Client(host=url)
    i = 0
    while True:
        global running
        global winning_sentences
        global previous_missing
        i = i + 1
        if(running != True):
           # Exiting
           print(f"Quitting client {client_id} url {url} model {model} i {i} running: {running}")
           return
        try:
            if(DEBUG):
                print(f"client {client_id} url {url} model {model} i {i} running: {running}")

            sentence = Sentence(generate_response(client, model).strip().replace("\n", " "), client_id)
            if(DEBUG):
                print(sentence.get_text())

            winning_sentences.add(sentence)

            missing_winners = winning_sentences.get_duplicate_winners(5)
            if(missing_winners != previous_missing):
                previous_missing = missing_winners
                for winner in missing_winners:
                    print(f"missing {winner.get_missing_count()} {winner.get_text()} '{winner.get_missing()}' duplicates: {winner.get_duplength()} '{winner.get_dupkeys()}' client {winner.get_client()} score: {winner.get_score()}")
                print("****************************\n")
            # 3 Seconds of cool down for the LLM. This actually saves time in the forever loop.
            time.sleep(3)

        except Exception as e:
            dummy = 1 # Ignore all exceptions. Set dummy so linter doesn't complain.
            if(DEBUG):
                print(f"client {client_id} url {url} {e}")
        

def main():
    """
    Creates and starts multiple client threads.
    """

    clients = [
        {"id": 1, "url": "http://192.168.137.118:11434", "model": "gemma3:12b"},
        {"id": 2, "url": "http://192.168.137.117:11434", "model": "gemma3:4b"},
        {"id": 3, "url": "http://192.168.137.119:11434", "model": "gemma3:4b"},
    ]

    global running
    running = True
    threads = []
    for client in clients:
        thread = threading.Thread(target=worker, args=(client["id"], client["url"], client["model"]))
        threads.append(thread)
        thread.start()

    try:
        time.sleep(timeout)
        # Time's up. Tell threads to wrap it up. There may be a significant delay because the client might still be processing.
        running = False
        print(f"Calling it quits after {timeout} seconds.")
        
        # Wait for all threads to finish
        for thread in threads:
            thread.join(timeout=30)

        print("\n\nAll threads have stopped.")
        missing_winners = winning_sentences.get_missing_winners(50)
        
        # Word file assists with the randomness of the prompt
        with open("winners", 'a') as file:
            for winner in missing_winners:
                message = f"missing {winner.get_missing_count()} {winner.get_text()} '{winner.get_missing()}' duplicates: {winner.get_duplength()} '{winner.get_dupkeys()}' client {winner.get_client()} score: {winner.get_score()}"
                print(message)
                print(message, file=file)

            print("-----------------------------")
            duplicate_winners = winning_sentences.get_duplicate_winners(50)
            for winner in duplicate_winners:
                message = f"duplicates: {winner.get_duplength()} {winner.get_text()} '{winner.get_dupkeys()}' missing {winner.get_missing_count()} '{winner.get_missing()}' client {winner.get_client()} score: {winner.get_score()}"
                print(message)
                print(message, file=file)

            file.close()
            print("============================\n\n")

    
       
    except KeyboardInterrupt:
        print("Stopping threads due to KeyboardInterrupt...")
        running = False
        for thread in threads:
            thread.join()
        print("All threads stopped after KeyboardInterrupt")

if __name__ == "__main__":
    main()
# Out:
# missing 2 Zipping brazenly, vexed quixotic jumbles xylophone zillions tomorrow. 'fk' duplicates: 15 'zipnbrelyxuotms' client 3 score: 8640
# ****************************
#
# missing 2 Zipping brazenly, vexed quixotic jumbles xylophone zillions tomorrow. 'fk' duplicates: 15 'zipnbrelyxuotms' client 3 score: 8640
# missing 2 Zoom, flax enjoyed big quizzes where charming pupils read makeup wisely. 'tv' duplicates: 17 'zomlaenydiguswhrp' client 1 score: 9792
# ****************************
#
# missing 2 Zoom, flax enjoyed big quizzes where charming pupils read makeup wisely. 'tv' duplicates: 17 'zomlaenydiguswhrp' client 1 score: 9792
# ****************************
#
# missing 5 Box whispers, xylophone boasts quiet, frozen amber zest, following gables." 'cdjkv' duplicates: 17 'boxwhisperlnatfzg' client 2 score: 17
# missing 0 Jazzy sphinx vowed, "Quickly, brave men plot, feeling hope." '' duplicates: 11 'azyphinvoel' client 1 score: 7436
# missing 2 Zipping brazenly, vexed quixotic jumbles xylophone zillions tomorrow. 'fk' duplicates: 15 'zipnbrelyxuotms' client 3 score: 8640
# missing 0 Adopt zealous quick foxes, bringing happy joy under vast whims. '' duplicates: 14 'adopteusirnghy' client 1 score: 9464
# missing 2 Zoom, flax enjoyed big quizzes where charming pupils read makeup wisely. 'tv' duplicates: 17 'zomlaenydiguswhrp' client 1 score: 9792
# ****************************
#
# missing 0 Jazzy sphinx vowed, "Quickly, brave men plot, feeling hope." '' duplicates: 11 'azyphinvoel' client 1 score: 7436
# missing 2 Zipping brazenly, vexed quixotic jumbles xylophone zillions tomorrow. 'fk' duplicates: 15 'zipnbrelyxuotms' client 3 score: 8640
# missing 1 Quantum jokes quickly bridge, exposing fowl garb near vast hope. 'z' duplicates: 15 'quantokesilbrgp' client 1 score: 9375
# missing 0 Adopt zealous quick foxes, bringing happy joy under vast whims. '' duplicates: 14 'adopteusirnghy' client 1 score: 9464
# missing 2 Zoom, flax enjoyed big quizzes where charming pupils read makeup wisely. 'tv' duplicates: 17 'zomlaenydiguswhrp' client 1 score: 9792
# ****************************
#
# missing 2 Zipping brazenly, vexed quixotic jumbles xylophone zillions tomorrow. 'fk' duplicates: 15 'zipnbrelyxuotms' client 3 score: 8640
# missing 1 Quantum jokes quickly bridge, exposing fowl garb near vast hope. 'z' duplicates: 15 'quantokesilbrgp' client 1 score: 9375
# missing 1 Jack quizzed Wendy, finding clever numbers before a deep thought. 'x' duplicates: 15 'acuizednfgrboth' client 1 score: 9375
# missing 0 Adopt zealous quick foxes, bringing happy joy under vast whims. '' duplicates: 14 'adopteusirnghy' client 1 score: 9464
# missing 2 Zoom, flax enjoyed big quizzes where charming pupils read makeup wisely. 'tv' duplicates: 17 'zomlaenydiguswhrp' client 1 score: 9792
# ****************************
#
# missing 1 Quantum jokes quickly bridge, exposing fowl garb near vast hope. 'z' duplicates: 15 'quantokesilbrgp' client 1 score: 9375
# missing 1 Jack quizzed Wendy, finding clever numbers before a deep thought. 'x' duplicates: 15 'acuizednfgrboth' client 1 score: 9375
# missing 0 Adopt zealous quick foxes, bringing happy joy under vast whims. '' duplicates: 14 'adopteusirnghy' client 1 score: 9464
# missing 2 Zoom, flax enjoyed big quizzes where charming pupils read makeup wisely. 'tv' duplicates: 17 'zomlaenydiguswhrp' client 1 score: 9792
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# ****************************
#
# missing 1 Jack quizzed Wendy, finding clever numbers before a deep thought. 'x' duplicates: 15 'acuizednfgrboth' client 1 score: 9375
# missing 0 Adopt zealous quick foxes, bringing happy joy under vast whims. '' duplicates: 14 'adopteusirnghy' client 1 score: 9464
# missing 2 Zoom, flax enjoyed big quizzes where charming pupils read makeup wisely. 'tv' duplicates: 17 'zomlaenydiguswhrp' client 1 score: 9792
# missing 2 Quartz gym fixed, bravely, xenophobic pilots sew during hectic urban repairs. 'jk' duplicates: 18 'uartgyixedblnophcs' client 1 score: 10368
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# ****************************
#
# missing 0 Adopt zealous quick foxes, bringing happy joy under vast whims. '' duplicates: 14 'adopteusirnghy' client 1 score: 9464
# missing 2 Zoom, flax enjoyed big quizzes where charming pupils read makeup wisely. 'tv' duplicates: 17 'zomlaenydiguswhrp' client 1 score: 9792
# missing 2 Zealous fox jumps wildly, vexing quizzical readers with complex trends. 'bk' duplicates: 17 'zealousxmpwidncrt' client 3 score: 9792
# missing 2 Quartz gym fixed, bravely, xenophobic pilots sew during hectic urban repairs. 'jk' duplicates: 18 'uartgyixedblnophcs' client 1 score: 10368
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# ****************************
#
# missing 2 Zoom, flax enjoyed big quizzes where charming pupils read makeup wisely. 'tv' duplicates: 17 'zomlaenydiguswhrp' client 1 score: 9792
# missing 2 Zealous fox jumps wildly, vexing quizzical readers with complex trends. 'bk' duplicates: 17 'zealousxmpwidncrt' client 3 score: 9792
# missing 2 Amazingly, quirky zebra's profound fix gave worthy explanation, existing always. 'cj' duplicates: 17 'azinglyurespofxwt' client 1 score: 9792
# missing 2 Quartz gym fixed, bravely, xenophobic pilots sew during hectic urban repairs. 'jk' duplicates: 18 'uartgyixedblnophcs' client 1 score: 10368
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# ****************************
#
# missing 2 Zealous fox jumps wildly, vexing quizzical readers with complex trends. 'bk' duplicates: 17 'zealousxmpwidncrt' client 3 score: 9792
# missing 2 Amazingly, quirky zebra's profound fix gave worthy explanation, existing always. 'cj' duplicates: 17 'azinglyurespofxwt' client 1 score: 9792
# missing 2 Quartz gym fixed, bravely, xenophobic pilots sew during hectic urban repairs. 'jk' duplicates: 18 'uartgyixedblnophcs' client 1 score: 10368
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# missing 1 Abject judges quickly expleted nervous, volatile blame,receiving awful whispers. 'z' duplicates: 18 'abjectudgsilpnrvow' client 1 score: 11250
# ****************************
#
# missing 2 Amazingly, quirky zebra's profound fix gave worthy explanation, existing always. 'cj' duplicates: 17 'azinglyurespofxwt' client 1 score: 9792
# missing 2 Zipping fox awkwardly danced while xenops quietly baked vibrant loaves. 'jm' duplicates: 17 'ipnoxawkrdlyestbv' client 2 score: 9792
# missing 2 Quartz gym fixed, bravely, xenophobic pilots sew during hectic urban repairs. 'jk' duplicates: 18 'uartgyixedblnophcs' client 1 score: 10368
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# missing 1 Abject judges quickly expleted nervous, volatile blame,receiving awful whispers. 'z' duplicates: 18 'abjectudgsilpnrvow' client 1 score: 11250
# ****************************
#
# missing 2 Zipping fox awkwardly danced while xenops quietly baked vibrant loaves. 'jm' duplicates: 17 'ipnoxawkrdlyestbv' client 2 score: 9792
# missing 2 Quartz gym fixed, bravely, xenophobic pilots sew during hectic urban repairs. 'jk' duplicates: 18 'uartgyixedblnophcs' client 1 score: 10368
# missing 1 Zealous xylophone xylographs justified quickly, embracing nuanced wisdom alone. 'v' duplicates: 17 'ealousxyphngridcm' client 3 score: 10625
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# missing 1 Abject judges quickly expleted nervous, volatile blame,receiving awful whispers. 'z' duplicates: 18 'abjectudgsilpnrvow' client 1 score: 11250
# ****************************
#
# missing 1 Journey abruptly quickly zoomed west after benign conflict helped prove zen! 'x' duplicates: 16 'ourneyabptliczdf' client 1 score: 10000
# missing 2 Quartz gym fixed, bravely, xenophobic pilots sew during hectic urban repairs. 'jk' duplicates: 18 'uartgyixedblnophcs' client 1 score: 10368
# missing 1 Zealous xylophone xylographs justified quickly, embracing nuanced wisdom alone. 'v' duplicates: 17 'ealousxyphngridcm' client 3 score: 10625
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# missing 1 Abject judges quickly expleted nervous, volatile blame,receiving awful whispers. 'z' duplicates: 18 'abjectudgsilpnrvow' client 1 score: 11250
# ****************************
#
# missing 2 Quartz gym fixed, bravely, xenophobic pilots sew during hectic urban repairs. 'jk' duplicates: 18 'uartgyixedblnophcs' client 1 score: 10368
# missing 1 Zealous xylophone xylographs justified quickly, embracing nuanced wisdom alone. 'v' duplicates: 17 'ealousxyphngridcm' client 3 score: 10625
# missing 1 Box jumper frothed lazy queen validates what exciting pitfalls bury deep. 'k' duplicates: 17 'boxuperfthdlaynis' client 1 score: 10625
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# missing 1 Abject judges quickly expleted nervous, volatile blame,receiving awful whispers. 'z' duplicates: 18 'abjectudgsilpnrvow' client 1 score: 11250
# ****************************
#
# missing 1 Zealous xylophone xylographs justified quickly, embracing nuanced wisdom alone. 'v' duplicates: 17 'ealousxyphngridcm' client 3 score: 10625
# missing 1 Box jumper frothed lazy queen validates what exciting pitfalls bury deep. 'k' duplicates: 17 'boxuperfthdlaynis' client 1 score: 10625
# missing 0 Jumbo elves gaze whilst fixing quirky band upon dim electric mouth. '' duplicates: 16 'umboelsgahitnrdc' client 1 score: 10816
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# missing 1 Abject judges quickly expleted nervous, volatile blame,receiving awful whispers. 'z' duplicates: 18 'abjectudgsilpnrvow' client 1 score: 11250
# ****************************
#
# missing 1 Box jumper frothed lazy queen validates what exciting pitfalls bury deep. 'k' duplicates: 17 'boxuperfthdlaynis' client 1 score: 10625
# missing 1 Jax promptly ventured over blue cats firing whimsical zigzag quotes generally! 'k' duplicates: 17 'apromtlyvenucsigz' client 1 score: 10625
# missing 0 Jumbo elves gaze whilst fixing quirky band upon dim electric mouth. '' duplicates: 16 'umboelsgahitnrdc' client 1 score: 10816
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# missing 1 Abject judges quickly expleted nervous, volatile blame,receiving awful whispers. 'z' duplicates: 18 'abjectudgsilpnrvow' client 1 score: 11250
# ****************************
#
# missing 1 Jax promptly ventured over blue cats firing whimsical zigzag quotes generally! 'k' duplicates: 17 'apromtlyvenucsigz' client 1 score: 10625
# missing 1 Exuberant champions dazzled, achieving victory with flamboyant, quirky zeal. 'j' duplicates: 17 'eubrantchmiodzlvy' client 3 score: 10625
# missing 0 Jumbo elves gaze whilst fixing quirky band upon dim electric mouth. '' duplicates: 16 'umboelsgahitnrdc' client 1 score: 10816
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# missing 1 Abject judges quickly expleted nervous, volatile blame,receiving awful whispers. 'z' duplicates: 18 'abjectudgsilpnrvow' client 1 score: 11250
# ****************************
#
# missing 1 Exuberant champions dazzled, achieving victory with flamboyant, quirky zeal. 'j' duplicates: 17 'eubrantchmiodzlvy' client 3 score: 10625
# missing 1 Quick judges vex charming lads, proofably observing fragrant whims! 'z' duplicates: 17 'uicdgesvharmnlofb' client 1 score: 10625
# missing 0 Jumbo elves gaze whilst fixing quirky band upon dim electric mouth. '' duplicates: 16 'umboelsgahitnrdc' client 1 score: 10816
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# missing 1 Abject judges quickly expleted nervous, volatile blame,receiving awful whispers. 'z' duplicates: 18 'abjectudgsilpnrvow' client 1 score: 11250
# ****************************
#
# missing 1 Quick judges vex charming lads, proofably observing fragrant whims! 'z' duplicates: 17 'uicdgesvharmnlofb' client 1 score: 10625
# missing 1 Jaded quiz boxers humbly vex few grants, planning civic reform. 'k' duplicates: 17 'adeuiboxrsmlvfgnc' client 1 score: 10625
# missing 0 Jumbo elves gaze whilst fixing quirky band upon dim electric mouth. '' duplicates: 16 'umboelsgahitnrdc' client 1 score: 10816
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# missing 1 Abject judges quickly expleted nervous, volatile blame,receiving awful whispers. 'z' duplicates: 18 'abjectudgsilpnrvow' client 1 score: 11250
# ****************************
#
# missing 1 Jaded quiz boxers humbly vex few grants, planning civic reform. 'k' duplicates: 17 'adeuiboxrsmlvfgnc' client 1 score: 10625
# missing 0 Jumbo elves gaze whilst fixing quirky band upon dim electric mouth. '' duplicates: 16 'umboelsgahitnrdc' client 1 score: 10816
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# missing 1 Abject judges quickly expleted nervous, volatile blame,receiving awful whispers. 'z' duplicates: 18 'abjectudgsilpnrvow' client 1 score: 11250
# missing 1 Jack vehemently admired glowing hazy quaint Zeus knowingly put black fun, yep. 'x' duplicates: 18 'ackehmntlydigowzup' client 1 score: 11250
# ****************************
#
# missing 1 Brief quirky examine jug swiftly bathed cold fans help prize zealiously. --- 'v' duplicates: 17 'briefuyanstlhdopz' client 1 score: 10625
# missing 0 Jumbo elves gaze whilst fixing quirky band upon dim electric mouth. '' duplicates: 16 'umboelsgahitnrdc' client 1 score: 10816
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# missing 1 Abject judges quickly expleted nervous, volatile blame,receiving awful whispers. 'z' duplicates: 18 'abjectudgsilpnrvow' client 1 score: 11250
# missing 1 Jack vehemently admired glowing hazy quaint Zeus knowingly put black fun, yep. 'x' duplicates: 18 'ackehmntlydigowzup' client 1 score: 11250
# ****************************
#
# missing 0 Jumbo elves gaze whilst fixing quirky band upon dim electric mouth. '' duplicates: 16 'umboelsgahitnrdc' client 1 score: 10816
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# missing 1 Abject judges quickly expleted nervous, volatile blame,receiving awful whispers. 'z' duplicates: 18 'abjectudgsilpnrvow' client 1 score: 11250
# missing 1 Jack vehemently admired glowing hazy quaint Zeus knowingly put black fun, yep. 'x' duplicates: 18 'ackehmntlydigowzup' client 1 score: 11250
# missing 0 Quick foxes jumped over hazy byzones, allowing graceful warmth. '' duplicates: 17 'uicfoesmrhazynlwg' client 1 score: 11492
# ****************************
#
# missing 1 Justify powerful vexed chords; queen swiftly helped amazing, brave norms. 'k' duplicates: 18 'ustifypowerlvdhnam' client 1 score: 11250
# missing 1 Abject judges quickly expleted nervous, volatile blame,receiving awful whispers. 'z' duplicates: 18 'abjectudgsilpnrvow' client 1 score: 11250
# missing 1 Jack vehemently admired glowing hazy quaint Zeus knowingly put black fun, yep. 'x' duplicates: 18 'ackehmntlydigowzup' client 1 score: 11250
# missing 0 Quick foxes jumped over hazy byzones, allowing graceful warmth. '' duplicates: 17 'uicfoesmrhazynlwg' client 1 score: 11492
# missing 1 Quazy goblins fixed wretched items, giving her lucky, playful zones quickly. 'j' duplicates: 19 'quazygolinsfedrtchk' client 1 score: 11875
# ****************************
#
# missing 1 Abject judges quickly expleted nervous, volatile blame,receiving awful whispers. 'z' duplicates: 18 'abjectudgsilpnrvow' client 1 score: 11250
# missing 1 Jack vehemently admired glowing hazy quaint Zeus knowingly put black fun, yep. 'x' duplicates: 18 'ackehmntlydigowzup' client 1 score: 11250
# missing 1 Quartz vividly examined puzzling bricks forging headway quite recklessly anew." 'j' duplicates: 18 'quartzvidlyengcksw' client 1 score: 11250
# missing 0 Quick foxes jumped over hazy byzones, allowing graceful warmth. '' duplicates: 17 'uicfoesmrhazynlwg' client 1 score: 11492
# missing 1 Quazy goblins fixed wretched items, giving her lucky, playful zones quickly. 'j' duplicates: 19 'quazygolinsfedrtchk' client 1 score: 11875
# ****************************
#
# missing 1 Jack vehemently admired glowing hazy quaint Zeus knowingly put black fun, yep. 'x' duplicates: 18 'ackehmntlydigowzup' client 1 score: 11250
# missing 1 Quartz vividly examined puzzling bricks forging headway quite recklessly anew." 'j' duplicates: 18 'quartzvidlyengcksw' client 1 score: 11250
# missing 1 Just awkwardly flipped quiz examples perplexing wrongly; zest vanished quickly. 'b' duplicates: 18 'ustawkrdlyipeqzxng' client 1 score: 11250
# missing 0 Quick foxes jumped over hazy byzones, allowing graceful warmth. '' duplicates: 17 'uicfoesmrhazynlwg' client 1 score: 11492
# missing 1 Quazy goblins fixed wretched items, giving her lucky, playful zones quickly. 'j' duplicates: 19 'quazygolinsfedrtchk' client 1 score: 11875
# ****************************
#
# missing 1 Quartz vividly examined puzzling bricks forging headway quite recklessly anew." 'j' duplicates: 18 'quartzvidlyengcksw' client 1 score: 11250
# missing 1 Just awkwardly flipped quiz examples perplexing wrongly; zest vanished quickly. 'b' duplicates: 18 'ustawkrdlyipeqzxng' client 1 score: 11250
# missing 1 Quick brown foxes jump quizzically when amazing, drastic reforms truly bloom. 'v' duplicates: 18 'quicbrownfesmzalyt' client 1 score: 11250
# missing 0 Quick foxes jumped over hazy byzones, allowing graceful warmth. '' duplicates: 17 'uicfoesmrhazynlwg' client 1 score: 11492
# missing 1 Quazy goblins fixed wretched items, giving her lucky, playful zones quickly. 'j' duplicates: 19 'quazygolinsfedrtchk' client 1 score: 11875
# ****************************
#
# missing 1 Just awkwardly flipped quiz examples perplexing wrongly; zest vanished quickly. 'b' duplicates: 18 'ustawkrdlyipeqzxng' client 1 score: 11250
# missing 1 Quick brown foxes jump quizzically when amazing, drastic reforms truly bloom. 'v' duplicates: 18 'quicbrownfesmzalyt' client 1 score: 11250
# missing 1 Always jumpquickly because dreadful exotic fowl gravely hopped until waxing. 'z' duplicates: 18 'alwysupicedrfxotgn' client 1 score: 11250
# missing 0 Quick foxes jumped over hazy byzones, allowing graceful warmth. '' duplicates: 17 'uicfoesmrhazynlwg' client 1 score: 11492
# missing 1 Quazy goblins fixed wretched items, giving her lucky, playful zones quickly. 'j' duplicates: 19 'quazygolinsfedrtchk' client 1 score: 11875
# ****************************
#
# missing 1 Quick brown foxes jump quizzically when amazing, drastic reforms truly bloom. 'v' duplicates: 18 'quicbrownfesmzalyt' client 1 score: 11250
# missing 1 Always jumpquickly because dreadful exotic fowl gravely hopped until waxing. 'z' duplicates: 18 'alwysupicedrfxotgn' client 1 score: 11250
# missing 0 Quick foxes jumped over hazy byzones, allowing graceful warmth. '' duplicates: 17 'uicfoesmrhazynlwg' client 1 score: 11492
# missing 1 Quazy goblins fixed wretched items, giving her lucky, playful zones quickly. 'j' duplicates: 19 'quazygolinsfedrtchk' client 1 score: 11875
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# ****************************
#
# missing 1 Always jumpquickly because dreadful exotic fowl gravely hopped until waxing. 'z' duplicates: 18 'alwysupicedrfxotgn' client 1 score: 11250
# missing 0 Quick foxes jumped over hazy byzones, allowing graceful warmth. '' duplicates: 17 'uicfoesmrhazynlwg' client 1 score: 11492
# missing 0 Zany fox jumped quickly, vexing owls, xylophones, quizzing zombies, just before. '' duplicates: 17 'znyfoxjumpeqilgsb' client 2 score: 11492
# missing 1 Quazy goblins fixed wretched items, giving her lucky, playful zones quickly. 'j' duplicates: 19 'quazygolinsfedrtchk' client 1 score: 11875
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# ****************************
#
# missing 1 Buzz quietly exemplify zenith jawbox or profound vex struggles alike then.. 'c' duplicates: 18 'buzietlyxpfnhaorsg' client 1 score: 11250
# missing 0 Quick foxes jumped over hazy byzones, allowing graceful warmth. '' duplicates: 17 'uicfoesmrhazynlwg' client 1 score: 11492
# missing 0 Zany fox jumped quickly, vexing owls, xylophones, quizzing zombies, just before. '' duplicates: 17 'znyfoxjumpeqilgsb' client 2 score: 11492
# missing 1 Quazy goblins fixed wretched items, giving her lucky, playful zones quickly. 'j' duplicates: 19 'quazygolinsfedrtchk' client 1 score: 11875
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# ****************************
#
# missing 1 Jazzy quick fox jumped over vibrant, brown, silent, perplexed whales. 'g' duplicates: 18 'jazuioxpedvrbntwsl' client 1 score: 11250
# missing 0 Quick foxes jumped over hazy byzones, allowing graceful warmth. '' duplicates: 17 'uicfoesmrhazynlwg' client 1 score: 11492
# missing 0 Zany fox jumped quickly, vexing owls, xylophones, quizzing zombies, just before. '' duplicates: 17 'znyfoxjumpeqilgsb' client 2 score: 11492
# missing 1 Quazy goblins fixed wretched items, giving her lucky, playful zones quickly. 'j' duplicates: 19 'quazygolinsfedrtchk' client 1 score: 11875
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# ****************************
#
# missing 0 Quick foxes jumped over hazy byzones, allowing graceful warmth. '' duplicates: 17 'uicfoesmrhazynlwg' client 1 score: 11492
# missing 0 Zany fox jumped quickly, vexing owls, xylophones, quizzing zombies, just before. '' duplicates: 17 'znyfoxjumpeqilgsb' client 2 score: 11492
# missing 1 Quazy goblins fixed wretched items, giving her lucky, playful zones quickly. 'j' duplicates: 19 'quazygolinsfedrtchk' client 1 score: 11875
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# missing 0 Jack quizzed vile boywax experts humming fragile clocks despite zoning slowly. '' duplicates: 20 'ackuizedloywxprtsmng' client 1 score: 13520
# ****************************
#
# missing 0 Zany fox jumped quickly, vexing owls, xylophones, quizzing zombies, just before. '' duplicates: 17 'znyfoxjumpeqilgsb' client 2 score: 11492
# missing 1 Quazy goblins fixed wretched items, giving her lucky, playful zones quickly. 'j' duplicates: 19 'quazygolinsfedrtchk' client 1 score: 11875
# missing 1 Jack quick jovial fez brings wisdom; every point'sexpensed aptly founds glow!. 'h' duplicates: 20 'jackuiovlferngswdypt' client 1 score: 12500
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# missing 0 Jack quizzed vile boywax experts humming fragile clocks despite zoning slowly. '' duplicates: 20 'ackuizedloywxprtsmng' client 1 score: 13520
# ****************************
#
# missing 1 Quazy goblins fixed wretched items, giving her lucky, playful zones quickly. 'j' duplicates: 19 'quazygolinsfedrtchk' client 1 score: 11875
# missing 0 Jazz quick fox blended, defying grumpy whales showcasing fervent hopes now. '' duplicates: 18 'azuicfolendygrpwhs' client 1 score: 12168
# missing 1 Jack quick jovial fez brings wisdom; every point'sexpensed aptly founds glow!. 'h' duplicates: 20 'jackuiovlferngswdypt' client 1 score: 12500
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# missing 0 Jack quizzed vile boywax experts humming fragile clocks despite zoning slowly. '' duplicates: 20 'ackuizedloywxprtsmng' client 1 score: 13520
# ****************************
#
# missing 1 Jane briefly exclaimed puzzling quick jets; fox gladdens weary bishops aloud 'v' duplicates: 19 'janebriflyxcdpuzgso' client 1 score: 11875
# missing 0 Jazz quick fox blended, defying grumpy whales showcasing fervent hopes now. '' duplicates: 18 'azuicfolendygrpwhs' client 1 score: 12168
# missing 1 Jack quick jovial fez brings wisdom; every point'sexpensed aptly founds glow!. 'h' duplicates: 20 'jackuiovlferngswdypt' client 1 score: 12500
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# missing 0 Jack quizzed vile boywax experts humming fragile clocks despite zoning slowly. '' duplicates: 20 'ackuizedloywxprtsmng' client 1 score: 13520
# ****************************
#
# missing 0 Jazz quick fox blended, defying grumpy whales showcasing fervent hopes now. '' duplicates: 18 'azuicfolendygrpwhs' client 1 score: 12168
# missing 0 Believe juxtamosing facts quizly, remarkable depths empower scholarly xenodochy. '' duplicates: 18 'beliuxtamosncyrdph' client 1 score: 12168
# missing 1 Jack quick jovial fez brings wisdom; every point'sexpensed aptly founds glow!. 'h' duplicates: 20 'jackuiovlferngswdypt' client 1 score: 12500
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# missing 0 Jack quizzed vile boywax experts humming fragile clocks despite zoning slowly. '' duplicates: 20 'ackuizedloywxprtsmng' client 1 score: 13520
# ****************************
#
# missing 0 Believe juxtamosing facts quizly, remarkable depths empower scholarly xenodochy. '' duplicates: 18 'beliuxtamosncyrdph' client 1 score: 12168
# missing 0 Quartz judges vexed lawmakers, probing cryptic bills, examining federal growth. '' duplicates: 18 'uartdgesxlwmpobinc' client 1 score: 12168
# missing 1 Jack quick jovial fez brings wisdom; every point'sexpensed aptly founds glow!. 'h' duplicates: 20 'jackuiovlferngswdypt' client 1 score: 12500
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# missing 0 Jack quizzed vile boywax experts humming fragile clocks despite zoning slowly. '' duplicates: 20 'ackuizedloywxprtsmng' client 1 score: 13520
# ****************************
#
# missing 0 Quartz judges vexed lawmakers, probing cryptic bills, examining federal growth. '' duplicates: 18 'uartdgesxlwmpobinc' client 1 score: 12168
# missing 1 Jack quick jovial fez brings wisdom; every point'sexpensed aptly founds glow!. 'h' duplicates: 20 'jackuiovlferngswdypt' client 1 score: 12500
# missing 1 The quirky fox jumps bravely, vexing zealots while weaving a complex fable. 'd' duplicates: 20 'theuiryfoxmpsbavlngw' client 3 score: 12500
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# missing 0 Jack quizzed vile boywax experts humming fragile clocks despite zoning slowly. '' duplicates: 20 'ackuizedloywxprtsmng' client 1 score: 13520
# ****************************
#
# missing 0 Zealous fox jumps quickly, vexing quirky owls, revealing hidden alphabets. '' duplicates: 18 'ealousxpqikyvngrhd' client 3 score: 12168
# missing 1 Jack quick jovial fez brings wisdom; every point'sexpensed aptly founds glow!. 'h' duplicates: 20 'jackuiovlferngswdypt' client 1 score: 12500
# missing 1 The quirky fox jumps bravely, vexing zealots while weaving a complex fable. 'd' duplicates: 20 'theuiryfoxmpsbavlngw' client 3 score: 12500
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# missing 0 Jack quizzed vile boywax experts humming fragile clocks despite zoning slowly. '' duplicates: 20 'ackuizedloywxprtsmng' client 1 score: 13520
# ****************************
#
# missing 1 Jack quick jovial fez brings wisdom; every point'sexpensed aptly founds glow!. 'h' duplicates: 20 'jackuiovlferngswdypt' client 1 score: 12500
# missing 1 The quirky fox jumps bravely, vexing zealots while weaving a complex fable. 'd' duplicates: 20 'theuiryfoxmpsbavlngw' client 3 score: 12500
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# missing 0 Jack quizzed vile boywax experts humming fragile clocks despite zoning slowly. '' duplicates: 20 'ackuizedloywxprtsmng' client 1 score: 13520
# missing 0 Jewels perplexed amazing quiet zones bring hard comfort forever thankfully waxy. '' duplicates: 20 'ewlsprxdamzingutohfy' client 1 score: 13520
# ****************************
#
# missing 1 The quirky fox jumps bravely, vexing zealots while weaving a complex fable. 'd' duplicates: 20 'theuiryfoxmpsbavlngw' client 3 score: 12500
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# missing 0 Jack quizzed vile boywax experts humming fragile clocks despite zoning slowly. '' duplicates: 20 'ackuizedloywxprtsmng' client 1 score: 13520
# missing 0 Jewels perplexed amazing quiet zones bring hard comfort forever thankfully waxy. '' duplicates: 20 'ewlsprxdamzingutohfy' client 1 score: 13520
# missing 0 Daring jockswampingly quiz fervent globe handling zinc apathy over wax blooms.* '' duplicates: 20 'daringocswmplyzevtbh' client 1 score: 13520
# ****************************
#
# missing 0 Jazywx plumbing forms q Zed brisk technique governs all projects now." '' duplicates: 19 'jazwplumbingorsqetc' client 1 score: 12844
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# missing 0 Jack quizzed vile boywax experts humming fragile clocks despite zoning slowly. '' duplicates: 20 'ackuizedloywxprtsmng' client 1 score: 13520
# missing 0 Jewels perplexed amazing quiet zones bring hard comfort forever thankfully waxy. '' duplicates: 20 'ewlsprxdamzingutohfy' client 1 score: 13520
# missing 0 Daring jockswampingly quiz fervent globe handling zinc apathy over wax blooms.* '' duplicates: 20 'daringocswmplyzevtbh' client 1 score: 13520
# ****************************
#
# missing 0 Either beat, fox jumps quickly, vexing zealots, finding joyous, weird alphabet. '' duplicates: 19 'eithrbafoxjupslyngd' client 2 score: 12844
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# missing 0 Jack quizzed vile boywax experts humming fragile clocks despite zoning slowly. '' duplicates: 20 'ackuizedloywxprtsmng' client 1 score: 13520
# missing 0 Jewels perplexed amazing quiet zones bring hard comfort forever thankfully waxy. '' duplicates: 20 'ewlsprxdamzingutohfy' client 1 score: 13520
# missing 0 Daring jockswampingly quiz fervent globe handling zinc apathy over wax blooms.* '' duplicates: 20 'daringocswmplyzevtbh' client 1 score: 13520
# ****************************
#
# missing 1 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'v' duplicates: 21 'quartbicksexmplfyhond' client 1 score: 13125
# missing 0 Jack quizzed vile boywax experts humming fragile clocks despite zoning slowly. '' duplicates: 20 'ackuizedloywxprtsmng' client 1 score: 13520
# missing 0 Jewels perplexed amazing quiet zones bring hard comfort forever thankfully waxy. '' duplicates: 20 'ewlsprxdamzingutohfy' client 1 score: 13520
# missing 0 Daring jockswampingly quiz fervent globe handling zinc apathy over wax blooms.* '' duplicates: 20 'daringocswmplyzevtbh' client 1 score: 13520
# missing 0 Zealous foxes jumped quickly over wacky barges enjoying quite bizarre triumphs. '' duplicates: 20 'zealousjmpqickyrbgnt' client 2 score: 13520
# ****************************
#
# Calling it quits after 3600 seconds.
# Quitting client 1 url http://192.168.137.118:11434 model gemma3:12b i 1056 running: False
# Quitting client 2 url http://192.168.137.117:11434 model gemma3:4b i 2326 running: False
# Quitting client 3 url http://192.168.137.119:11434 model gemma3:4b i 995 running: False
#
#
# All threads have stopped.
# missing 0 Jazzy sphinx vowed, "Quickly, brave men plot, feeling hope." '' duplicates: 11 'azyphinvoel' client 1 score: 7436
# missing 0 Adopt zealous quick foxes, bringing happy joy under vast whims. '' duplicates: 14 'adopteusirnghy' client 1 score: 9464
# missing 0 Quartz jived, vexing plump hawks, calmly breaking free, now gone. '' duplicates: 14 'uarivengplmwko' client 1 score: 9464
# missing 0 Quartz jinxed bleakly, few nymphs lost, vexing sad chrome. '' duplicates: 14 'artinxedlymhso' client 1 score: 9464
# missing 0 Jumbo elves gaze whilst fixing quirky band upon dim electric mouth. '' duplicates: 16 'umboelsgahitnrdc' client 1 score: 10816
# missing 0 Quick foxes jumped over hazy byzones, allowing graceful warmth. '' duplicates: 17 'uicfoesmrhazynlwg' client 1 score: 11492
# missing 0 Zesty foxes jump wildly, exhibiting quirky, vibrant, electric clusters. '' duplicates: 12 'estyxuilbnrc' client 2 score: 8112
# missing 0 Quartz jokes examine fanciful building upon rapid valuation methods anyway. '' duplicates: 15 'uartoesminfldpy' client 1 score: 10140
# missing 0 Quick buzzards jumped over fence, vexed while blasting shiny plum. '' duplicates: 16 'uicbzardsmpevnhl' client 1 score: 10816
# missing 0 Insurance coverage zapped a fox jumping quickly under strange alphabet whims. '' duplicates: 16 'insuraceogpdmlth' client 3 score: 10816
# missing 0 Quick brown fox jumps over lazy dogs, breathe offer zeal. '' duplicates: 10 'ubrofselaz' client 1 score: 6760
# missing 0 Jumpy quizzes excite, feeling brave, awkward nymphs glow, strangely zestful. '' duplicates: 16 'umpyizestflngraw' client 1 score: 10816
# missing 0 Jew Zbyshek brought quiche every April fixed data numerically. '' duplicates: 12 'ebyhruticald' client 1 score: 8112
# missing 0 Zebras quietly jumped, vexing hawks, barring xylophone's playful, bizarre echo. '' duplicates: 16 'zebrasuilypxngho' client 3 score: 10816
# missing 0 Quick zip boxes jumped fervously against a novel whimplicity felt. '' duplicates: 15 'uicpoesmfvlyant' client 1 score: 10140
# missing 0 Zany fox jumped quickly, vexing owls, xylophones, quizzing zombies, just before. '' duplicates: 17 'znyfoxjumpeqilgsb' client 2 score: 11492
# missing 0 Abrupt query examined fowl gaze held intricate joke loved mystery. '' duplicates: 12 'aruteymindol' client 1 score: 8112
# missing 0 Quick brown fox jumps creatively over the lazy dog yearning. '' duplicates: 13 'uicroneatvlyg' client 2 score: 8788
# missing 0 Zipping quickly, a fox jumped over the lazy brown jackal's lap. '' duplicates: 14 'zipnucklyaojer' client 2 score: 9464
# missing 0 Jazy quick farms boxed within lovely, ample ground. '' duplicates: 11 'ayuirmoednl' client 1 score: 7436
# missing 0 Jack quizzed vile boywax experts humming fragile clocks despite zoning slowly. '' duplicates: 20 'ackuizedloywxprtsmng' client 1 score: 13520
# missing 0 Quick wizards fixably jog, proving active zealotry; humans brave curiosity! '' duplicates: 16 'uiczarsblyogvnte' client 1 score: 10816
# missing 0 Quartz jumbles awkwardly fixed every clumsy protein highway. '' duplicates: 13 'uartmleswdyih' client 1 score: 8788
# missing 0 Jump quickly by where foxes gaze, then unveil evident proofs. '' duplicates: 14 'upilyherfostnv' client 1 score: 9464
# missing 0 Zealous fox jumps quickly, bagging vowels for precise snapshot evidence. '' duplicates: 14 'ealousfpicgnvr' client 3 score: 9464
# missing 0 Fox juries gladly vex quick wizards hoping just blame faith. '' duplicates: 15 'foxjuriesgladht' client 1 score: 10140
# missing 0 Jazz quick fox blended, defying grumpy whales showcasing fervent hopes now. '' duplicates: 18 'azuicfolendygrpwhs' client 1 score: 12168
# missing 0 Briefly jackdrew quivering writes zig and phlegmiats xylphones.\\``` '' duplicates: 14 'rielyadwngtsph' client 1 score: 9464
# missing 0 Quick brown fox jumps over lazy dogs, vexing xylophone rhythms. '' duplicates: 15 'uironxmpsvelygh' client 3 score: 10140
# missing 0 Jax quickly zoned beneath firm guiding healths: proof of vows done wisely. '' duplicates: 16 'auilyonedthfrgsw' client 1 score: 10816
# missing 0 Though jxyzed quick warnings fervently prompt breathless chaos forever '' duplicates: 17 'thougyeicarnsfvlp' client 1 score: 11492
# missing 0 Quite breezy foxes jovfully lick damp earth grading palatable winter yarns. '' duplicates: 16 'uitebryfosldapgn' client 1 score: 10816
# missing 0 Judge wax quick zealot bribez fantz humbly disprove common truths. '' duplicates: 16 'udeaiczlotbrnhms' client 1 score: 10816
# missing 0 Jack buzzed quickly, vexing dwarf home while adding potential risk. '' duplicates: 16 'ackuzedilngwrhot' client 1 score: 10816
# missing 0 Amazingly quick foxes jab wildly beyond pregnant teachers using vinyl. '' duplicates: 15 'ainglyucoesbdrt' client 1 score: 10140
# missing 0 Believe juxtamosing facts quizly, remarkable depths empower scholarly xenodochy. '' duplicates: 18 'beliuxtamosncyrdph' client 1 score: 12168
# missing 0 Jax zipped quickly, observing complex solar patterns with genuine fascination. '' duplicates: 14 'axipeuclosrngt' client 2 score: 9464
# missing 0 Quartz judges vexed lawmakers, probing cryptic bills, examining federal growth. '' duplicates: 18 'uartdgesxlwmpobinc' client 1 score: 12168
# missing 0 Azure quietly reflected joyous knights, blocking wild expansive forms . '' duplicates: 16 'aureitlyfcdoskng' client 1 score: 10816
# missing 0 Zealous foxes jumped quickly, weaving branches beneath a vibrant, leafy tree. '' duplicates: 16 'ealousficyvnbrht' client 3 score: 10816
# missing 0 Jukebox quiz vehemently asked bravery, copying flaws to gently hope. '' duplicates: 17 'ukeboivhntlyasrpg' client 1 score: 11492
# missing 0 Zealous fox jumps quickly, vexing quirky owls, revealing hidden alphabets. '' duplicates: 18 'ealousxpqikyvngrhd' client 3 score: 12168
# missing 0 Jax quickly valued superb, bizarre feng shui gifts where many observed. '' duplicates: 15 'auilyvedsrbfngh' client 1 score: 10140
# missing 0 Jewels perplexed amazing quiet zones bring hard comfort forever thankfully waxy. '' duplicates: 20 'ewlsprxdamzingutohfy' client 1 score: 13520
# missing 0 Jazz quickly foxed big planes unveiling rhythmic dwarf experts. '' duplicates: 18 'azuiclyfxedgpnsrht' client 1 score: 12168
# missing 0 Daring jockswampingly quiz fervent globe handling zinc apathy over wax blooms.* '' duplicates: 20 'daringocswmplyzevtbh' client 1 score: 13520
# missing 0 Jazywx plumbing forms q Zed brisk technique governs all projects now." '' duplicates: 19 'jazwplumbingorsqetc' client 1 score: 12844
# missing 0 Quick fox jumps wildly, vexing quirky zebras with a humorous image. '' duplicates: 16 'quikoxmswlyegrah' client 2 score: 10816
# missing 0 Jane quickly vowed "bizarium perplexing truth" at our hopeful claims. '' duplicates: 13 'aneuiclormpth' client 1 score: 8788
# missing 0 Quartz jolt baffled, quickly vexed, grumpy bricks crashed silently now. '' duplicates: 17 'quartolbfedickysn' client 1 score: 11492
# -----------------------------
# duplicates: 18 Twelve brave foxes watched jumbles zipped vexingly quiz boldly, then Zowie. 'twelvbaoxshduzipny' missing 1 'k' client 3 score: 11250
# duplicates: 18 Quixotically zipped by, moved bravely concerning exuberant joyous knights felt. 'uixotcalypedbvrngs' missing 1 'w' client 1 score: 11250
# duplicates: 18 Jay quizzes baffled xenophilic dwarves completing rigorous testing beforehand. 'auizesbfldnophcrtg' missing 1 'k' client 1 score: 11250
# duplicates: 18 Amazblzing complex, hefty junk paved central depot quickly unearthed urban zones 'amzblincopehtyukdr' missing 1 'w' client 1 score: 11250
# duplicates: 18 Amazebbqfox judicious plight quaintly reverenced upholstery ventured wise. 'aebqoudicsplhtnyrv' missing 1 'k' client 1 score: 11250
# duplicates: 18 Bright fuzzy jewels exemplify quaint, honest, victory amongst perplexing data. 'rightfuzyelsxmpano' missing 1 'k' client 1 score: 11250
# duplicates: 18 Quick zephyrs jambed, waxing puzzled fortunes; try guesses wisely somehow. 'uizephyrsamdwnglot' missing 1 'v' client 1 score: 11250
# duplicates: 17 Quick foxes jumped over hazy byzones, allowing graceful warmth. 'uicfoesmrhazynlwg' missing 0 '' client 1 score: 11492
# duplicates: 17 Zany fox jumped quickly, vexing owls, xylophones, quizzing zombies, just before. 'znyfoxjumpeqilgsb' missing 0 '' client 2 score: 11492
# duplicates: 17 Though jxyzed quick warnings fervently prompt breathless chaos forever 'thougyeicarnsfvlp' missing 0 '' client 1 score: 11492
# duplicates: 17 Jukebox quiz vehemently asked bravery, copying flaws to gently hope. 'ukeboivhntlyasrpg' missing 0 '' client 1 score: 11492
# duplicates: 17 Quartz jolt baffled, quickly vexed, grumpy bricks crashed silently now. 'quartolbfedickysn' missing 0 '' client 1 score: 11492
# duplicates: 17 Zipping quickly, fox jumps bravely over quiet Bind Valley's hazy, warm peaks. 'zipnquklyomsbrave' missing 0 '' client 2 score: 11492
# duplicates: 17 "Zealous fox jumped quickly by vox newspapers, exhibiting zealous knowledge." 'zealousxpdikybnwg' missing 0 '' client 3 score: 11492
# duplicates: 17 Flummox quietly jokes with azure brawling fighters resolving unexpected plight. 'flumoxietswharngp' missing 0 '' client 1 score: 11492
# duplicates: 17 Boxing quiz jumped flawlessly; prove data excitingly makes swift help! 'oxingumpedflawsyt' missing 0 '' client 1 score: 11492
# duplicates: 17 Black box jumped vigorously quite under zestful way haphazard forms. 'blaoumpedirsytzfh' missing 0 '' client 1 score: 11492
# duplicates: 17 Juggling fox vibes quell any dark whims experiencing sharp quartz breezy hunt. 'uglinxbesqayrhptz' missing 0 '' client 1 score: 11492
# duplicates: 17 Whether fox jumps quickly over zealous brown dogs, vexed, yearning, each. 'wheroxusiclyvandg' missing 0 '' client 2 score: 11492
# duplicates: 17 Quackers, very well jablick family explored fuzzy gnome heritage intently.&punct 'uackerylifmpozgnt' missing 0 '' client 1 score: 11492
# duplicates: 17 Pack zeal foxes by humming vibrant jet quirkly adorn cheap wind.\ 'packelobyhuminrtd' missing 0 '' client 1 score: 11492
# duplicates: 20 Exuberant whimsical zebras pack complex fox guitars, enjoying quirky shows. 'exubrantwhimsclpkogy' missing 2 'dv' client 2 score: 11520
# duplicates: 19 Quazy goblins fixed wretched items, giving her lucky, playful zones quickly. 'quazygolinsfedrtchk' missing 1 'j' client 1 score: 11875
# duplicates: 19 Jane briefly exclaimed puzzling quick jets; fox gladdens weary bishops aloud 'janebriflyxcdpuzgso' missing 1 'v' client 1 score: 11875
# duplicates: 19 Amazingly quiltboxed fervent ghost hawks joked, tracing windy calm debut. 'aminglyutboedrhswkc' missing 1 'p' client 1 score: 11875
# duplicates: 19 Jazzingly quite shrewd voyage was fed hemp blocks very deeply scrutinized 'azinglyuteshrwdvopc' missing 1 'x' client 1 score: 11875
# duplicates: 19 Quartz jumps briefly, vexing wild nymphs, amazing characters flowed. 'uartzmpsieflyngwdhc' missing 1 'k' client 1 score: 11875
# duplicates: 19 Quick gazebosmably flowing with jets xyz utterly frames loaded prospects . 'uicgazebosmlyfwtrdp' missing 1 'v' client 1 score: 11875
# duplicates: 19 Jax quickly baffled zero phones upon wry gaming luckedly brought cold axes. 'axuicklybfedrophnsg' missing 1 'v' client 1 score: 11875
# duplicates: 19 Quick jangles framed the lively paradox resolving jumpbox within deep awe. 'uijanglesrmdthvpoxw' missing 1 'z' client 1 score: 11875
# duplicates: 18 Jazz quick fox blended, defying grumpy whales showcasing fervent hopes now. 'azuicfolendygrpwhs' missing 0 '' client 1 score: 12168
# duplicates: 18 Believe juxtamosing facts quizly, remarkable depths empower scholarly xenodochy. 'beliuxtamosncyrdph' missing 0 '' client 1 score: 12168
# duplicates: 18 Quartz judges vexed lawmakers, probing cryptic bills, examining federal growth. 'uartdgesxlwmpobinc' missing 0 '' client 1 score: 12168
# duplicates: 18 Zealous fox jumps quickly, vexing quirky owls, revealing hidden alphabets. 'ealousxpqikyvngrhd' missing 0 '' client 3 score: 12168
# duplicates: 18 Jazz quickly foxed big planes unveiling rhythmic dwarf experts. 'azuiclyfxedgpnsrht' missing 0 '' client 1 score: 12168
# duplicates: 18 Jazz quiver flew: blankly chromating dusty giants woke perplexing vortex 'azuiverlwnkyotgspx' missing 0 '' client 1 score: 12168
# duplicates: 18 Buzz exemplified quartz hymns quickly divulged later joyful Xenophon wrote. 'uzexmplifdqarthyno' missing 0 '' client 1 score: 12168
# duplicates: 20 Jack quick jovial fez brings wisdom; every point'sexpensed aptly founds glow!. 'jackuiovlferngswdypt' missing 1 'h' client 1 score: 12500
# duplicates: 20 The quirky fox jumps bravely, vexing zealots while weaving a complex fable. 'theuiryfoxmpsbavlngw' missing 1 'd' client 3 score: 12500
# duplicates: 20 Quick waltzes fixed grubby shops now exemplify craving pricey zest abound. 'uicwaltzesfxdgrbyopn' missing 1 'j' client 1 score: 12500
# duplicates: 20 Lazy brown foxes quickly jumped above clever dwarfs enjoying pleasant times. 'laybrownfesuicjmpdvt' missing 1 'h' client 1 score: 12500
# duplicates: 19 Jazywx plumbing forms q Zed brisk technique governs all projects now." 'jazwplumbingorsqetc' missing 0 '' client 1 score: 12844
# duplicates: 19 Either beat, fox jumps quickly, vexing zealots, finding joyous, weird alphabet. 'eithrbafoxjupslyngd' missing 0 '' client 2 score: 12844
# duplicates: 19 Blank juxtapositions quickly charmed every forlorn gaze, bewitchingly prompted. 'blankutposicyhrmedg' missing 0 '' client 1 score: 12844
# duplicates: 19 Withdraw your gaze, observe the fox jumping quickly, xenophobic, zealous. 'withrayougzebsxpncl' missing 0 '' client 2 score: 12844
# duplicates: 21 Quartz bricks exemplify how xenophobes jump quickly under faded grey paths. 'quartbicksexmplfyhond' missing 1 'v' client 1 score: 13125
# duplicates: 20 Jack quizzed vile boywax experts humming fragile clocks despite zoning slowly. 'ackuizedloywxprtsmng' missing 0 '' client 1 score: 13520
# duplicates: 20 Jewels perplexed amazing quiet zones bring hard comfort forever thankfully waxy. 'ewlsprxdamzingutohfy' missing 0 '' client 1 score: 13520
# duplicates: 20 Daring jockswampingly quiz fervent globe handling zinc apathy over wax blooms.* 'daringocswmplyzevtbh' missing 0 '' client 1 score: 13520
# duplicates: 20 Zealous foxes jumped quickly over wacky barges enjoying quite bizarre triumphs. 'zealousjmpqickyrbgnt' missing 0 '' client 2 score: 13520
# ============================
